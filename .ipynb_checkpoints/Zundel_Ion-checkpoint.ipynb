# %% [markdown]
# # Ion Zundel et Potentiel Machine Learning #
# Loan RENAUD et Zacharie WAYSENSON
#
#
# ## **Load des données et animations** ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
import pandas as pd
from scipy.constants import Boltzmann
from scipy.constants import e as eV
import mdtraj as mdt
import nglview as nv
from ase import Atoms
from dscribe.descriptors import CoulombMatrix
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from dscribe.descriptors import SOAP
from ase.io import read
from sklearn.decomposition import PCA
from dscribe.kernels import AverageKernel
from scipy.spatial import distance
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn.kernel_ridge import KernelRidge
import keras
import tensorflow as tf
from keras import regularizers
from keras import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import tensorflow as tf
import vg



# %matplotlib inline

# %%
#Loader du fichier .xyz
def load_data(file):
    o1_index=[2]
    o2_index=[3]
    h1_index=[4]
    h2_index=[5]
    h3_index=[6]
    h4_index=[7]
    h5_index=[8]

    o1=[]
    o2=[]
    h1=[]
    h2=[]
    h3=[]
    h4=[]
    h5=[]

    with open(file, 'r') as infile:

        for index, line in enumerate(infile):
            items = line.split()

            if index%9 in o1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o1.append([0,x,y,z])

            if index%9 in o2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o2.append([0,x,y,z])

            if index%9 in h1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h1.append([1,x,y,z])   

            if index%9 in h2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h2.append([1,x,y,z])

            if index%9 in h3_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h3.append([1,x,y,z])

            if index%9 in h4_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h4.append([1,x,y,z])

            if index%9 in h5_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h5.append([1,x,y,z])
                
    return np.concatenate((o1, o2, h1, h2, h3, h4, h5), axis=1).reshape(10000, 7, 4) #10000 fois 7 colomnes de 4 éléments  (particule, x, y, z)

#Loader de l'output de la simulation (fichier .out)
output=pd.read_csv('new_energies_sparse.out', sep=' ', header=None)

#Extraction des énergies (5eme colonne)
energies=output[4]

#Load du fichier .xyz
dataset=load_data("new_positions_sparse.xyz")

#################
# Plot des données (Animation 3D + Energie)
#################

#Nombre de data utilisées pour l'animation
N=100

#Init animation 2D
def init():
    return graph,

#Fonction update plot energies
def update_en(num):
    graph.set_data(x[:num],y[:num])
    return graph,

#Mise en forme des trajectoires
def transform_data(X, Y, Z):
    t = np.vstack((X, Y, Z))
    return t

#Fonction update pour le plot des trajectoires
def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        line.set_data(data[0:2, num-1:num])
        line.set_3d_properties(data[2,num-1:num])
    return lines

#Fonction update des deux plots
def update_both(num, data2, line2):
    update_en(num)
    update_lines(num, data2, line2)
    
#Création de la figure
fig= plt.figure(figsize=(5, 8))

#ax1 = plot des énergies
ax1=fig.add_subplot(2, 1, 2) 
ax1.set_xlim(0, N)
ax1.set_ylim(np.min(energies), np.max(energies))
ax1.set_xlabel("Simulation step")
ax1.set_ylabel("Energie potentielle du système (u.a.)")

graph, = plt.plot([], [], '-')

#ax = plot des trajectoires
ax=fig.add_subplot(2, 1, 1, projection='3d')

ax.set_xlim3d([np.min(dataset[:, :, 1][:N]), np.max(dataset[:, :, 1][:N])])
ax.set_xlabel('X')

ax.set_ylim3d([np.min(dataset[:, :, 2][:N]), np.max(dataset[:, :, 2][:N])])
ax.set_ylabel('Y')

ax.set_zlim3d([np.min(dataset[:, :, 3][:N]), np.max(dataset[:, :, 3][:N])])
ax.set_zlabel('Z')

ax.set_title('Résultats de la simulation ab-initio')

plt.tight_layout()

# Données de l'énergie
x = range(N)
y = energies[:N]

# Données 3D
data=[]
lines=[]
colors=['r', 'r', 'silver','silver', 'silver', 'silver', 'silver'] #couleur des atomes
for i in range(dataset.shape[1]):
    coord=dataset[:, i][:N]
    X=coord[:, 1]
    Y=coord[:, 2]
    Z=coord[:, 3]
    data.append(transform_data(X, Y, Z))
    
    lines.append(ax.plot(data[0][0,0:1], data[0][1,0:1], data[0][2,0:1], 'o', color=colors[i])[0])

# Objet d'animation
ani = animation.FuncAnimation(fig, update_both, len(X), fargs=(data, lines),
                              interval=100, blit=False)

# ani.save('ab-initio.mp4')
plt.show()

# %% [markdown]
# Deuxième option pour tracer les postions :

# %%
nv.show_mdtraj(mdt.load_xyz("new_positions_sparse.xyz", top='zundel.pdb'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-04b2ae6e4ffc> in <module>
# ----> 1 nv.show_mdtraj(mdt.load_xyz("new_positions_sparse.xyz", top='zundel.pdb'))
#
# ~\anaconda3\lib\site-packages\mdtraj\formats\xyzfile.py in load_xyz(filename, top, stride, atom_indices, frame)
#     101                         'you supplied %s'.format(type(filename)))
#     102
# --> 103     topology = _parse_topology(top)
#     104     atom_indices = cast_indices(atom_indices)
#     105
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in _parse_topology(top, **kwargs)
#     172         topology = top.topology
#     173     elif isinstance(top, (string_types, os.PathLike)) and (ext in ['.pdb', '.pdb.gz', '.h5','.lh5']):
# --> 174         _traj = load_frame(top, 0, **kwargs)
#     175         topology = _traj.topology
#     176     elif isinstance(top, (string_types, os.PathLike)) and (ext in ['.prmtop', '.parm7', '.prm7']):
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in load_frame(filename, index, top, atom_indices, **kwargs)
#     308
#     309     if loader.__name__ not in ['load_dtr']:
# --> 310         _assert_files_exist(filename)
#     311     else:
#     312         _assert_files_or_dirs_exist(filename)
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in _assert_files_exist(filenames)
#      98     for fn in filenames:
#      99         if not (os.path.exists(fn) and os.path.isfile(fn)):
# --> 100             raise IOError('No such file: %s' % fn)
#     101
#     102
#
# OSError: No such file: zundel.pdb

# %% [markdown]
# ## Séparation des données ##

# %%
#Séparation des données
print("data shape :", dataset.shape)
print("target shape :", energies.shape)
X_train, X_test, y_train, y_test=train_test_split(dataset, energies, random_state=22)

#Scaling des y
yscaler=StandardScaler()
y_train=yscaler.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test=yscaler.fit_transform(y_test.to_numpy().reshape(-1, 1))
# Out:
# data shape : (10000, 7, 4)
# target shape : (10000,)

# %% [markdown]
# # Descripteurs #
#
# ## Descripteurs géometriques ##

# %%
import seaborn as sns
sns.set_style("white")
#Coordonées spatiales pour chaque atome
O1=dataset[:,0,1:4]
O2=dataset[:,1,1:4]
H=dataset[:,2,1:4]
H11=dataset[:,5,1:4]
H12=dataset[:,6,1:4]
H21=dataset[:,3,1:4]
H22=dataset[:,4,1:4]

#Calcul des Coordonnées vectorielles des atomes 
O2_O1=O1-O2
O2_H=H-O2
O1_H=H-O1
O1_H11=H11-O1
O1_H12=H12-O1
O2_H21=H21-O2
O2_H22=H22-O2

#calcul des distances et angles interessants
dO_O=np.linalg.norm(O2_O1,axis=1)
dO1_H=np.linalg.norm(O1_H,axis=1)
dO2_H=np.linalg.norm(O2_H,axis=1)

H22_O2_H21 = vg.angle(O2_H21,O2_H22)
H21_O1_H11 = vg.angle(O1_H11,O1_H12)

# Plot
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(dO_O), color="blue", **kwargs)
plt.vlines(dO_O.mean(),0,7,color="red", label="moyenne")
plt.vlines(dO_O.mean()+dO_O.std(),0,7, label="ecart type",color="k")
plt.vlines(dO_O.mean()-dO_O.std(),0,7, color="k")
print("dO_O moyen :",dO_O.mean()," +- ",dO_O.std())

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")

plt.title("Distribution des distances O-O")
plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO_O,energies,s=0.3,marker='.')
plt.vlines(dO_O.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(dO_O.mean()+dO_O.std(),0,0.007, label="ecart type",color="k")
plt.vlines(dO_O.mean()-dO_O.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()


plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(dO1_H), color="orange", label="Premier O", **kwargs)
sns.distplot(pd.DataFrame(dO2_H), color="blue", label="Deuxieme O", **kwargs)
plt.vlines(dO1_H.mean(),0,3,color="red", label="moyenne")
plt.vlines(dO1_H.mean()+dO1_H.std(),0,3, label="ecart type",color="k")
plt.vlines(dO1_H.mean()-dO1_H.std(),0,3, color="k")
print("dO1_H moyen :",dO1_H.mean()," +- ",dO1_H.std())

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")

plt.title("Distribution des distances O-H pour l'hydrogene central")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO1_H,energies,s=0.3)
plt.vlines(dO1_H.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(dO1_H.mean()+dO1_H.std(),0,0.007, label="ecart type",color="k")
plt.vlines(dO1_H.mean()-dO1_H.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(H22_O2_H21), color="orange", label="Premier H2O", **kwargs)
sns.distplot(pd.DataFrame(H21_O1_H11), color="blue", label="Deuxieme H2O", **kwargs)
plt.vlines(H22_O2_H21.mean(),0,0.15,color="red", label="moyenne")
plt.vlines(H22_O2_H21.mean()+H22_O2_H21.std(),0,0.15, label="ecart type",color="k")
plt.vlines(H22_O2_H21.mean()-H22_O2_H21.std(),0,0.15, color="k")
print("H22_O2_H21 moyen :",H22_O2_H21.mean()," +- ",H22_O2_H21.std())

plt.xlabel(r'Angle $[degres]$')
plt.ylabel("Densité")

plt.title("Distribution des angles O-H-O pour les molecules d'eau")
plt.legend()

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(H22_O2_H21,energies,s=0.3,marker='.')
plt.vlines(H22_O2_H21.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(H22_O2_H21.mean()+H22_O2_H21.std(),0,0.007, label="ecart type",color="k")
plt.vlines(H22_O2_H21.mean()-H22_O2_H21.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Angle [degres]')
plt.ylabel("Energie [u.a]")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# dO_O moyen : 4.53007034788335  +-  0.05661715866559092
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# dO1_H moyen : 2.27340180914684  +-  0.12949155504015944
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# H22_O2_H21 moyen : 108.90639931766596  +-  2.813481373777933

# %% [markdown]
# ## Permutation Invariant Vector (PIV) ##

# %%
#Fonction de switch (voir dans le rapport) de type Fermi-Dirac
def C(rmin, rmax, x): 
    a=20/(rmax-rmin) #pente pour la bijection (rmin, rmax) => (-10, 10)

    bij=a*x+10-a*rmax #bijection (modèle affine)
    y=1/(np.exp(0.3*bij)+1) #calcul de la valeur de la fonction de switch
    return y

#Descripteur PIV
# X : dataset d'entrée
# pca_d : nombre de composantes conservées lors de la pca
# label : label pour le plot retourné
def PIV_descr(X, pca_d=10, label='label'):
    piv=[]
    for i in range(len(X)): #pour chaque configuration
        dist=distance.cdist(X[i][:, 1:], X[i][:, 1:], 'euclidean') #calcul de la distance entre chaque paire d'atomes
        
        #décomposition de la matrice obtenue par type d'interactions (O-O, O-H, H-H)
        a=np.array([dist[0, 1]]) #interaction O-O
        b=np.concatenate((dist[0, 2:],dist[1, 2:])) #interaction O-H
        c=[] #interaction H-H
        for i in range(2, dist.shape[0]):
            c=np.concatenate((c, dist[i, i+1:]))
        
        brmin=np.min(b)
        brmax=np.max(b)
        
        crmin=np.min(c)
        crmax=np.max(c)
        
        #evaluation de la fonction de switch
        aswitched=C(brmin, brmax, a)
        bswitched=C(brmin, brmax, b)
        cswitched=C(crmin, crmax, c)
        
        #tri des valeurs par ordre ascendant dans chaque bloc
        bs=np.sort(bswitched)
        cs=np.sort(cswitched)
        
        #création du vecteur par concaténation
        piv.append(np.concatenate((aswitched, bs, cs)))
        
    #PCA sur le vecteur obtenu
    data_2d = np.array([features_2d.flatten() for features_2d in piv])
    pca = PCA(n_components=pca_d)
    pca.fit(data_2d)
    piv_pca = pca.transform(data_2d)
    print("original shape:   ", piv_pca.shape) 
    print("transformed shape:", piv_pca.shape)
    
    plt.plot(np.cumsum(pca.explained_variance_ratio_), linestyle='--', marker='o', label=label)
    plt.xlabel("Nombre de composantes")
    plt.ylabel('Variance totale expliquée')
    return piv_pca

# %% [markdown]
# **Création et scaling des descripteurs**

# %%
scaler=StandardScaler()

X_train_PIV=PIV_descr(X_train, label="données d'entraînement")
X_train_PIV_red=scaler.fit_transform(X_train_PIV)
X_test_PIV=PIV_descr(X_test, label="données de test")
X_test_PIV_red=scaler.fit_transform(X_test_PIV)
plt.legend()
# Out:
# original shape:    (7500, 10)
# transformed shape: (7500, 10)
# original shape:    (2500, 10)
# transformed shape: (2500, 10)

# %% [markdown]
# ## Matrices de Coulomb ##

# %%
#Fonction pour la création de la matrice de Coulomb à partir d'un dataset
def create_CM(data):
    cm = CoulombMatrix(n_atoms_max=7) #matrice de Coulomb de dimensions 7
    zundel_steps=[]
    for i in range(data.shape[0]): #on ajoute chaque configuration
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %% [markdown]
# ## **Exploration statistique des matrices de Coulomb**. ##

# %%
#création des matrices de Coulomb pour les données d'entrainement
X_train_CM=create_CM(X_train)
X_test_CM=create_CM(X_test)

#scaling des données (centrées réduites)
scaler=StandardScaler()
X_train_CM_red=scaler.fit_transform(X_train_CM)
X_test_CM_red=scaler.fit_transform(X_test_CM)

#conversion dans un Dataset pour explorer les données statistiquement avec les outils pandas
X_train_DF=pd.DataFrame(X_train_CM)

stat=X_train_DF.describe()

statnp=stat.to_numpy().reshape(8, 7, 7)

#Plot des stats sous forme de matrice colorée
for i, l in enumerate(stat.index):
    plt.matshow(statnp[i], cmap="plasma")
    for (x, y), value in np.ndenumerate(statnp[i]):
        plt.text(x, y, f"{value:.2f}", va="center", ha="center", color="white")
    plt.title(l)

# %% [markdown]
# Exemple de matrice de Coulomb :

# %%
plt.matshow(create_CM(X_train)[0].reshape(7, 7), cmap="YlGnBu")

for (x, y), value in np.ndenumerate(create_CM(X_train)[0].reshape(7, 7)):
    plt.text(x, y, f"{value:.3f}", va="center", ha="center", color="red")
    
plt.title("Exemple de matrice de Coulomb")
# Out:
# Text(0.5, 1.0, 'Exemple de matrice de Coulomb')

# %% [markdown]
# ## Matrices de Coulomb version Eigenspectrum ##

# %%
#même fonction que précédemment mais en ne retenant que les valeurs propres
def create_CM_eigen(data):
    cm = CoulombMatrix(n_atoms_max=7, permutation='eigenspectrum')
    zundel_steps=[]
    for i in range(data.shape[0]):
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %% [markdown]
# **Création et scaling des descripteurs**

# %%
X_train_CMe=create_CM_eigen(X_train)
X_test_CMe=create_CM_eigen(X_test)
X_train_CMe_red=scaler.fit_transform(X_train_CMe)
X_test_CMe_red=scaler.fit_transform(X_test_CMe)

# %% [markdown]
# ### **Exploration statistique du nouveau descripteur**

# %%
pd.DataFrame(X_train_CMe).describe()
# Out:
#                  0            1            2            3            4  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     88.701505    59.682468     0.417565     0.242826     0.173534
# std       0.183102     0.177838     0.009194     0.006553     0.004729
# min      87.977655    58.979104     0.388062     0.219960     0.157364
# 25%      88.582326    59.559842     0.411327     0.238478     0.170198
# 50%      88.705274    59.678830     0.417490     0.242890     0.173346
# 75%      88.827863    59.797708     0.423616     0.247244     0.176679
# max      89.435804    60.383806     0.453386     0.267795     0.194823
#
#                  5            6
# count  7500.000000  7500.000000
# mean      0.162842     0.152649
# std       0.004301     0.005124
# min       0.143278     0.131788
# 25%       0.159958     0.149336
# 50%       0.162958     0.152911
# 75%       0.165817     0.156172
# max       0.178765     0.169214

# %%
#plot des corrélations

sns.pairplot(pd.DataFrame(X_train_CMe_red), corner=True)

# %% [markdown]
# ## SOAP ##

# %%
from dscribe.descriptors import SOAP
from ase.io import read
from sklearn.decomposition import PCA
from dscribe.kernels import AverageKernel

#genere un ensemble de vecteurs soap avec PCA
def SOAP_Vectors(xyz_filename,cutoff=5., n_max=6, l_max=6, zeta=2.0, atom_sigma=0.5, pca_d=25):
    # read the xyz file
    frames = read(xyz_filename, ':')
    n_frames = len(frames)

    # species and PBC
    global_species = []
    for frame in frames:
        global_species.extend(frame.get_atomic_numbers())
        frame.set_pbc(True)
    global_species = np.unique(global_species)
    print("loaded xyz file: {fn}, with {n_frames} frames and elements: {ele}".format(fn=xyz_filename, n_frames=n_frames,
                                                                                     ele=global_species))
    # soap
    desc = SOAP(rcut=cutoff, nmax=n_max, lmax=l_max, sigma=atom_sigma, species=global_species, periodic=False,
                average="off")
    soap_vectors = desc.create(frames)
    data_2d = np.array([features_2d.flatten() for features_2d in soap_vectors])
    pca = PCA(n_components=pca_d)
    pca.fit(data_2d)
    Soap_pca = pca.transform(data_2d)
    return Soap_pca,pca

#genere un ensemble de vecteurs soap avec une PCA deja entrainée pour une unique configuration atomique 
def SOAP_Vector(xyz_filename, pca,cutoff=5., n_max=6, l_max=6, zeta=2.0,atom_sigma=0.5):
    # read the xyz file
    frames = read(xyz_filename, ':')
    # species and PBC
    global_species = []
    for frame in frames:
        global_species.extend(frame.get_atomic_numbers())
        frame.set_pbc(True)
    global_species = np.unique(global_species)
    # soap
    desc = SOAP(rcut=cutoff, nmax=n_max, lmax=l_max, sigma=atom_sigma, species=global_species, periodic=False,average="off")
    soap_vectors = desc.create(frames)
    data_2d = np.array([soap_vectors.flatten()]).reshape(1, -1)
    Soap_pca = pca.transform(data_2d)

    return Soap_pca

# %% [markdown]
# **Séparation des données et création des descripteurs**

# %%
Soap_pca,pca=SOAP_Vectors("new_positions_sparse.xyz", cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca_d=15)
# Out:
# loaded xyz file: new_positions_sparse.xyz, with 10000 frames and elements: [1 8]

# %%
X_train_soap, X_test_soap, y_train, y_test=train_test_split(Soap_pca, energies, random_state=22)

X_train_soap_red=scaler.fit_transform(X_train_soap)
X_test_soap_red=scaler.fit_transform(X_test_soap)

yscaler=StandardScaler()
y_train=yscaler.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test=yscaler.fit_transform(y_test.to_numpy().reshape(-1, 1))

# %%
#Plot de la variance totale expliquée
plt.plot(np.cumsum(pca.explained_variance_ratio_), linestyle='--', marker='o')
plt.xlabel("Nombre de composantes")
plt.ylabel('Variance totale expliquée')
# Out:
# Text(0, 0.5, 'Variance totale expliquée')

# %% [markdown]
# # Modèles et apprentissage #
#
# ## **Prédicteur naif** ##

# %%
#retourne la valeur moyenne
def naive_predictor(xtrain, ytrain):
    return np.ones((xtrain.shape[0],))*ytrain.mean()

#résultats du modèle naïf (ici on peut utiliser n'importe quel descripteur)
y_fit=naive_predictor(X_train, y_train)
y_pred_test=naive_predictor(X_test,y_train)

#erreur quadratique moyenne
mse=mean_squared_error(np.array(y_train), y_fit)
mse_test=mean_squared_error(np.array(y_test), y_pred_test)

print("Erreur quadratique moyenne sur les données d'entraînement : ", mse)
print("Erreur quadratique moyenne sur les données de test : ",mse_test)
# Out:
# Erreur quadratique moyenne sur les données d'entraînement :  1.0
# Erreur quadratique moyenne sur les données de test :  1.0

# %% [markdown]
# Plot des y_test en fonction de y_pred

# %%
fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')

#on récupère les limites du plot
xmin, xmax=plt.xlim()
ymin, ymax=plt.ylim()

#ligne du prédicteur idéal
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Modèle naïf")

plt.show()

# %% [markdown]
# ## **Modèle linéaire** ##

# %% [markdown]
# ### Modèle de regession Ridge avec recherche sur grille ###

# %%
#Test avec Matrices de Coulomb

#paramètres testés
a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_CMe_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("MSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_CMe_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print("MSE sur les données de test : ", mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# MSE moyen: 0.7911226116852111
# MSE sur les données de test :  0.7564859632709957

# %%
#Test avec PIV 
from sklearn.linear_model import RidgeCV

a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_PIV_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("MSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_PIV_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print("MSE sur les données de test : ", mse_test_rcv)
# Out:
# Best regularization parameter : 28.278179796253383
# MSE moyen: 0.732613775574381
# MSE sur les données de test :  0.7119053592975245

# %% [markdown]
# ### Modèle linéaire en dimension augmentée (polynomial Features) ###

# %%
mse_list=[] #liste qui stocke la mse pour le train set
mse_test_list=[] #idem pour le test set
for d in range(1,5): #on teste des degrés de 1 à 5
    poly=PolynomialFeatures(degree=d)
    Zmodif=poly.fit_transform(X_train_CMe_red)
    Zmodif_test=poly.fit_transform(X_test_CMe_red)
    
    #recherche sur grille
    a=np.logspace(-10, 10, 1000)
    model=RidgeCV(alphas=a)
    model.fit(Zmodif, y_train)

    print("Best regularization parameter :", model.alpha_)
    print("MSE moyen:", -model.best_score_)

    y_pred_test_rcv=model.predict(Zmodif_test)
    mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
    print("MSE sur le set de test :", mse_test_rcv)
    
    #stockage des meilleurs scores
    mse_list.append(-model.best_score_)
    mse_test_list.append(mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# MSE moyen: 0.7911226116852113
# MSE sur le set de test : 0.7564859632710083
# Best regularization parameter : 14.162866162991973
# MSE moyen: 0.5399559357654161
# MSE sur le set de test : 0.5213666113616616
# Best regularization parameter : 17.030650292528428
# MSE moyen: 0.5402247037401428
# MSE sur le set de test : 0.5217424378170666
# Best regularization parameter : 42.818517986524064
# MSE moyen: 0.5518063896545434
# MSE sur le set de test : 0.5342317688277887

# %%
#plot des résultats
plt.plot([1]*len(mse_list), label='modèle naif')
plt.plot(mse_list, label="train")
plt.plot(mse_test_list, label='test')
plt.legend()
plt.ylabel("MSE")
plt.xlabel("Dimension du polynome")
# Out:
# Text(0.5, 0, 'Dimension du polynome')

# %% [markdown]
# ## Kernel Ridge Regression - Recherche sur grille ##

# %% [markdown]
# ### PIV ###

# %%
krrPIV = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-13, -10,4),
                                                                          "gamma": np.logspace(-7, -5, 4)})
krrPIV.fit(X_train_PIV_red, y_train)

y_pred_test_krr_PIV=krrPIV.predict(X_test_PIV_red)

mse_test_PIV=mean_squared_error(np.array(y_test), y_pred_test_krr_PIV)
b_params_PIV=krrPIV.best_params_
print("MSE : ", mse_test_PIV)
print("Meilleurs paramètres : ",b_params_PIV)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.61249e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.39347e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.7956e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.45434e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.49664e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.14858e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.72041e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.69082e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.62524e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.6978e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.11276e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.32367e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.19066e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.1112e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.64981e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.80074e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.34146e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.22326e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.30182e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.29078e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.35706e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.39553e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.06838e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.30292e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.51232e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.77702e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.81284e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.07641e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.38245e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.58798e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.44955e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.91841e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.96075e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.75221e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.37338e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.56379e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.48333e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.50641e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.5629e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.82479e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.57123e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.61236e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.69595e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.59175e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.41595e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.46602e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.07987e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.34952e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.56067e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.38148e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.7332e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# MSE :  0.5844247340118286
# Meilleurs paramètres :  {'alpha': 1e-10, 'gamma': 1e-05}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_PIV=krrPIV.predict(X_test_PIV_red)
plt.scatter(y_pred_test_krr_PIV,  y_test, marker='.', color='purple',alpha=0.3)
mse_test_PIV=mean_squared_error(np.array(y_test), y_pred_test_krr_PIV)
print(mse_test_PIV)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("PIV")
plt.show()
print(X_train_PIV_red.shape)
# Out:
# 0.5844247340118286
# (7500, 10)

# %% [markdown]
# ### Coulomb Matrix ###

# %%
krrcm = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-11, -10,4),
                                                                          "gamma": np.logspace(-5, -3,4)})
krrcm.fit(X_train_CM_red, y_train)

y_pred_test_krr_cm=krrcm.predict(X_test_CM_red)

mse_test_cm=mean_squared_error(np.array(y_test), y_pred_test_krr_cm)
b_params_cm=krrcm.best_params_
print("MSE : ", mse_test_cm)
print("Meilleurs paramètres : ",b_params_cm)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.08106e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.09593e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.09094e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.06055e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.88952e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.33993e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.73668e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.69697e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.65629e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.75428e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# MSE :  0.9167550999982191
# Meilleurs paramètres :  {'alpha': 4.641588833612773e-11, 'gamma': 0.001}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_cm=krrcm.predict(X_test_CM_red)
plt.scatter(y_pred_test_krr_cm,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.title("Coulomb Matrix (l2 sorted)")
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.show()

# %% [markdown]
# ### Coulomb Matrix Eigenvalues ###

# %%
krrcmeig = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-10, -9,4),
                                                                          "gamma": np.logspace(-5, -4,4)})
krrcmeig.fit(X_train_CMe_red, y_train)

y_pred_test_krr_cmeig=krrcmeig.predict(X_test_CMe_red)

mse_test_cmeig=mean_squared_error(np.array(y_test), y_pred_test_krr_cmeig)
b_params_cmeig=krrcmeig.best_params_
print("MSE : ", mse_test_cmeig)
print("Meilleurs paramètres : ",b_params_cmeig)
# Out:
# MSE :  0.5208115911258475
# Meilleurs paramètres :  {'alpha': 2.1544346900318867e-10, 'gamma': 1e-05}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_cmeig=krrcmeig.predict(X_test_CMe_red)
plt.scatter(y_pred_test_krr_cmeig,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Coulomb Matrix (Eigenvalues)")
plt.show()

# %% [markdown]
# ### Comparaison CM/PIV ###

# %%
#tirer des points au hasard dans le dataset et créer les descripteurs PIV et CMeig associés et retourner la valeur de la prediction
def random(dataset, energies, PIV, CMeig, N):
    idx=np.random.randint(len(dataset), size=N) #index tirés au hasard
    y_pred_PIV=krrPIV.predict(PIV[idx])
    y_pred_cmeig=krrcmeig.predict(CMeig[idx])
    
    return energies[idx], y_pred_PIV, y_pred_cmeig
    
ysample, PIVsample, CMeigsample = random(X_test, y_test, X_test_PIV_red, X_test_CMe_red, 15)

# %%
#Plot des points tirés au hasard

fig=plt.figure(figsize=(11, 5))
plt.subplot(1, 2, 1)
plt.xlabel('$y_{pred}$', fontsize=15)
plt.ylabel('$y_{test}$', fontsize=15)
colors = plt.cm.jet(np.linspace(0, 1, len(ysample)))
plt.scatter(y_pred_test_krr_PIV,  y_test, marker='.', color='purple',alpha=0.3)
plt.scatter(PIVsample, ysample, marker='.', color=colors,alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("PIV")

plt.subplot(1, 2, 2)
plt.scatter(y_pred_test_krr_cmeig,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$', fontsize=15)
plt.ylabel('$y_{test}$', fontsize=15)
plt.scatter(CMeigsample, ysample, marker='.', color=colors,alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Coulomb Matrix (Eigenvalues)")
plt.show()

# %%
# plot y_CM en fct de y_PIV + 10 points en cyan tirés au hasard

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test_krr_cmeig,  y_pred_test_krr_PIV, marker='.', color='purple',alpha=0.2)
plt.scatter(CMeigsample, PIVsample, marker='.', color='cyan',alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')

plt.xlabel('$y_{CM}$', fontsize=15)
plt.ylabel('$y_{PIV}$', fontsize=15)
#plt.scatter(CMeigsample, ysample, marker='.', color=colors,alpha=1)

plt.title("Prédictions PIV vs CM (eigenvalues)")
plt.show()

# %%
#histogramme des distances entre les deux modèles

sns.distplot(pd.DataFrame((PIVsample-CMeigsample)), color="blue")
plt.xlabel(r'Distance $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des distances")
plt.show()

print("Ecart type : ", np.std(pd.DataFrame((PIVsample-CMeigsample))))
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Ecart type :  0    0.475148
# dtype: float64

# %% [markdown]
# ### SOAP ###

# %%
krrsoap = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-11.5, -10.5,4),
                                                                          "gamma": np.logspace(-7,-5,6)})
krrsoap.fit(X_train_soap_red, y_train)

y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)

mse_test_soap=mean_squared_error(np.array(y_test), y_pred_test_krr_soap)
b_params_soap=krrsoap.best_params_
print("MSE : ", mse_test_soap)
print(b_params_soap)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.27127e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.73018e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.11427e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.09831e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.52251e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.43107e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.34419e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.06368e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.51323e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.38767e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.90864e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.45758e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.83591e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.90354e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.42162e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.35824e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.6703e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.27681e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.64915e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.70308e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.07355e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.13475e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.03866e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.11108e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.11447e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.88321e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.46237e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.47033e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.41489e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.42996e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.11408e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.38602e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.08714e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.2605e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.2296e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.55883e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.62699e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.62771e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.60441e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.03591e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.38032e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.54785e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05774e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.15445e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.31334e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.69578e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.55394e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.52317e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.66501e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.02023e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.90042e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.98437e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.77247e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.94486e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.99997e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.68457e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.50085e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.74825e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.5512e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.47989e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.60461e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# MSE :  0.1913298981485932
# {'alpha': 6.8129206905796225e-12, 'gamma': 3.981071705534969e-06}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)
plt.scatter(y_pred_test_krr_soap,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("SOAP")
plt.show()

# %% [markdown]
# ## **Réseau de neurones** ##

# %%
#on renomme les variables
X_soap_red=X_train_soap_red
y_soap=y_train

#création du modèle
model=Sequential()
model.add(Dense(units=15, activation='tanh', input_shape=(15,)))
model.add(Dense(units=12, activation='tanh'))
model.add(Dense(units=1))
model.summary()

model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])

Hist=model.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist.history['loss'][1:])
plt.plot(Hist.history['val_loss'][1:])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                240
#
#  dense_1 (Dense)             (None, 12)                192
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 445
# Trainable params: 445
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 1s 4ms/step - loss: 1.1701 - mean_squared_error: 1.1701 - val_loss: 0.8104 - val_mean_squared_error: 0.8104
# Epoch 2/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8067 - mean_squared_error: 0.8067 - val_loss: 0.7234 - val_mean_squared_error: 0.7234
# Epoch 3/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7677 - mean_squared_error: 0.7677 - val_loss: 0.7098 - val_mean_squared_error: 0.7098
# Epoch 4/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7527 - mean_squared_error: 0.7527 - val_loss: 0.6938 - val_mean_squared_error: 0.6938
# Epoch 5/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7369 - mean_squared_error: 0.7369 - val_loss: 0.6820 - val_mean_squared_error: 0.6820
# Epoch 6/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7226 - mean_squared_error: 0.7226 - val_loss: 0.6739 - val_mean_squared_error: 0.6739
# Epoch 7/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7088 - mean_squared_error: 0.7088 - val_loss: 0.6596 - val_mean_squared_error: 0.6596
# Epoch 8/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6932 - mean_squared_error: 0.6932 - val_loss: 0.6486 - val_mean_squared_error: 0.6486
# Epoch 9/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6790 - mean_squared_error: 0.6790 - val_loss: 0.6354 - val_mean_squared_error: 0.6354
# Epoch 10/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6623 - mean_squared_error: 0.6623 - val_loss: 0.6185 - val_mean_squared_error: 0.6185
# Epoch 11/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6438 - mean_squared_error: 0.6438 - val_loss: 0.6097 - val_mean_squared_error: 0.6097
# Epoch 12/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6261 - mean_squared_error: 0.6261 - val_loss: 0.5956 - val_mean_squared_error: 0.5956
# Epoch 13/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.6074 - mean_squared_error: 0.6074 - val_loss: 0.5775 - val_mean_squared_error: 0.5775
# Epoch 14/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5878 - mean_squared_error: 0.5878 - val_loss: 0.5650 - val_mean_squared_error: 0.5650
# Epoch 15/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5676 - mean_squared_error: 0.5676 - val_loss: 0.5525 - val_mean_squared_error: 0.5525
# Epoch 16/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5491 - mean_squared_error: 0.5491 - val_loss: 0.5402 - val_mean_squared_error: 0.5402
# Epoch 17/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5292 - mean_squared_error: 0.5292 - val_loss: 0.5192 - val_mean_squared_error: 0.5192
# Epoch 18/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5096 - mean_squared_error: 0.5096 - val_loss: 0.5089 - val_mean_squared_error: 0.5089
# Epoch 19/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4900 - mean_squared_error: 0.4900 - val_loss: 0.4981 - val_mean_squared_error: 0.4981
# Epoch 20/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4744 - mean_squared_error: 0.4744 - val_loss: 0.4832 - val_mean_squared_error: 0.4832
# Epoch 21/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4565 - mean_squared_error: 0.4565 - val_loss: 0.4671 - val_mean_squared_error: 0.4671
# Epoch 22/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4398 - mean_squared_error: 0.4398 - val_loss: 0.4516 - val_mean_squared_error: 0.4516
# Epoch 23/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4245 - mean_squared_error: 0.4245 - val_loss: 0.4404 - val_mean_squared_error: 0.4404
# Epoch 24/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4111 - mean_squared_error: 0.4111 - val_loss: 0.4255 - val_mean_squared_error: 0.4255
# Epoch 25/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3949 - mean_squared_error: 0.3949 - val_loss: 0.4115 - val_mean_squared_error: 0.4115
# Epoch 26/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.4015 - val_mean_squared_error: 0.4015
# Epoch 27/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3684 - mean_squared_error: 0.3684 - val_loss: 0.3881 - val_mean_squared_error: 0.3881
# Epoch 28/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3547 - mean_squared_error: 0.3547 - val_loss: 0.3756 - val_mean_squared_error: 0.3756
# Epoch 29/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3420 - mean_squared_error: 0.3420 - val_loss: 0.3660 - val_mean_squared_error: 0.3660
# Epoch 30/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3307 - mean_squared_error: 0.3307 - val_loss: 0.3563 - val_mean_squared_error: 0.3563
# Epoch 31/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3193 - mean_squared_error: 0.3193 - val_loss: 0.3414 - val_mean_squared_error: 0.3414
# Epoch 32/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3080 - mean_squared_error: 0.3080 - val_loss: 0.3363 - val_mean_squared_error: 0.3363
# Epoch 33/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2980 - mean_squared_error: 0.2980 - val_loss: 0.3284 - val_mean_squared_error: 0.3284
# Epoch 34/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2919 - mean_squared_error: 0.2919 - val_loss: 0.3243 - val_mean_squared_error: 0.3243
# Epoch 35/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2844 - mean_squared_error: 0.2844 - val_loss: 0.3153 - val_mean_squared_error: 0.3153
# Epoch 36/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2765 - mean_squared_error: 0.2765 - val_loss: 0.3117 - val_mean_squared_error: 0.3117
# Epoch 37/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2706 - mean_squared_error: 0.2706 - val_loss: 0.3041 - val_mean_squared_error: 0.3041
# Epoch 38/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2660 - mean_squared_error: 0.2660 - val_loss: 0.2968 - val_mean_squared_error: 0.2968
# Epoch 39/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2618 - mean_squared_error: 0.2618 - val_loss: 0.2901 - val_mean_squared_error: 0.2901
# Epoch 40/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2557 - mean_squared_error: 0.2557 - val_loss: 0.2915 - val_mean_squared_error: 0.2915
# Epoch 41/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2537 - mean_squared_error: 0.2537 - val_loss: 0.2836 - val_mean_squared_error: 0.2836
# Epoch 42/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2512 - mean_squared_error: 0.2512 - val_loss: 0.2846 - val_mean_squared_error: 0.2846
# Epoch 43/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2468 - mean_squared_error: 0.2468 - val_loss: 0.2830 - val_mean_squared_error: 0.2830
# Epoch 44/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2428 - mean_squared_error: 0.2428 - val_loss: 0.2718 - val_mean_squared_error: 0.2718
# Epoch 45/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2696 - val_mean_squared_error: 0.2696
# Epoch 46/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2408 - mean_squared_error: 0.2408 - val_loss: 0.2766 - val_mean_squared_error: 0.2766
# Epoch 47/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2364 - mean_squared_error: 0.2364 - val_loss: 0.2749 - val_mean_squared_error: 0.2749
# Epoch 48/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 0.2731 - val_mean_squared_error: 0.2731
# Epoch 49/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2344 - mean_squared_error: 0.2344 - val_loss: 0.2664 - val_mean_squared_error: 0.2664
# Epoch 50/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2040 - mean_squared_error: 0.2040 - val_loss: 0.2413 - val_mean_squared_error: 0.2413
# Epoch 106/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2037 - mean_squared_error: 0.2037 - val_loss: 0.2404 - val_mean_squared_error: 0.2404
# Epoch 107/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2029 - mean_squared_error: 0.2029 - val_loss: 0.2385 - val_mean_squared_error: 0.2385
# Epoch 108/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2032 - mean_squared_error: 0.2032 - val_loss: 0.2368 - val_mean_squared_error: 0.2368
# Epoch 109/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2021 - mean_squared_error: 0.2021 - val_loss: 0.2421 - val_mean_squared_error: 0.2421
# Epoch 110/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2032 - mean_squared_error: 0.2032 - val_loss: 0.2379 - val_mean_squared_error: 0.2379
# Epoch 111/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2017 - mean_squared_error: 0.2017 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Epoch 112/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2025 - mean_squared_error: 0.2025 - val_loss: 0.2457 - val_mean_squared_error: 0.2457
# Epoch 113/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2023 - mean_squared_error: 0.2023 - val_loss: 0.2429 - val_mean_squared_error: 0.2429
# Epoch 114/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2024 - mean_squared_error: 0.2024 - val_loss: 0.2383 - val_mean_squared_error: 0.2383
# Epoch 115/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2017 - mean_squared_error: 0.2017 - val_loss: 0.2409 - val_mean_squared_error: 0.2409
# Epoch 116/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2004 - mean_squared_error: 0.2004 - val_loss: 0.2458 - val_mean_squared_error: 0.2458
# Epoch 117/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2014 - mean_squared_error: 0.2014 - val_loss: 0.2383 - val_mean_squared_error: 0.2383
# Epoch 118/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2003 - mean_squared_error: 0.2003 - val_loss: 0.2398 - val_mean_squared_error: 0.2398
# Epoch 119/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2013 - mean_squared_error: 0.2013 - val_loss: 0.2379 - val_mean_squared_error: 0.2379
# Epoch 120/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2022 - mean_squared_error: 0.2022 - val_loss: 0.2414 - val_mean_squared_error: 0.2414
# Epoch 121/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2001 - mean_squared_error: 0.2001 - val_loss: 0.2421 - val_mean_squared_error: 0.2421
# Epoch 122/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2003 - mean_squared_error: 0.2003 - val_loss: 0.2384 - val_mean_squared_error: 0.2384
# Epoch 123/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2023 - mean_squared_error: 0.2023 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Epoch 124/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1996 - mean_squared_error: 0.1996 - val_loss: 0.2362 - val_mean_squared_error: 0.2362
# Epoch 125/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1992 - mean_squared_error: 0.1992 - val_loss: 0.2394 - val_mean_squared_error: 0.2394
# Epoch 126/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1996 - mean_squared_error: 0.1996 - val_loss: 0.2428 - val_mean_squared_error: 0.2428
# Epoch 127/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2012 - mean_squared_error: 0.2012 - val_loss: 0.2355 - val_mean_squared_error: 0.2355
# Epoch 128/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1995 - mean_squared_error: 0.1995 - val_loss: 0.2382 - val_mean_squared_error: 0.2382
# Epoch 129/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1991 - mean_squared_error: 0.1991 - val_loss: 0.2380 - val_mean_squared_error: 0.2380
# Epoch 130/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1987 - mean_squared_error: 0.1987 - val_loss: 0.2343 - val_mean_squared_error: 0.2343
# Epoch 131/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1983 - mean_squared_error: 0.1983 - val_loss: 0.2436 - val_mean_squared_error: 0.2436
# Epoch 132/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1916 - mean_squared_error: 0.1916 - val_loss: 0.2464 - val_mean_squared_error: 0.2464
# Epoch 216/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1928 - mean_squared_error: 0.1928 - val_loss: 0.2422 - val_mean_squared_error: 0.2422
# Epoch 217/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1909 - mean_squared_error: 0.1909 - val_loss: 0.2357 - val_mean_squared_error: 0.2357
# Epoch 218/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.2367 - val_mean_squared_error: 0.2367
# Epoch 219/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1909 - mean_squared_error: 0.1909 - val_loss: 0.2366 - val_mean_squared_error: 0.2366
# Epoch 220/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.2415 - val_mean_squared_error: 0.2415
# Epoch 221/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1912 - mean_squared_error: 0.1912 - val_loss: 0.2413 - val_mean_squared_error: 0.2413
# Epoch 222/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1931 - mean_squared_error: 0.1931 - val_loss: 0.2349 - val_mean_squared_error: 0.2349
# Epoch 223/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1916 - mean_squared_error: 0.1916 - val_loss: 0.2369 - val_mean_squared_error: 0.2369
# Epoch 224/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1908 - mean_squared_error: 0.1908 - val_loss: 0.2384 - val_mean_squared_error: 0.2384
# Epoch 225/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1912 - mean_squared_error: 0.1912 - val_loss: 0.2344 - val_mean_squared_error: 0.2344
# Epoch 226/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1923 - mean_squared_error: 0.1923 - val_loss: 0.2397 - val_mean_squared_error: 0.2397
# Epoch 227/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1906 - mean_squared_error: 0.1906 - val_loss: 0.2356 - val_mean_squared_error: 0.2356
# Epoch 228/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.2343 - val_mean_squared_error: 0.2343
# Epoch 229/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1907 - mean_squared_error: 0.1907 - val_loss: 0.2349 - val_mean_squared_error: 0.2349
# Epoch 230/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1924 - mean_squared_error: 0.1924 - val_loss: 0.2395 - val_mean_squared_error: 0.2395
# Epoch 231/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1897 - mean_squared_error: 0.1897 - val_loss: 0.2427 - val_mean_squared_error: 0.2427
# Epoch 232/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1900 - mean_squared_error: 0.1900 - val_loss: 0.2400 - val_mean_squared_error: 0.2400
# Epoch 233/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1904 - mean_squared_error: 0.1904 - val_loss: 0.2374 - val_mean_squared_error: 0.2374
# Epoch 234/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1896 - mean_squared_error: 0.1896 - val_loss: 0.2400 - val_mean_squared_error: 0.2400
# Epoch 235/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1914 - mean_squared_error: 0.1914 - val_loss: 0.2379 - val_mean_squared_error: 0.2379
# Epoch 236/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1899 - mean_squared_error: 0.1899 - val_loss: 0.2442 - val_mean_squared_error: 0.2442
# Epoch 237/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1894 - mean_squared_error: 0.1894 - val_loss: 0.2386 - val_mean_squared_error: 0.2386
# Epoch 238/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1899 - mean_squared_error: 0.1899 - val_loss: 0.2375 - val_mean_squared_error: 0.2375
# Epoch 239/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1899 - mean_squared_error: 0.1899 - val_loss: 0.2401 - val_mean_squared_error: 0.2401
# Epoch 240/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.2354 - val_mean_squared_error: 0.2354
# Epoch 241/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1886 - mean_squared_error: 0.1886 - val_loss: 0.2374 - val_mean_squared_error: 0.2374
# Epoch 242/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2399 - val_mean_squared_error: 0.2399
# Epoch 243/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Epoch 244/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2415 - val_mean_squared_error: 0.2415
# Epoch 245/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1895 - mean_squared_error: 0.1895 - val_loss: 0.2357 - val_mean_squared_error: 0.2357
# Epoch 246/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1892 - mean_squared_error: 0.1892 - val_loss: 0.2360 - val_mean_squared_error: 0.2360
# Epoch 247/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2398 - val_mean_squared_error: 0.2398
# Epoch 248/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1899 - mean_squared_error: 0.1899 - val_loss: 0.2399 - val_mean_squared_error: 0.2399
# Epoch 249/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1894 - mean_squared_error: 0.1894 - val_loss: 0.2389 - val_mean_squared_error: 0.2389
# Epoch 250/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1912 - mean_squared_error: 0.1912 - val_loss: 0.2432 - val_mean_squared_error: 0.2432
# Epoch 251/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1892 - mean_squared_error: 0.1892 - val_loss: 0.2405 - val_mean_squared_error: 0.2405
# Epoch 252/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.2379 - val_mean_squared_error: 0.2379
# Epoch 253/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.2403 - val_mean_squared_error: 0.2403
# Epoch 254/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1903 - mean_squared_error: 0.1903 - val_loss: 0.2435 - val_mean_squared_error: 0.2435
# Epoch 255/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1902 - mean_squared_error: 0.1902 - val_loss: 0.2409 - val_mean_squared_error: 0.2409
# Epoch 256/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1883 - mean_squared_error: 0.1883 - val_loss: 0.2413 - val_mean_squared_error: 0.2413
# Epoch 257/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1881 - mean_squared_error: 0.1881 - val_loss: 0.2377 - val_mean_squared_error: 0.2377
# Epoch 258/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.2349 - val_mean_squared_error: 0.2349
# Epoch 259/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.2414 - val_mean_squared_error: 0.2414
# Epoch 260/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2362 - val_mean_squared_error: 0.2362
# Epoch 261/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.2414 - val_mean_squared_error: 0.2414
# Epoch 262/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.2351 - val_mean_squared_error: 0.2351
# Epoch 263/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.2394 - val_mean_squared_error: 0.2394
# Epoch 264/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1886 - mean_squared_error: 0.1886 - val_loss: 0.2440 - val_mean_squared_error: 0.2440
# Epoch 265/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2403 - val_mean_squared_error: 0.2403
# Epoch 266/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1892 - mean_squared_error: 0.1892 - val_loss: 0.2394 - val_mean_squared_error: 0.2394
# Epoch 267/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1895 - mean_squared_error: 0.1895 - val_loss: 0.2372 - val_mean_squared_error: 0.2372
# Epoch 268/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1880 - mean_squared_error: 0.1880 - val_loss: 0.2353 - val_mean_squared_error: 0.2353
# Epoch 269/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1878 - mean_squared_error: 0.1878 - val_loss: 0.2388 - val_mean_squared_error: 0.2388
# Epoch 270/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1899 - mean_squared_error: 0.1899 - val_loss: 0.2330 - val_mean_squared_error: 0.2330
# Epoch 271/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.2428 - val_mean_squared_error: 0.2428
# Epoch 272/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2391 - val_mean_squared_error: 0.2391
# Epoch 273/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1885 - mean_squared_error: 0.1885 - val_loss: 0.2351 - val_mean_squared_error: 0.2351
# Epoch 274/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1875 - mean_squared_error: 0.1875 - val_loss: 0.2459 - val_mean_squared_error: 0.2459
# Epoch 275/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.2382 - val_mean_squared_error: 0.2382
# Epoch 276/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1897 - mean_squared_error: 0.1897 - val_loss: 0.2352 - val_mean_squared_error: 0.2352
# Epoch 277/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.2417 - val_mean_squared_error: 0.2417
# Epoch 278/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.2376 - val_mean_squared_error: 0.2376
# Epoch 279/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1893 - mean_squared_error: 0.1893 - val_loss: 0.2359 - val_mean_squared_error: 0.2359
# Epoch 280/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1879 - mean_squared_error: 0.1879 - val_loss: 0.2374 - val_mean_squared_error: 0.2374
# Epoch 281/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1877 - mean_squared_error: 0.1877 - val_loss: 0.2387 - val_mean_squared_error: 0.2387
# Epoch 282/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.2360 - val_mean_squared_error: 0.2360
# Epoch 283/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1893 - mean_squared_error: 0.1893 - val_loss: 0.2364 - val_mean_squared_error: 0.2364
# Epoch 284/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1875 - mean_squared_error: 0.1875 - val_loss: 0.2431 - val_mean_squared_error: 0.2431
# Epoch 285/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2401 - val_mean_squared_error: 0.2401
# Epoch 286/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1898 - mean_squared_error: 0.1898 - val_loss: 0.2376 - val_mean_squared_error: 0.2376
# Epoch 287/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.2387 - val_mean_squared_error: 0.2387
# Epoch 288/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.2345 - val_mean_squared_error: 0.2345
# Epoch 289/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1896 - mean_squared_error: 0.1896 - val_loss: 0.2427 - val_mean_squared_error: 0.2427
# Epoch 290/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1883 - mean_squared_error: 0.1883 - val_loss: 0.2409 - val_mean_squared_error: 0.2409
# Epoch 291/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1887 - mean_squared_error: 0.1887 - val_loss: 0.2357 - val_mean_squared_error: 0.2357
# Epoch 292/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1882 - mean_squared_error: 0.1882 - val_loss: 0.2385 - val_mean_squared_error: 0.2385
# Epoch 293/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1872 - mean_squared_error: 0.1872 - val_loss: 0.2478 - val_mean_squared_error: 0.2478
# Epoch 294/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1894 - mean_squared_error: 0.1894 - val_loss: 0.2400 - val_mean_squared_error: 0.2400
# Epoch 295/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1881 - mean_squared_error: 0.1881 - val_loss: 0.2393 - val_mean_squared_error: 0.2393
# Epoch 296/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1873 - mean_squared_error: 0.1873 - val_loss: 0.2418 - val_mean_squared_error: 0.2418
# Epoch 297/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1895 - mean_squared_error: 0.1895 - val_loss: 0.2355 - val_mean_squared_error: 0.2355
# Epoch 298/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1883 - mean_squared_error: 0.1883 - val_loss: 0.2407 - val_mean_squared_error: 0.2407
# Epoch 299/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1881 - mean_squared_error: 0.1881 - val_loss: 0.2368 - val_mean_squared_error: 0.2368
# Epoch 300/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1880 - mean_squared_error: 0.1880 - val_loss: 0.2374 - val_mean_squared_error: 0.2374

# %% [markdown]
# ### Modèle régularisé ###

# %%
model_reg=Sequential()
model_reg.add(Dense(units=15, activation='tanh', input_shape=(15,), kernel_regularizer=regularizers.l2(0.06)))

model_reg.add(Dense(units=12, activation='tanh'))
model_reg.add(Dense(units=1))
model_reg.summary()

model_reg.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])
Hist_reg=model_reg.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist_reg.history['loss'][1:])
plt.plot(Hist_reg.history['val_loss'][1:])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 15)                240
#
#  dense_4 (Dense)             (None, 12)                192
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 445
# Trainable params: 445
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 1s 5ms/step - loss: 1.5370 - mean_squared_error: 0.9023 - val_loss: 1.2640 - val_mean_squared_error: 0.7713
# Epoch 2/300
# 94/94 [==============================] - 0s 2ms/step - loss: 1.1749 - mean_squared_error: 0.7844 - val_loss: 1.0078 - val_mean_squared_error: 0.7067
# Epoch 3/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.9929 - mean_squared_error: 0.7538 - val_loss: 0.8737 - val_mean_squared_error: 0.6882
# Epoch 4/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8936 - mean_squared_error: 0.7442 - val_loss: 0.8021 - val_mean_squared_error: 0.6828
# Epoch 5/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8383 - mean_squared_error: 0.7392 - val_loss: 0.7619 - val_mean_squared_error: 0.6806
# Epoch 6/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8053 - mean_squared_error: 0.7355 - val_loss: 0.7335 - val_mean_squared_error: 0.6728
# Epoch 7/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.7856 - mean_squared_error: 0.7314 - val_loss: 0.7195 - val_mean_squared_error: 0.6698
# Epoch 8/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7700 - mean_squared_error: 0.7243 - val_loss: 0.7068 - val_mean_squared_error: 0.6638
# Epoch 9/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7589 - mean_squared_error: 0.7175 - val_loss: 0.6992 - val_mean_squared_error: 0.6594
# Epoch 10/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7472 - mean_squared_error: 0.7082 - val_loss: 0.6875 - val_mean_squared_error: 0.6489
# Epoch 11/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7367 - mean_squared_error: 0.6984 - val_loss: 0.6826 - val_mean_squared_error: 0.6448
# Epoch 12/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7289 - mean_squared_error: 0.6915 - val_loss: 0.6799 - val_mean_squared_error: 0.6423
# Epoch 13/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7208 - mean_squared_error: 0.6834 - val_loss: 0.6763 - val_mean_squared_error: 0.6390
# Epoch 14/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7165 - mean_squared_error: 0.6795 - val_loss: 0.6721 - val_mean_squared_error: 0.6346
# Epoch 15/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7064 - mean_squared_error: 0.6695 - val_loss: 0.6610 - val_mean_squared_error: 0.6236
# Epoch 16/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7005 - mean_squared_error: 0.6638 - val_loss: 0.6570 - val_mean_squared_error: 0.6198
# Epoch 17/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6954 - mean_squared_error: 0.6578 - val_loss: 0.6499 - val_mean_squared_error: 0.6122
# Epoch 18/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6887 - mean_squared_error: 0.6507 - val_loss: 0.6420 - val_mean_squared_error: 0.6041
# Epoch 19/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6808 - mean_squared_error: 0.6419 - val_loss: 0.6428 - val_mean_squared_error: 0.6033
# Epoch 20/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6730 - mean_squared_error: 0.6325 - val_loss: 0.6327 - val_mean_squared_error: 0.5910
# Epoch 21/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6647 - mean_squared_error: 0.6218 - val_loss: 0.6338 - val_mean_squared_error: 0.5896
# Epoch 22/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6553 - mean_squared_error: 0.6098 - val_loss: 0.6188 - val_mean_squared_error: 0.5722
# Epoch 23/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2812 - mean_squared_error: 0.2352 - val_loss: 0.3041 - val_mean_squared_error: 0.2581
# Epoch 162/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2863 - mean_squared_error: 0.2404 - val_loss: 0.3029 - val_mean_squared_error: 0.2570
# Epoch 163/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2847 - mean_squared_error: 0.2390 - val_loss: 0.3056 - val_mean_squared_error: 0.2597
# Epoch 164/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2829 - mean_squared_error: 0.2374 - val_loss: 0.3126 - val_mean_squared_error: 0.2670
# Epoch 165/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2838 - mean_squared_error: 0.2384 - val_loss: 0.3083 - val_mean_squared_error: 0.2629
# Epoch 166/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2834 - mean_squared_error: 0.2381 - val_loss: 0.3221 - val_mean_squared_error: 0.2768
# Epoch 167/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2830 - mean_squared_error: 0.2378 - val_loss: 0.3038 - val_mean_squared_error: 0.2588
# Epoch 168/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2794 - mean_squared_error: 0.2345 - val_loss: 0.2979 - val_mean_squared_error: 0.2530
# Epoch 169/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2812 - mean_squared_error: 0.2364 - val_loss: 0.2958 - val_mean_squared_error: 0.2509
# Epoch 170/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2836 - mean_squared_error: 0.2386 - val_loss: 0.3093 - val_mean_squared_error: 0.2646
# Epoch 171/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2809 - mean_squared_error: 0.2362 - val_loss: 0.3023 - val_mean_squared_error: 0.2578
# Epoch 172/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2796 - mean_squared_error: 0.2351 - val_loss: 0.2976 - val_mean_squared_error: 0.2532
# Epoch 173/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2817 - mean_squared_error: 0.2373 - val_loss: 0.2993 - val_mean_squared_error: 0.2550
# Epoch 174/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2772 - mean_squared_error: 0.2329 - val_loss: 0.3022 - val_mean_squared_error: 0.2580
# Epoch 175/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2788 - mean_squared_error: 0.2346 - val_loss: 0.3011 - val_mean_squared_error: 0.2571
# Epoch 176/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2806 - mean_squared_error: 0.2366 - val_loss: 0.3039 - val_mean_squared_error: 0.2598
# Epoch 177/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2809 - mean_squared_error: 0.2368 - val_loss: 0.2946 - val_mean_squared_error: 0.2507
# Epoch 178/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2794 - mean_squared_error: 0.2358 - val_loss: 0.3049 - val_mean_squared_error: 0.2610
# Epoch 179/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2758 - mean_squared_error: 0.2320 - val_loss: 0.2922 - val_mean_squared_error: 0.2482
# Epoch 180/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2754 - mean_squared_error: 0.2316 - val_loss: 0.2946 - val_mean_squared_error: 0.2510
# Epoch 181/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2752 - mean_squared_error: 0.2317 - val_loss: 0.2899 - val_mean_squared_error: 0.2465
# Epoch 182/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2813 - mean_squared_error: 0.2378 - val_loss: 0.2901 - val_mean_squared_error: 0.2468
# Epoch 183/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2763 - mean_squared_error: 0.2332 - val_loss: 0.2933 - val_mean_squared_error: 0.2502
# Epoch 184/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2779 - mean_squared_error: 0.2347 - val_loss: 0.2943 - val_mean_squared_error: 0.2514
# Epoch 185/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2790 - mean_squared_error: 0.2359 - val_loss: 0.3021 - val_mean_squared_error: 0.2594
# Epoch 186/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2730 - mean_squared_error: 0.2301 - val_loss: 0.2910 - val_mean_squared_error: 0.2482
# Epoch 187/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2790 - mean_squared_error: 0.2362 - val_loss: 0.2941 - val_mean_squared_error: 0.2513
# Epoch 188/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2585 - mean_squared_error: 0.2207 - val_loss: 0.3076 - val_mean_squared_error: 0.2697
# Epoch 299/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2657 - mean_squared_error: 0.2282 - val_loss: 0.2978 - val_mean_squared_error: 0.2600
# Epoch 300/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2618 - mean_squared_error: 0.2240 - val_loss: 0.2853 - val_mean_squared_error: 0.2477

# %% [markdown]
# ### Modèle dropout ###

# %%
model_drop=Sequential()
model_drop.add(Dense(units=15, activation='tanh', input_shape=(15,), kernel_regularizer=regularizers.l2(0.065)))
model.add(Dropout(0.2))
model_drop.add(Dense(units=12, activation='tanh'))
model_drop.add(Dense(units=1))
model_drop.summary()

model_drop.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])
Hist_drop=model_drop.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist_drop.history['loss'][1:])
plt.plot(Hist_drop.history['val_loss'][1:])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 15)                240
#
#  dense_7 (Dense)             (None, 12)                192
#
#  dense_8 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 445
# Trainable params: 445
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 1s 3ms/step - loss: 1.7628 - mean_squared_error: 0.9793 - val_loss: 1.4040 - val_mean_squared_error: 0.7526
# Epoch 2/300
# 94/94 [==============================] - 0s 2ms/step - loss: 1.3163 - mean_squared_error: 0.7761 - val_loss: 1.1487 - val_mean_squared_error: 0.7106
# Epoch 3/300
# 94/94 [==============================] - 0s 2ms/step - loss: 1.1164 - mean_squared_error: 0.7544 - val_loss: 0.9879 - val_mean_squared_error: 0.6929
# Epoch 4/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.9882 - mean_squared_error: 0.7420 - val_loss: 0.8824 - val_mean_squared_error: 0.6791
# Epoch 5/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.9059 - mean_squared_error: 0.7334 - val_loss: 0.8188 - val_mean_squared_error: 0.6743
# Epoch 6/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8525 - mean_squared_error: 0.7274 - val_loss: 0.7758 - val_mean_squared_error: 0.6686
# Epoch 7/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8165 - mean_squared_error: 0.7214 - val_loss: 0.7448 - val_mean_squared_error: 0.6606
# Epoch 8/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7911 - mean_squared_error: 0.7150 - val_loss: 0.7241 - val_mean_squared_error: 0.6545
# Epoch 9/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7734 - mean_squared_error: 0.7085 - val_loss: 0.7100 - val_mean_squared_error: 0.6498
# Epoch 10/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7583 - mean_squared_error: 0.7009 - val_loss: 0.6899 - val_mean_squared_error: 0.6351
# Epoch 11/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7444 - mean_squared_error: 0.6911 - val_loss: 0.6801 - val_mean_squared_error: 0.6279
# Epoch 12/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7325 - mean_squared_error: 0.6809 - val_loss: 0.6742 - val_mean_squared_error: 0.6241
# Epoch 13/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7213 - mean_squared_error: 0.6714 - val_loss: 0.6620 - val_mean_squared_error: 0.6119
# Epoch 14/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7134 - mean_squared_error: 0.6637 - val_loss: 0.6570 - val_mean_squared_error: 0.6078
# Epoch 15/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7021 - mean_squared_error: 0.6527 - val_loss: 0.6509 - val_mean_squared_error: 0.6016
# Epoch 16/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6958 - mean_squared_error: 0.6462 - val_loss: 0.6496 - val_mean_squared_error: 0.6004
# Epoch 17/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6862 - mean_squared_error: 0.6372 - val_loss: 0.6400 - val_mean_squared_error: 0.5906
# Epoch 18/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3187 - mean_squared_error: 0.2642 - val_loss: 0.3479 - val_mean_squared_error: 0.2930
# Epoch 102/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3295 - mean_squared_error: 0.2749 - val_loss: 0.3368 - val_mean_squared_error: 0.2824
# Epoch 103/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3216 - mean_squared_error: 0.2672 - val_loss: 0.3445 - val_mean_squared_error: 0.2899
# Epoch 104/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3149 - mean_squared_error: 0.2605 - val_loss: 0.3251 - val_mean_squared_error: 0.2710
# Epoch 105/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3188 - mean_squared_error: 0.2646 - val_loss: 0.3407 - val_mean_squared_error: 0.2871
# Epoch 106/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3224 - mean_squared_error: 0.2685 - val_loss: 0.3291 - val_mean_squared_error: 0.2750
# Epoch 107/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3180 - mean_squared_error: 0.2642 - val_loss: 0.3288 - val_mean_squared_error: 0.2752
# Epoch 108/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3146 - mean_squared_error: 0.2608 - val_loss: 0.3325 - val_mean_squared_error: 0.2789
# Epoch 109/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3126 - mean_squared_error: 0.2589 - val_loss: 0.3309 - val_mean_squared_error: 0.2772
# Epoch 110/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3168 - mean_squared_error: 0.2630 - val_loss: 0.3393 - val_mean_squared_error: 0.2856
# Epoch 111/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3147 - mean_squared_error: 0.2611 - val_loss: 0.3481 - val_mean_squared_error: 0.2946
# Epoch 112/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3158 - mean_squared_error: 0.2621 - val_loss: 0.3254 - val_mean_squared_error: 0.2720
# Epoch 113/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3134 - mean_squared_error: 0.2599 - val_loss: 0.3201 - val_mean_squared_error: 0.2668
# Epoch 114/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3106 - mean_squared_error: 0.2571 - val_loss: 0.3222 - val_mean_squared_error: 0.2687
# Epoch 115/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3094 - mean_squared_error: 0.2556 - val_loss: 0.3426 - val_mean_squared_error: 0.2888
# Epoch 116/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3098 - mean_squared_error: 0.2561 - val_loss: 0.3319 - val_mean_squared_error: 0.2784
# Epoch 117/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3092 - mean_squared_error: 0.2555 - val_loss: 0.3319 - val_mean_squared_error: 0.2782
# Epoch 118/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3105 - mean_squared_error: 0.2565 - val_loss: 0.3244 - val_mean_squared_error: 0.2704
# Epoch 119/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3101 - mean_squared_error: 0.2558 - val_loss: 0.3232 - val_mean_squared_error: 0.2692
# Epoch 120/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3071 - mean_squared_error: 0.2527 - val_loss: 0.3172 - val_mean_squared_error: 0.2628
# Epoch 121/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3036 - mean_squared_error: 0.2492 - val_loss: 0.3294 - val_mean_squared_error: 0.2748
# Epoch 122/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3010 - mean_squared_error: 0.2464 - val_loss: 0.3138 - val_mean_squared_error: 0.2593
# Epoch 123/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3008 - mean_squared_error: 0.2462 - val_loss: 0.3202 - val_mean_squared_error: 0.2656
# Epoch 124/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3025 - mean_squared_error: 0.2478 - val_loss: 0.3255 - val_mean_squared_error: 0.2705
# Epoch 125/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2962 - mean_squared_error: 0.2412 - val_loss: 0.3230 - val_mean_squared_error: 0.2686
# Epoch 126/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2983 - mean_squared_error: 0.2438 - val_loss: 0.3270 - val_mean_squared_error: 0.2724
# Epoch 127/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2992 - mean_squared_error: 0.2449 - val_loss: 0.3177 - val_mean_squared_error: 0.2632
# Epoch 128/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2837 - mean_squared_error: 0.2348 - val_loss: 0.2946 - val_mean_squared_error: 0.2458
# Epoch 157/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2865 - mean_squared_error: 0.2377 - val_loss: 0.3233 - val_mean_squared_error: 0.2746
# Epoch 158/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2857 - mean_squared_error: 0.2368 - val_loss: 0.3157 - val_mean_squared_error: 0.2671
# Epoch 159/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2882 - mean_squared_error: 0.2397 - val_loss: 0.3128 - val_mean_squared_error: 0.2640
# Epoch 160/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2834 - mean_squared_error: 0.2349 - val_loss: 0.3030 - val_mean_squared_error: 0.2546
# Epoch 161/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2878 - mean_squared_error: 0.2396 - val_loss: 0.3215 - val_mean_squared_error: 0.2732
# Epoch 162/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2873 - mean_squared_error: 0.2390 - val_loss: 0.2955 - val_mean_squared_error: 0.2477
# Epoch 163/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2837 - mean_squared_error: 0.2359 - val_loss: 0.2995 - val_mean_squared_error: 0.2518
# Epoch 164/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_squared_error: 0.2378 - val_loss: 0.3076 - val_mean_squared_error: 0.2600
# Epoch 165/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2809 - mean_squared_error: 0.2333 - val_loss: 0.3078 - val_mean_squared_error: 0.2603
# Epoch 166/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2865 - mean_squared_error: 0.2388 - val_loss: 0.2951 - val_mean_squared_error: 0.2476
# Epoch 167/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2846 - mean_squared_error: 0.2371 - val_loss: 0.2964 - val_mean_squared_error: 0.2491
# Epoch 168/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2871 - mean_squared_error: 0.2399 - val_loss: 0.3107 - val_mean_squared_error: 0.2632
# Epoch 169/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2825 - mean_squared_error: 0.2351 - val_loss: 0.3064 - val_mean_squared_error: 0.2592
# Epoch 170/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2849 - mean_squared_error: 0.2379 - val_loss: 0.3042 - val_mean_squared_error: 0.2570
# Epoch 171/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2879 - mean_squared_error: 0.2409 - val_loss: 0.2871 - val_mean_squared_error: 0.2404
# Epoch 172/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2808 - mean_squared_error: 0.2339 - val_loss: 0.3119 - val_mean_squared_error: 0.2652
# Epoch 173/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2865 - mean_squared_error: 0.2398 - val_loss: 0.2972 - val_mean_squared_error: 0.2506
# Epoch 174/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2840 - mean_squared_error: 0.2374 - val_loss: 0.2988 - val_mean_squared_error: 0.2522
# Epoch 175/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2860 - mean_squared_error: 0.2395 - val_loss: 0.2876 - val_mean_squared_error: 0.2412
# Epoch 176/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2818 - mean_squared_error: 0.2354 - val_loss: 0.2899 - val_mean_squared_error: 0.2432
# Epoch 177/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2843 - mean_squared_error: 0.2378 - val_loss: 0.3031 - val_mean_squared_error: 0.2565
# Epoch 178/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2816 - mean_squared_error: 0.2350 - val_loss: 0.3064 - val_mean_squared_error: 0.2600
# Epoch 179/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2844 - mean_squared_error: 0.2383 - val_loss: 0.3075 - val_mean_squared_error: 0.2614
# Epoch 180/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2820 - mean_squared_error: 0.2357 - val_loss: 0.2991 - val_mean_squared_error: 0.2531
# Epoch 181/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2831 - mean_squared_error: 0.2371 - val_loss: 0.3155 - val_mean_squared_error: 0.2695
# Epoch 182/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2832 - mean_squared_error: 0.2375 - val_loss: 0.2852 - val_mean_squared_error: 0.2396
# Epoch 183/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2808 - mean_squared_error: 0.2351 - val_loss: 0.2893 - val_mean_squared_error: 0.2437
# Epoch 184/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2827 - mean_squared_error: 0.2372 - val_loss: 0.3057 - val_mean_squared_error: 0.2602
# Epoch 185/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2849 - mean_squared_error: 0.2395 - val_loss: 0.3038 - val_mean_squared_error: 0.2585
# Epoch 186/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2815 - mean_squared_error: 0.2361 - val_loss: 0.2918 - val_mean_squared_error: 0.2465
# Epoch 187/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2828 - mean_squared_error: 0.2375 - val_loss: 0.2948 - val_mean_squared_error: 0.2493
# Epoch 188/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2811 - mean_squared_error: 0.2358 - val_loss: 0.2972 - val_mean_squared_error: 0.2522
# Epoch 189/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2782 - mean_squared_error: 0.2331 - val_loss: 0.2800 - val_mean_squared_error: 0.2348
# Epoch 190/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2820 - mean_squared_error: 0.2368 - val_loss: 0.2917 - val_mean_squared_error: 0.2469
# Epoch 191/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2785 - mean_squared_error: 0.2337 - val_loss: 0.2995 - val_mean_squared_error: 0.2548
# Epoch 192/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2797 - mean_squared_error: 0.2349 - val_loss: 0.2890 - val_mean_squared_error: 0.2442
# Epoch 193/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2802 - mean_squared_error: 0.2352 - val_loss: 0.3039 - val_mean_squared_error: 0.2593
# Epoch 194/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2774 - mean_squared_error: 0.2328 - val_loss: 0.2944 - val_mean_squared_error: 0.2500
# Epoch 195/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2786 - mean_squared_error: 0.2341 - val_loss: 0.3095 - val_mean_squared_error: 0.2650
# Epoch 196/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2836 - mean_squared_error: 0.2390 - val_loss: 0.3002 - val_mean_squared_error: 0.2558
# Epoch 197/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2838 - mean_squared_error: 0.2395 - val_loss: 0.3043 - val_mean_squared_error: 0.2600
# Epoch 198/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2828 - mean_squared_error: 0.2384 - val_loss: 0.2893 - val_mean_squared_error: 0.2450
# Epoch 199/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2817 - mean_squared_error: 0.2375 - val_loss: 0.3010 - val_mean_squared_error: 0.2569
# Epoch 200/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2775 - mean_squared_error: 0.2332 - val_loss: 0.2917 - val_mean_squared_error: 0.2475
# Epoch 201/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2789 - mean_squared_error: 0.2348 - val_loss: 0.2871 - val_mean_squared_error: 0.2433
# Epoch 202/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2779 - mean_squared_error: 0.2339 - val_loss: 0.2897 - val_mean_squared_error: 0.2457
# Epoch 203/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2783 - mean_squared_error: 0.2346 - val_loss: 0.3005 - val_mean_squared_error: 0.2565
# Epoch 204/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2824 - mean_squared_error: 0.2384 - val_loss: 0.3005 - val_mean_squared_error: 0.2565
# Epoch 205/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2820 - mean_squared_error: 0.2383 - val_loss: 0.2881 - val_mean_squared_error: 0.2440
# Epoch 206/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2783 - mean_squared_error: 0.2345 - val_loss: 0.2998 - val_mean_squared_error: 0.2561
# Epoch 207/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2817 - mean_squared_error: 0.2380 - val_loss: 0.2952 - val_mean_squared_error: 0.2515
# Epoch 208/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2777 - mean_squared_error: 0.2341 - val_loss: 0.2901 - val_mean_squared_error: 0.2466
# Epoch 209/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2765 - mean_squared_error: 0.2328 - val_loss: 0.2876 - val_mean_squared_error: 0.2441
# Epoch 210/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2803 - mean_squared_error: 0.2368 - val_loss: 0.2983 - val_mean_squared_error: 0.2549
# Epoch 211/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2781 - mean_squared_error: 0.2346 - val_loss: 0.3160 - val_mean_squared_error: 0.2724
# Epoch 212/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2829 - mean_squared_error: 0.2395 - val_loss: 0.2958 - val_mean_squared_error: 0.2523
# Epoch 213/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2770 - mean_squared_error: 0.2336 - val_loss: 0.3082 - val_mean_squared_error: 0.2647
# Epoch 214/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2792 - mean_squared_error: 0.2358 - val_loss: 0.2944 - val_mean_squared_error: 0.2511
# Epoch 215/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2789 - mean_squared_error: 0.2354 - val_loss: 0.3050 - val_mean_squared_error: 0.2618
# Epoch 216/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2759 - mean_squared_error: 0.2327 - val_loss: 0.2828 - val_mean_squared_error: 0.2395
# Epoch 217/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2737 - mean_squared_error: 0.2305 - val_loss: 0.2920 - val_mean_squared_error: 0.2490
# Epoch 218/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2778 - mean_squared_error: 0.2349 - val_loss: 0.2868 - val_mean_squared_error: 0.2436
# Epoch 219/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2799 - mean_squared_error: 0.2369 - val_loss: 0.2933 - val_mean_squared_error: 0.2502
# Epoch 220/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2769 - mean_squared_error: 0.2340 - val_loss: 0.2962 - val_mean_squared_error: 0.2533
# Epoch 221/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2716 - mean_squared_error: 0.2288 - val_loss: 0.2973 - val_mean_squared_error: 0.2545
# Epoch 222/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2814 - mean_squared_error: 0.2387 - val_loss: 0.2951 - val_mean_squared_error: 0.2524
# Epoch 223/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2791 - mean_squared_error: 0.2363 - val_loss: 0.2861 - val_mean_squared_error: 0.2433
# Epoch 224/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2770 - mean_squared_error: 0.2344 - val_loss: 0.2888 - val_mean_squared_error: 0.2463
# Epoch 225/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2784 - mean_squared_error: 0.2356 - val_loss: 0.2907 - val_mean_squared_error: 0.2480
# Epoch 226/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2756 - mean_squared_error: 0.2330 - val_loss: 0.2856 - val_mean_squared_error: 0.2430
# Epoch 227/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2717 - mean_squared_error: 0.2291 - val_loss: 0.2838 - val_mean_squared_error: 0.2415
# Epoch 228/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2734 - mean_squared_error: 0.2311 - val_loss: 0.2894 - val_mean_squared_error: 0.2471
# Epoch 229/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2808 - mean_squared_error: 0.2385 - val_loss: 0.2799 - val_mean_squared_error: 0.2376
# Epoch 230/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2758 - mean_squared_error: 0.2334 - val_loss: 0.3018 - val_mean_squared_error: 0.2595
# Epoch 231/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2770 - mean_squared_error: 0.2349 - val_loss: 0.3017 - val_mean_squared_error: 0.2593
# Epoch 232/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2741 - mean_squared_error: 0.2316 - val_loss: 0.2968 - val_mean_squared_error: 0.2547
# Epoch 233/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2760 - mean_squared_error: 0.2340 - val_loss: 0.2874 - val_mean_squared_error: 0.2455
# Epoch 234/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2723 - mean_squared_error: 0.2303 - val_loss: 0.3009 - val_mean_squared_error: 0.2589
# Epoch 235/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2743 - mean_squared_error: 0.2321 - val_loss: 0.2848 - val_mean_squared_error: 0.2429
# Epoch 236/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2735 - mean_squared_error: 0.2316 - val_loss: 0.2866 - val_mean_squared_error: 0.2450
# Epoch 237/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2718 - mean_squared_error: 0.2299 - val_loss: 0.2995 - val_mean_squared_error: 0.2577
# Epoch 238/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2717 - mean_squared_error: 0.2301 - val_loss: 0.2947 - val_mean_squared_error: 0.2530
# Epoch 239/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2735 - mean_squared_error: 0.2320 - val_loss: 0.2943 - val_mean_squared_error: 0.2527
# Epoch 240/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2764 - mean_squared_error: 0.2349 - val_loss: 0.2937 - val_mean_squared_error: 0.2524
# Epoch 241/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2812 - mean_squared_error: 0.2399 - val_loss: 0.2801 - val_mean_squared_error: 0.2386
# Epoch 242/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2737 - mean_squared_error: 0.2321 - val_loss: 0.2963 - val_mean_squared_error: 0.2545
# Epoch 243/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2760 - mean_squared_error: 0.2346 - val_loss: 0.2791 - val_mean_squared_error: 0.2378
# Epoch 244/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2732 - mean_squared_error: 0.2319 - val_loss: 0.2852 - val_mean_squared_error: 0.2438
# Epoch 245/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2783 - mean_squared_error: 0.2369 - val_loss: 0.2856 - val_mean_squared_error: 0.2442
# Epoch 246/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2742 - mean_squared_error: 0.2329 - val_loss: 0.2972 - val_mean_squared_error: 0.2558
# Epoch 247/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2751 - mean_squared_error: 0.2339 - val_loss: 0.3012 - val_mean_squared_error: 0.2601
# Epoch 248/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2751 - mean_squared_error: 0.2337 - val_loss: 0.2898 - val_mean_squared_error: 0.2486
# Epoch 249/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2767 - mean_squared_error: 0.2355 - val_loss: 0.2943 - val_mean_squared_error: 0.2530
# Epoch 250/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2792 - mean_squared_error: 0.2380 - val_loss: 0.2952 - val_mean_squared_error: 0.2538
# Epoch 251/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2752 - mean_squared_error: 0.2339 - val_loss: 0.2890 - val_mean_squared_error: 0.2477
# Epoch 252/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2730 - mean_squared_error: 0.2317 - val_loss: 0.2953 - val_mean_squared_error: 0.2542
# Epoch 253/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2731 - mean_squared_error: 0.2320 - val_loss: 0.3017 - val_mean_squared_error: 0.2605
# Epoch 254/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2794 - mean_squared_error: 0.2381 - val_loss: 0.2881 - val_mean_squared_error: 0.2469
# Epoch 255/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2731 - mean_squared_error: 0.2318 - val_loss: 0.3035 - val_mean_squared_error: 0.2626
# Epoch 256/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2754 - mean_squared_error: 0.2344 - val_loss: 0.2916 - val_mean_squared_error: 0.2505
# Epoch 257/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2771 - mean_squared_error: 0.2361 - val_loss: 0.2921 - val_mean_squared_error: 0.2513
# Epoch 258/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2739 - mean_squared_error: 0.2328 - val_loss: 0.3038 - val_mean_squared_error: 0.2628
# Epoch 259/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2709 - mean_squared_error: 0.2299 - val_loss: 0.2878 - val_mean_squared_error: 0.2469
# Epoch 260/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2694 - mean_squared_error: 0.2285 - val_loss: 0.2918 - val_mean_squared_error: 0.2512
# Epoch 261/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2742 - mean_squared_error: 0.2336 - val_loss: 0.3000 - val_mean_squared_error: 0.2595
# Epoch 262/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2774 - mean_squared_error: 0.2366 - val_loss: 0.2989 - val_mean_squared_error: 0.2582
# Epoch 263/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2775 - mean_squared_error: 0.2369 - val_loss: 0.2773 - val_mean_squared_error: 0.2367
# Epoch 264/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2708 - mean_squared_error: 0.2298 - val_loss: 0.3019 - val_mean_squared_error: 0.2609
# Epoch 265/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2721 - mean_squared_error: 0.2314 - val_loss: 0.2867 - val_mean_squared_error: 0.2460
# Epoch 266/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2754 - mean_squared_error: 0.2346 - val_loss: 0.3206 - val_mean_squared_error: 0.2801
# Epoch 267/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2708 - mean_squared_error: 0.2302 - val_loss: 0.2934 - val_mean_squared_error: 0.2529
# Epoch 268/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2722 - mean_squared_error: 0.2315 - val_loss: 0.2860 - val_mean_squared_error: 0.2455
# Epoch 269/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2732 - mean_squared_error: 0.2327 - val_loss: 0.2938 - val_mean_squared_error: 0.2533
# Epoch 270/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2720 - mean_squared_error: 0.2314 - val_loss: 0.2843 - val_mean_squared_error: 0.2439
# Epoch 271/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2709 - mean_squared_error: 0.2303 - val_loss: 0.2862 - val_mean_squared_error: 0.2458
# Epoch 272/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2800 - mean_squared_error: 0.2396 - val_loss: 0.2848 - val_mean_squared_error: 0.2443
# Epoch 273/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2719 - mean_squared_error: 0.2315 - val_loss: 0.2868 - val_mean_squared_error: 0.2466
# Epoch 274/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2740 - mean_squared_error: 0.2336 - val_loss: 0.2890 - val_mean_squared_error: 0.2484
# Epoch 275/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2726 - mean_squared_error: 0.2321 - val_loss: 0.3125 - val_mean_squared_error: 0.2721
# Epoch 276/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2745 - mean_squared_error: 0.2342 - val_loss: 0.2962 - val_mean_squared_error: 0.2560
# Epoch 277/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2700 - mean_squared_error: 0.2298 - val_loss: 0.2976 - val_mean_squared_error: 0.2574
# Epoch 278/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2754 - mean_squared_error: 0.2351 - val_loss: 0.2863 - val_mean_squared_error: 0.2462
# Epoch 279/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2703 - mean_squared_error: 0.2301 - val_loss: 0.3052 - val_mean_squared_error: 0.2646
# Epoch 280/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2713 - mean_squared_error: 0.2309 - val_loss: 0.2896 - val_mean_squared_error: 0.2492
# Epoch 281/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2767 - mean_squared_error: 0.2366 - val_loss: 0.3022 - val_mean_squared_error: 0.2622
# Epoch 282/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2704 - mean_squared_error: 0.2301 - val_loss: 0.2865 - val_mean_squared_error: 0.2463
# Epoch 283/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2706 - mean_squared_error: 0.2305 - val_loss: 0.2848 - val_mean_squared_error: 0.2447
# Epoch 284/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2745 - mean_squared_error: 0.2345 - val_loss: 0.3066 - val_mean_squared_error: 0.2663
# Epoch 285/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2782 - mean_squared_error: 0.2380 - val_loss: 0.2914 - val_mean_squared_error: 0.2514
# Epoch 286/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2756 - mean_squared_error: 0.2356 - val_loss: 0.3153 - val_mean_squared_error: 0.2750
# Epoch 287/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2742 - mean_squared_error: 0.2341 - val_loss: 0.3041 - val_mean_squared_error: 0.2640
# Epoch 288/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2716 - mean_squared_error: 0.2314 - val_loss: 0.2821 - val_mean_squared_error: 0.2418
# Epoch 289/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2758 - mean_squared_error: 0.2357 - val_loss: 0.2813 - val_mean_squared_error: 0.2413
# Epoch 290/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2749 - mean_squared_error: 0.2349 - val_loss: 0.3026 - val_mean_squared_error: 0.2623
# Epoch 291/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2707 - mean_squared_error: 0.2305 - val_loss: 0.2854 - val_mean_squared_error: 0.2452
# Epoch 292/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2753 - mean_squared_error: 0.2352 - val_loss: 0.2971 - val_mean_squared_error: 0.2572
# Epoch 293/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2709 - mean_squared_error: 0.2310 - val_loss: 0.2936 - val_mean_squared_error: 0.2537
# Epoch 294/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2777 - mean_squared_error: 0.2376 - val_loss: 0.2903 - val_mean_squared_error: 0.2506
# Epoch 295/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2736 - mean_squared_error: 0.2338 - val_loss: 0.2825 - val_mean_squared_error: 0.2427
# Epoch 296/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2730 - mean_squared_error: 0.2332 - val_loss: 0.2900 - val_mean_squared_error: 0.2500
# Epoch 297/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2771 - mean_squared_error: 0.2371 - val_loss: 0.2868 - val_mean_squared_error: 0.2469
# Epoch 298/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2700 - mean_squared_error: 0.2301 - val_loss: 0.3050 - val_mean_squared_error: 0.2651
# Epoch 299/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2761 - mean_squared_error: 0.2362 - val_loss: 0.2925 - val_mean_squared_error: 0.2525
# Epoch 300/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2723 - mean_squared_error: 0.2325 - val_loss: 0.2827 - val_mean_squared_error: 0.2427

# %% [markdown]
# ### Plot des courbes d'apprentissage des modèles ###

# %%
plt.plot(Hist.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()
print(np.min(Hist.history['val_mean_squared_error'][3:]))

plt.plot(Hist_reg.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist_reg.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()

print(np.min(Hist_reg.history['val_mean_squared_error'][3:]))

plt.plot(Hist_drop.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist_drop.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()
print(np.min(Hist_drop.history['val_mean_squared_error'][3:]))
# Out:
# 0.2330419272184372
# 0.23587514460086823
# 0.23476170003414154

# %% [markdown]
# ### Résultats des modèles (plot y_pred y_test) ###

# %%
y_pred_test=model.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))
      
fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau de neurones")
plt.show()

y_pred_test=model_reg.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau avec regularisation l2")
plt.show()

y_pred_test=model_drop.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau avec dropout")
plt.show()
# Out:
# 79/79 [==============================] - 0s 916us/step
# 0.21927872637713067
# 79/79 [==============================] - 0s 878us/step
# 0.23985723534417422
# 79/79 [==============================] - 0s 1ms/step
# 0.2371705794046522

# %% [markdown]
# # Monte-Carlo #
# ## Calcul de "signatures" en énergie ##

# %%
y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)

y_pred_test=model.predict(X_test_soap_red)
plt.plot(y_pred_test_krr_soap,label='KRR')
plt.plot(y_pred_test,alpha=0.5,label='reseaux de neurones')
plt.xlabel('pas de simulation')
plt.ylabel('energies [u.a]')
plt.legend()
# Out:
# 79/79 [==============================] - 0s 891us/step

# %%
import seaborn as sns
sns.set_style("white")


# Plot
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(y_pred_test_krr_soap), color="blue", **kwargs,label="Kernel Ridge")
print("E moyen :",y_pred_test_krr_soap.mean()," +- ",y_pred_test_krr_soap.std())
sns.distplot(pd.DataFrame(y_test), color="orange", **kwargs,label="Y test")
print("E moyen :",y_test.mean()," +- ",y_test.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
plt.figure(figsize=(5,2), dpi= 200)

# plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(y_pred_test), color="blue", **kwargs,label="Réseau de neurones")
print("E moyen :",y_pred_test.mean()," +- ",y_pred_test.std())
sns.distplot(pd.DataFrame(y_test), color="orange", **kwargs,label="Y test")
print("E moyen :",y_test.mean()," +- ",y_test.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E moyen : -0.0074470703125  +-  0.9074976399941982
# E moyen : 1.1368683772161604e-17  +-  1.0
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E moyen : -0.002492039  +-  0.89818645
# E moyen : 1.1368683772161604e-17  +-  1.0

# %% [markdown]
# ## Generation des positions Monte-Carlo

# %%
#genere un fichier xyz
def generate_xyz(positions, filename):
  # Open the file for writing
  with open(filename, 'w') as f:
    for position in positions :
        # Write the number of atoms to the file
        f.write(str(len(position)) + '\n')
        f.write('\n')

        # Loop over the atomic positions
        for pos in position:
          # Write the atomic symbol and coordinates to the file
            if(pos[0]==0.):
                f.write('O ' + ' '.join(str(x) for x in pos[1:4]) + '\n')
            if(pos[0]==1.):
                f.write('H ' + ' '.join(str(x) for x in pos[1:4]) + '\n')
            
class Monte_Carlo:
    def __init__(self, dataset,model,yscaler,temp,E_min):
        self.model=model
        self.dataset=dataset
        self.yscaler=yscaler
        self.E_min=E_min
        self.E_temp=temp*Boltzmann/eV
        soap_vect,pca=SOAP_Vectors("new_positions_sparse.xyz", cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca_d=15)
        soapscaler=StandardScaler()
        self.soapscaler=soapscaler.fit(soap_vect)
        self.pca=pca
        O1 =self.dataset[:,0,1:4]
        O2 =self.dataset[:,1,1:4]
        H  =self.dataset[:,2,1:4]
        H11=self.dataset[:,5,1:4]
        H12=self.dataset[:,6,1:4]
        H21=self.dataset[:,3,1:4]
        H22=self.dataset[:,4,1:4]
        H_O1       = O1-H
        H_O2       = O2-H
        O1_H11     = H11-O1
        O1_H12     = H12-O1
        O2_H21     = H21-O2
        O2_H22     = H22-O2
        #ecart typique permis dans une etape
        self.H_O1_std       = 0.01*(O1-H).std()
        self.H_O2_std       = 0.01*(O2-H).std()
        self.O1_H11_std     = 0.01*(H11-O1).std()
        self.O1_H12_std     = 0.01*(H12-O1).std()
        self.O2_H21_std     = 0.01*(H21-O2).std()
        self.O2_H22_std     = 0.01*(H22-O2).std()
        self.O1_H_O2_std    = 0.01*(vg.angle(H_O1,H_O2)).std()
        self.H22_O2_H21_std = 0.01*(vg.angle(O2_H21,O2_H22)).std()
        self.H12_O1_H11_std = 0.01*(vg.angle(O1_H11,O1_H12)).std()
        

    def create_config(self,config):
        O1 =config[0,1:4]
        O2 =config[1,1:4]
        H  =config[2,1:4]
        H21=config[3,1:4]
        H22=config[4,1:4]
        H11=config[5,1:4]
        H12=config[6,1:4]
        
        H_O1       = O1-H
        H_O2       = O2-H
        O1_H11     = H11-O1
        O1_H12     = H12-O1
        O2_H21     = H21-O2
        O2_H22     = H22-O2
        O1_H_O2    = vg.angle(H_O1,H_O2)
        H22_O2_H21 = vg.angle(O2_H21,O2_H22)
        H12_O1_H11 = vg.angle(O1_H11,O1_H12)
        
        d_H_O1       = np.random.normal(loc=0, scale=self.H_O1_std      )
        d_H_O2       = np.random.normal(loc=0, scale=self.H_O2_std      )
        d_O1_H11     = np.random.normal(loc=0, scale=self.O1_H11_std    )
        d_O1_H12     = np.random.normal(loc=0, scale=self.O1_H12_std    )
        d_O2_H21     = np.random.normal(loc=0, scale=self.O2_H21_std    )
        d_O2_H22     = np.random.normal(loc=0, scale=self.O2_H22_std    )
        d_O1_H_O2    = np.random.normal(loc=0, scale=self.O1_H_O2_std   )
        d_H22_O2_H21 = np.random.normal(loc=0, scale=self.H22_O2_H21_std)
        d_H12_O1_H11 = np.random.normal(loc=0, scale=self.H12_O1_H11_std)
        new_H  = H
        r,t,p  = cartesian_to_polar_3d(H_O1)
        new_O1 = new_H + polar_to_cartesian_3d(r+d_H_O1,t+d_O1_H_O2/4,p+d_O1_H_O2/4)
        r,t,p  = cartesian_to_polar_3d(H_O2)
        new_O2 = new_H + polar_to_cartesian_3d(r+d_H_O2,t+d_O1_H_O2/4,p+d_O1_H_O2/4)
        r,t,p  = cartesian_to_polar_3d(O1_H11)
        new_H11= new_O1 + polar_to_cartesian_3d(r+d_O1_H11,t+d_H12_O1_H11/4,p+d_H12_O1_H11/4)
        r,t,p  = cartesian_to_polar_3d(O1_H12)
        new_H12= new_O1 + polar_to_cartesian_3d(r+d_O1_H12,t+d_H12_O1_H11/4,p+d_H12_O1_H11/4)
        r,t,p  = cartesian_to_polar_3d(O2_H21)
        new_H21= new_O2 + polar_to_cartesian_3d(r+d_O2_H21,t+d_H22_O2_H21/4,p+d_H22_O2_H21/4)
        r,t,p  = cartesian_to_polar_3d(O2_H22)
        new_H22= new_O2 + polar_to_cartesian_3d(r+d_O2_H22,t+d_H22_O2_H21/4,p+d_H22_O2_H21/4)
        new_config=np.copy(config)
        new_config[0,1:4]=new_O1 
        new_config[1,1:4]=new_O2 
        new_config[2,1:4]=new_H  
        new_config[3,1:4]=new_H21
        new_config[4,1:4]=new_H22
        new_config[5,1:4]=new_H11
        new_config[6,1:4]=new_H12
        return new_config
    
    #calcul d'energie d'une configuration
    def GetEnergy(self,config):
        generate_xyz([config], "a.xyz")
        Soap_pca=SOAP_Vector("a.xyz",  cutoff=5., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca=self.pca)
        Soap_pca_red=self.soapscaler.transform(Soap_pca)
        y_pred=self.model.predict(Soap_pca_red)
        E_pred=self.yscaler.inverse_transform(y_pred)
        return E_pred[0,0]
        
    #probabilité selon la distribution de Boltzmann
    def get_proba(self,E_last,E_new):
        return np.exp((E_last-E_new)/(self.E_temp))
    
    def run_mcmc(self,config_init,N_config):
        dataset_gen=[]
        energies_gen=[]
        E_last=self.GetEnergy(config_init)
        new_config=config_init
        dataset_gen.append(new_config)
        energies_gen.append(E_last)
        while(N_config> len(energies_gen)):
            test_config=self.create_config(new_config)
            E_pred=self.GetEnergy(test_config)
            if (E_pred <= E_last ):
                if (E_pred >= self.E_min):
                    new_config=test_config
                    dataset_gen.append(new_config)
                    energies_gen.append(E_pred)
            else :
                if(self.get_proba(E_last,E_pred)>np.random.uniform()):
                    new_config=test_config
                    dataset_gen.append(new_config)
                    energies_gen.append(E_pred)
        return np.array(dataset_gen),np.array(energies_gen)


def cartesian_to_polar_3d(vector):
  # Convert the input vector to a NumPy array
  v = np.array(vector)
  
  # Calculate the polar coordinates
  r = np.linalg.norm(v)
  theta = np.arccos(v[2] / r)
  phi = np.arctan2(v[1], v[0])
  
  # Return the polar coordinates
  return (r, theta, phi)

def polar_to_cartesian_3d(r, theta, phi):
  # Calculate the Cartesian coordinates
  x = r * np.sin(theta) * np.cos(phi)
  y = r * np.sin(theta) * np.sin(phi)
  z = r * np.cos(theta)
  
  # Return the Cartesian coordinates
  return (x, y, z)


krrsoap = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=2,param_grid={'alpha': [3.1622776601683794e-12], 'gamma': [3.162277660168379e-06]})
krrsoap.fit(X_train_soap_red, y_train)
MC=Monte_Carlo(dataset,model=krrsoap,yscaler=yscaler,temp=0.00001,E_min=energies[1:].min())
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.71017e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.98639e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.48205e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# loaded xyz file: new_positions_sparse.xyz, with 10000 frames and elements: [1 8]

# %%
#Nous generons les positions et energies
new_dataset,new_energies=MC.run_mcmc(dataset[11],2000)

# %% [markdown]
# ## Resultats du Monte-Carlo

# %%
generate_xyz(new_dataset, "mcmc.xyz")
nv.show_mdtraj(mdt.load_xyz("mcmc.xyz", top='zundel.pdb'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-57-c397d4e4448b> in <module>
#       1 generate_xyz(new_dataset, "mcmc.xyz")
# ----> 2 nv.show_mdtraj(mdt.load_xyz("mcmc.xyz", top='zundel.pdb'))
#
# ~\anaconda3\lib\site-packages\mdtraj\formats\xyzfile.py in load_xyz(filename, top, stride, atom_indices, frame)
#     101                         'you supplied %s'.format(type(filename)))
#     102
# --> 103     topology = _parse_topology(top)
#     104     atom_indices = cast_indices(atom_indices)
#     105
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in _parse_topology(top, **kwargs)
#     172         topology = top.topology
#     173     elif isinstance(top, (string_types, os.PathLike)) and (ext in ['.pdb', '.pdb.gz', '.h5','.lh5']):
# --> 174         _traj = load_frame(top, 0, **kwargs)
#     175         topology = _traj.topology
#     176     elif isinstance(top, (string_types, os.PathLike)) and (ext in ['.prmtop', '.parm7', '.prm7']):
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in load_frame(filename, index, top, atom_indices, **kwargs)
#     308
#     309     if loader.__name__ not in ['load_dtr']:
# --> 310         _assert_files_exist(filename)
#     311     else:
#     312         _assert_files_or_dirs_exist(filename)
#
# ~\anaconda3\lib\site-packages\mdtraj\core\trajectory.py in _assert_files_exist(filenames)
#      98     for fn in filenames:
#      99         if not (os.path.exists(fn) and os.path.isfile(fn)):
# --> 100             raise IOError('No such file: %s' % fn)
#     101
#     102
#
# OSError: No such file: zundel.pdb

# %%
plt.figure(figsize=(5,3), dpi= 200)

#Visualisation des energies
plt.plot(energies[:2000],label='ab initio')
plt.plot(new_energies,alpha=0.6,label="monte carlo")
plt.xlabel('pas de simulation')
plt.ylabel('energies [u.a]')
plt.legend()

# %%
#nous recalculons les distributions des descripteurs géometriques
plt.figure(figsize=(5,2), dpi= 200)
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

# plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(energies), color="blue", **kwargs,label="ab initio")
print("E moyen :",energies.mean()," +- ",energies.std())
sns.distplot(pd.DataFrame(new_energies), color="orange", **kwargs,label="monte carlo")
print("E moyen :",new_energies.mean()," +- ",new_energies.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E moyen : 0.002538257316696719  +-  0.0009099056886874164
# E moyen : 0.010165096303859759  +-  0.004779960631924897

# %%
import seaborn as sns
sns.set_style("white")

O1_old=dataset[:,0,1:4]
O2_old=dataset[:,1,1:4]
O2_O1_old=O1_old-O2_old
dO_O_old=np.linalg.norm(O2_O1_old,axis=1)


O1=new_dataset[:,0,1:4]
O2=new_dataset[:,1,1:4]
H=new_dataset[:,2,1:4]
H11=new_dataset[:,5,1:4]
H12=new_dataset[:,6,1:4]
H21=new_dataset[:,3,1:4]
H22=new_dataset[:,4,1:4]

O2_O1=O1-O2
O2_H=H-O2
O1_H=H-O1
O1_H11=H11-O1
O1_H12=H12-O1
O2_H21=H21-O2
O2_H22=H22-O2


dO_O=np.linalg.norm(O2_O1,axis=1)
dO1_H=np.linalg.norm(O1_H,axis=1)
dO2_H=np.linalg.norm(O2_H,axis=1)

H22_O2_H21 = vg.angle(O2_H21,O2_H22)
H12_O1_H11 = vg.angle(O1_H11,O1_H12)

# Plot
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(dO_O_old), color="blue", **kwargs,label='ab initio')

sns.distplot(pd.DataFrame(dO_O), color="orange", **kwargs,label='monte carlo')
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")
plt.legend()
plt.title("Distribution des distances O-O")
plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO_O,new_energies,s=0.3,marker='.')


plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()


plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(dO1_H), color="orange", label="Premier O", **kwargs)
sns.distplot(pd.DataFrame(dO2_H), color="blue", label="Deuxieme O", **kwargs)


plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")

plt.title("Distribution des distances O-H pour l'hydrogene central")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO1_H,new_energies,s=0.3)


plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(H22_O2_H21), color="orange", label="Premier H2O", **kwargs)
sns.distplot(pd.DataFrame(H12_O1_H11), color="blue", label="Deuxieme H2O", **kwargs)


plt.xlabel(r'Angle $[degres]$')
plt.ylabel("Densité")

plt.title("Distribution des angles O-H-O pour les molecules d'eau")
plt.legend()

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(H22_O2_H21,new_energies,s=0.3,marker='.')


plt.legend()
plt.xlabel(r'Angle [degres]')
plt.ylabel("Energie [u.a]")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.
