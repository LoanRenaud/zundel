# %% [markdown]
# # Ion Zundel et Potentiel Machine Learning #
# Loan RENAUD et Zacharie WAYSENSON
#
#
# ## **Load des données et animations** ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
import pandas as pd
from scipy.constants import Boltzmann
from scipy.constants import e as eV
import mdtraj as mdt
import nglview as nv
from ase import Atoms
from dscribe.descriptors import CoulombMatrix
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from dscribe.descriptors import SOAP
from ase.io import read
from sklearn.decomposition import PCA
from dscribe.kernels import AverageKernel
from scipy.spatial import distance
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn.kernel_ridge import KernelRidge
import keras
import tensorflow as tf
from keras import regularizers
from keras import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import tensorflow as tf




# %matplotlib inline

# %%
#Loader du fichier .xyz
def load_data(file):
    o1_index=[2]
    o2_index=[3]
    h1_index=[4]
    h2_index=[5]
    h3_index=[6]
    h4_index=[7]
    h5_index=[8]

    o1=[]
    o2=[]
    h1=[]
    h2=[]
    h3=[]
    h4=[]
    h5=[]

    with open(file, 'r') as infile:

        for index, line in enumerate(infile):
            items = line.split()

            if index%9 in o1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o1.append([0,x,y,z])

            if index%9 in o2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o2.append([0,x,y,z])

            if index%9 in h1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h1.append([1,x,y,z])   

            if index%9 in h2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h2.append([1,x,y,z])

            if index%9 in h3_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h3.append([1,x,y,z])

            if index%9 in h4_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h4.append([1,x,y,z])

            if index%9 in h5_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h5.append([1,x,y,z])
                
    return np.concatenate((o1, o2, h1, h2, h3, h4, h5), axis=1).reshape(10000, 7, 4) #10000 fois 7 colomnes de 4 éléments  (particule, x, y, z)

#Loader de l'output de la simulation (fichier .out)
output=pd.read_csv('new_energies_sparse.out', sep=' ', header=None)

#Extraction des énergies (5eme colonne)
energies=output[4]

#Load du fichier .xyz
dataset=load_data("new_positions_sparse.xyz")

#################
# Plot des données (Animation 3D + Energie)
#################

#Nombre de data utilisées pour l'animation
N=100

#Init animation 2D
def init():
    return graph,

#Fonction update plot energies
def update_en(num):
    graph.set_data(x[:num],y[:num])
    return graph,

#Mise en forme des trajectoires
def transform_data(X, Y, Z):
    t = np.vstack((X, Y, Z))
    return t

#Fonction update pour le plot des trajectoires
def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        line.set_data(data[0:2, num-1:num])
        line.set_3d_properties(data[2,num-1:num])
    return lines

#Fonction update des deux plots
def update_both(num, data2, line2):
    update_en(num)
    update_lines(num, data2, line2)
    
#Création de la figure
fig= plt.figure(figsize=(5, 8))

#ax1 = plot des énergies
ax1=fig.add_subplot(2, 1, 2) 
ax1.set_xlim(0, N)
ax1.set_ylim(np.min(energies), np.max(energies))
ax1.set_xlabel("Simulation step")
ax1.set_ylabel("Energie potentielle du système (u.a.)")

graph, = plt.plot([], [], '-')

#ax = plot des trajectoires
ax=fig.add_subplot(2, 1, 1, projection='3d')

ax.set_xlim3d([np.min(dataset[:, :, 1][:N]), np.max(dataset[:, :, 1][:N])])
ax.set_xlabel('X')

ax.set_ylim3d([np.min(dataset[:, :, 2][:N]), np.max(dataset[:, :, 2][:N])])
ax.set_ylabel('Y')

ax.set_zlim3d([np.min(dataset[:, :, 3][:N]), np.max(dataset[:, :, 3][:N])])
ax.set_zlabel('Z')

ax.set_title('Résultats de la simulation ab-initio')

plt.tight_layout()

# Données de l'énergie
x = range(N)
y = energies[:N]

# Données 3D
data=[]
lines=[]
colors=['r', 'r', 'silver','silver', 'silver', 'silver', 'silver'] #couleur des atomes
for i in range(dataset.shape[1]):
    coord=dataset[:, i][:N]
    X=coord[:, 1]
    Y=coord[:, 2]
    Z=coord[:, 3]
    data.append(transform_data(X, Y, Z))
    
    lines.append(ax.plot(data[0][0,0:1], data[0][1,0:1], data[0][2,0:1], 'o', color=colors[i])[0])

# Objet d'animation
ani = animation.FuncAnimation(fig, update_both, len(X), fargs=(data, lines),
                              interval=100, blit=False)

# ani.save('ab-initio.mp4')
plt.show()

# %% [markdown]
# Deuxième option pour tracer les postions :

# %%
nv.show_mdtraj(mdt.load_xyz("new_positions_sparse.xyz", top='zundel.pdb'))
# Out:
# NGLWidget(max_frame=9999)

# %% [markdown]
# ## Séparation des données ##

# %%
#Séparation des données
print("data shape :", dataset.shape)
print("target shape :", energies.shape)
X_train, X_test, y_train, y_test=train_test_split(dataset, energies, random_state=22)

#Scaling des y
yscaler=StandardScaler()
y_train=yscaler.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test=yscaler.fit_transform(y_test.to_numpy().reshape(-1, 1))
# Out:
# data shape : (10000, 7, 4)
# target shape : (10000,)

# %% [markdown]
# # Descripteurs #
#
# ## Descripteurs géometriques ##

# %%
import seaborn as sns
sns.set_style("white")
#Coordonées spatiales pour chaque atome
O1=dataset[:,0,1:4]
O2=dataset[:,1,1:4]
H=dataset[:,2,1:4]
H11=dataset[:,5,1:4]
H12=dataset[:,6,1:4]
H21=dataset[:,3,1:4]
H22=dataset[:,4,1:4]

#Calcul des Coordonnées vectorielles des atomes 
O2_O1=O1-O2
O2_H=H-O2
O1_H=H-O1
O1_H11=H11-O1
O1_H12=H12-O1
O2_H21=H21-O2
O2_H22=H22-O2

#calcul des distances et angles interessants
dO_O=np.linalg.norm(O2_O1,axis=1)
dO1_H=np.linalg.norm(O1_H,axis=1)
dO2_H=np.linalg.norm(O2_H,axis=1)

H22_O2_H21 = vg.angle(O2_H21,O2_H22)
H21_O1_H11 = vg.angle(O1_H11,O1_H12)

# Plot
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(dO_O), color="blue", **kwargs)
plt.vlines(dO_O.mean(),0,7,color="red", label="moyenne")
plt.vlines(dO_O.mean()+dO_O.std(),0,7, label="ecart type",color="k")
plt.vlines(dO_O.mean()-dO_O.std(),0,7, color="k")
print("dO_O moyen :",dO_O.mean()," +- ",dO_O.std())

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")

plt.title("Distribution des distances O-O")
plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO_O,energies,s=0.3,marker='.')
plt.vlines(dO_O.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(dO_O.mean()+dO_O.std(),0,0.007, label="ecart type",color="k")
plt.vlines(dO_O.mean()-dO_O.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()


plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(dO1_H), color="orange", label="Premier O", **kwargs)
sns.distplot(pd.DataFrame(dO2_H), color="blue", label="Deuxieme O", **kwargs)
plt.vlines(dO1_H.mean(),0,3,color="red", label="moyenne")
plt.vlines(dO1_H.mean()+dO1_H.std(),0,3, label="ecart type",color="k")
plt.vlines(dO1_H.mean()-dO1_H.std(),0,3, color="k")
print("dO1_H moyen :",dO1_H.mean()," +- ",dO1_H.std())

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Densité")

plt.title("Distribution des distances O-H pour l'hydrogene central")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(dO1_H,energies,s=0.3)
plt.vlines(dO1_H.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(dO1_H.mean()+dO1_H.std(),0,0.007, label="ecart type",color="k")
plt.vlines(dO1_H.mean()-dO1_H.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Distance $[a_0]$')
plt.ylabel("Energie [u.a]")

plt.show()

plt.figure(figsize=(5,2), dpi= 200)

sns.distplot(pd.DataFrame(H22_O2_H21), color="orange", label="Premier H2O", **kwargs)
sns.distplot(pd.DataFrame(H21_O1_H11), color="blue", label="Deuxieme H2O", **kwargs)
plt.vlines(H22_O2_H21.mean(),0,0.15,color="red", label="moyenne")
plt.vlines(H22_O2_H21.mean()+H22_O2_H21.std(),0,0.15, label="ecart type",color="k")
plt.vlines(H22_O2_H21.mean()-H22_O2_H21.std(),0,0.15, color="k")
print("H22_O2_H21 moyen :",H22_O2_H21.mean()," +- ",H22_O2_H21.std())

plt.xlabel(r'Angle $[degres]$')
plt.ylabel("Densité")

plt.title("Distribution des angles O-H-O pour les molecules d'eau")
plt.legend()

plt.show()

plt.figure(figsize=(5,2), dpi= 200)
plt.scatter(H22_O2_H21,energies,s=0.3,marker='.')
plt.vlines(H22_O2_H21.mean(),0,0.007,color="red", label="moyenne")
plt.vlines(H22_O2_H21.mean()+H22_O2_H21.std(),0,0.007, label="ecart type",color="k")
plt.vlines(H22_O2_H21.mean()-H22_O2_H21.std(),0,0.007, color="k")

plt.legend()
plt.xlabel(r'Angle [degres]')
plt.ylabel("Energie [u.a]")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# dO_O moyen : 4.53007034788335  +-  0.05661715866559092
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# dO1_H moyen : 2.27340180914684  +-  0.12949155504015944
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# H22_O2_H21 moyen : 108.90639931766596  +-  2.813481373777933

# %% [markdown]
# ## Permutation Invariant Vector (PIV) ##

# %%
#Fonction de switch (voir dans le rapport) de type Fermi-Dirac
def C(rmin, rmax, x): 
    a=20/(rmax-rmin) #pente pour la bijection (rmin, rmax) => (-10, 10)

    bij=a*x+10-a*rmax #bijection (modèle affine)
    y=1/(np.exp(0.3*bij)+1) #calcul de la valeur de la fonction de switch
    return y

#Descripteur PIV
# X : dataset d'entrée
# pca_d : nombre de composantes conservées lors de la pca
# label : label pour le plot retourné
def PIV_descr(X, pca_d=10, label='label'):
    piv=[]
    for i in range(len(X)): #pour chaque configuration
        dist=distance.cdist(X[i][:, 1:], X[i][:, 1:], 'euclidean') #calcul de la distance entre chaque paire d'atomes
        
        #décomposition de la matrice obtenue par type d'interactions (O-O, O-H, H-H)
        a=np.array([dist[0, 1]]) #interaction O-O
        b=np.concatenate((dist[0, 2:],dist[1, 2:])) #interaction O-H
        c=[] #interaction H-H
        for i in range(2, dist.shape[0]):
            c=np.concatenate((c, dist[i, i+1:]))
        
        brmin=np.min(b)
        brmax=np.max(b)
        
        crmin=np.min(c)
        crmax=np.max(c)
        
        #evaluation de la fonction de switch
        aswitched=C(brmin, brmax, a)
        bswitched=C(brmin, brmax, b)
        cswitched=C(crmin, crmax, c)
        
        #tri des valeurs par ordre ascendant dans chaque bloc
        bs=np.sort(bswitched)
        cs=np.sort(cswitched)
        
        #création du vecteur par concaténation
        piv.append(np.concatenate((aswitched, bs, cs)))
        
    #PCA sur le vecteur obtenu
    data_2d = np.array([features_2d.flatten() for features_2d in piv])
    pca = PCA(n_components=pca_d)
    pca.fit(data_2d)
    piv_pca = pca.transform(data_2d)
    print("original shape:   ", piv_pca.shape) 
    print("transformed shape:", piv_pca.shape)
    
    plt.plot(np.cumsum(pca.explained_variance_ratio_), linestyle='--', marker='o', label=label)
    plt.xlabel("Nombre de composantes")
    plt.ylabel('Variance totale expliquée')
    return piv_pca

# %% [markdown]
# **Création et scaling des descripteurs**

# %%
X_train_PIV=PIV_descr(X_train, label="données d'entraînement")
X_train_PIV_red=scaler.fit_transform(X_train_PIV)
X_test_PIV=PIV_descr(X_test, label="données de test")
X_test_PIV_red=scaler.fit_transform(X_test_PIV)
plt.legend()
# Out:
# original shape:    (7500, 10)
# transformed shape: (7500, 10)
# original shape:    (2500, 10)
# transformed shape: (2500, 10)

# %% [markdown]
# ## Matrices de Coulomb ##

# %%
#Fonction pour la création de la matrice de Coulomb à partir d'un dataset
def create_CM(data):
    cm = CoulombMatrix(n_atoms_max=7) #matrice de Coulomb de dimensions 7
    zundel_steps=[]
    for i in range(data.shape[0]): #on ajoute chaque configuration
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %% [markdown]
# ## **Exploration statistique des matrices de Coulomb**. ##

# %%
#création des matrices de Coulomb pour les données d'entrainement
X_train_CM=create_CM(X_train)
X_test_CM=create_CM(X_test)

#scaling des données (centrées réduites)
scaler=StandardScaler()
X_train_CM_red=scaler.fit_transform(X_train_CM)
X_test_CM_red=scaler.fit_transform(X_test_CM)

#conversion dans un Dataset pour explorer les données statistiquement avec les outils pandas
X_train_DF=pd.DataFrame(X_train_CM)

stat=X_train_DF.describe()

statnp=stat.to_numpy().reshape(8, 7, 7)

#Plot des stats sous forme de matrice colorée
for i, l in enumerate(stat.index):
    plt.matshow(statnp[i], cmap="plasma")
    for (x, y), value in np.ndenumerate(statnp[i]):
        plt.text(x, y, f"{value:.2f}", va="center", ha="center", color="white")
    plt.title(l)

# %% [markdown]
# Exemple de matrice de Coulomb :

# %%
plt.matshow(create_CM(X_train)[0].reshape(7, 7), cmap="YlGnBu")

for (x, y), value in np.ndenumerate(create_CM(X_train)[0].reshape(7, 7)):
    plt.text(x, y, f"{value:.3f}", va="center", ha="center", color="red")
    
plt.title("Exemple de matrice de Coulomb")
# Out:
# Text(0.5, 1.0, 'Exemple de matrice de Coulomb')

# %% [markdown]
# ## Matrices de Coulomb version Eigenspectrum ##

# %%
#même fonction que précédemment mais en ne retenant que les valeurs propres
def create_CM_eigen(data):
    cm = CoulombMatrix(n_atoms_max=7, permutation='eigenspectrum')
    zundel_steps=[]
    for i in range(data.shape[0]):
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %% [markdown]
# **Création et scaling des descripteurs**

# %%
X_train_CMe=create_CM_eigen(X_train)
X_test_CMe=create_CM_eigen(X_test)
X_train_CMe_red=scaler.fit_transform(X_train_CMe)
X_test_CMe_red=scaler.fit_transform(X_test_CMe)

# %% [markdown]
# ### **Exploration statistique du nouveau descripteur**

# %%
pd.DataFrame(X_train_CMe).describe()
# Out:
#                  0            1            2            3            4  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     88.701505    59.682468     0.417565     0.242826     0.173534
# std       0.183102     0.177838     0.009194     0.006553     0.004729
# min      87.977655    58.979104     0.388062     0.219960     0.157364
# 25%      88.582326    59.559842     0.411327     0.238478     0.170198
# 50%      88.705274    59.678830     0.417490     0.242890     0.173346
# 75%      88.827863    59.797708     0.423616     0.247244     0.176679
# max      89.435804    60.383806     0.453386     0.267795     0.194823
#
#                  5            6
# count  7500.000000  7500.000000
# mean      0.162842     0.152649
# std       0.004301     0.005124
# min       0.143278     0.131788
# 25%       0.159958     0.149336
# 50%       0.162958     0.152911
# 75%       0.165817     0.156172
# max       0.178765     0.169214

# %%
#plot des corrélations

sns.pairplot(pd.DataFrame(X_train_CMe_red), corner=True)

# %% [markdown]
# ## SOAP ##

# %%
from dscribe.descriptors import SOAP
from ase.io import read
from sklearn.decomposition import PCA
from dscribe.kernels import AverageKernel

#genere un ensemble de vecteurs soap avec PCA
def SOAP_Vectors(xyz_filename,cutoff=5., n_max=6, l_max=6, zeta=2.0, atom_sigma=0.5, pca_d=25):
    # read the xyz file
    frames = read(xyz_filename, ':')
    n_frames = len(frames)

    # species and PBC
    global_species = []
    for frame in frames:
        global_species.extend(frame.get_atomic_numbers())
        frame.set_pbc(True)
    global_species = np.unique(global_species)
    print("loaded xyz file: {fn}, with {n_frames} frames and elements: {ele}".format(fn=xyz_filename, n_frames=n_frames,
                                                                                     ele=global_species))
    # soap
    desc = SOAP(rcut=cutoff, nmax=n_max, lmax=l_max, sigma=atom_sigma, species=global_species, periodic=False,
                average="off")
    soap_vectors = desc.create(frames)
    data_2d = np.array([features_2d.flatten() for features_2d in soap_vectors])
    pca = PCA(n_components=pca_d)
    pca.fit(data_2d)
    Soap_pca = pca.transform(data_2d)
    return Soap_pca,pca

#genere un ensemble de vecteurs soap avec une PCA deja entrainée pour une unique configuration atomique 
def SOAP_Vector(xyz_filename, pca,cutoff=5., n_max=6, l_max=6, zeta=2.0,atom_sigma=0.5):
    # read the xyz file
    frames = read(xyz_filename, ':')
    # species and PBC
    global_species = []
    for frame in frames:
        global_species.extend(frame.get_atomic_numbers())
        frame.set_pbc(True)
    global_species = np.unique(global_species)
    # soap
    desc = SOAP(rcut=cutoff, nmax=n_max, lmax=l_max, sigma=atom_sigma, species=global_species, periodic=False,average="off")
    soap_vectors = desc.create(frames)
    data_2d = np.array([soap_vectors.flatten()]).reshape(1, -1)
    Soap_pca = pca.transform(data_2d)

    return Soap_pca

# %% [markdown]
# **Séparation des données et création des descripteurs**

# %%
Soap_pca,pca=SOAP_Vectors("new_positions_sparse.xyz", cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca_d=15)
# Out:
# loaded xyz file: new_positions_sparse.xyz, with 10000 frames and elements: [1 8]

# %%
X_train_soap, X_test_soap, y_train, y_test=train_test_split(Soap_pca, energies, random_state=22)

X_train_soap_red=scaler.fit_transform(X_train_soap)
X_test_soap_red=scaler.fit_transform(X_test_soap)

yscaler=StandardScaler()
y_train=yscaler.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test=yscaler.fit_transform(y_test.to_numpy().reshape(-1, 1))

# %%
#Plot de la variance totale expliquée
plt.plot(np.cumsum(pca.explained_variance_ratio_), linestyle='--', marker='o')
plt.xlabel("Nombre de composantes")
plt.ylabel('Variance totale expliquée')
# Out:
# Text(0, 0.5, 'Variance totale expliquée')

# %% [markdown]
# # Modèles et apprentissage #
#
# ## **Prédicteur naif** ##

# %%
#retourne la valeur moyenne
def naive_predictor(xtrain, ytrain):
    return np.ones((xtrain.shape[0],))*ytrain.mean()

#résultats du modèle naïf (ici on peut utiliser n'importe quel descripteur)
y_fit=naive_predictor(X_train, y_train)
y_pred_test=naive_predictor(X_test,y_train)

#erreur quadratique moyenne
mse=mean_squared_error(np.array(y_train), y_fit)
mse_test=mean_squared_error(np.array(y_test), y_pred_test)

print("Erreur quadratique moyenne sur les données d'entraînement : ", mse)
print("Erreur quadratique moyenne sur les données de test : ",mse_test)
# Out:
# Erreur quadratique moyenne sur les données d'entraînement :  1.0
# Erreur quadratique moyenne sur les données de test :  1.0

# %% [markdown]
# Plot des y_test en fonction de y_pred

# %%
fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')

#on récupère les limites du plot
xmin, xmax=plt.xlim()
ymin, ymax=plt.ylim()

#ligne du prédicteur idéal
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Modèle naïf")

plt.show()

# %% [markdown]
# ## **Modèle linéaire** ##

# %% [markdown]
# ### Modèle de regession Ridge avec recherche sur grille ###

# %%
#Test avec Matrices de Coulomb

#paramètres testés
a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_CMe_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("MSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_CMe_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print("MSE sur les données de test : ", mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 0.7911226116852113
# 0.7564859632710091

# %%
#Test avec PIV 
from sklearn.linear_model import RidgeCV

a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_PIV_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("MSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_PIV_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print("MSE sur les données de test : ", mse_test_rcv)
# Out:
# Best regularization parameter : 31.009266359319234
# RMSE moyen: 0.7326136001125692
# 0.736698723424327

# %% [markdown]
# ### Modèle linéaire en dimension augmentée (polynomial Features) ###

# %%
mse_list=[] #liste qui stocke la mse pour le train set
mse_test_list=[] #idem pour le test set
for d in range(1,5): #on teste des degrés de 1 à 5
    poly=PolynomialFeatures(degree=d)
    Zmodif=poly.fit_transform(X_train_CMe_red)
    Zmodif_test=poly.fit_transform(X_test_CMe_red)
    
    #recherche sur grille
    a=np.logspace(-10, 10, 1000)
    model=RidgeCV(alphas=a)
    model.fit(Zmodif, y_train)

    print("Best regularization parameter :", model.alpha_)
    print("MSE moyen:", -model.best_score_)

    y_pred_test_rcv=model.predict(Zmodif_test)
    mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
    print("MSE sur le set de test :", mse_test_rcv)
    
    #stockage des meilleurs scores
    mse_list.append(-model.best_score_)
    mse_test_list.append(mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 0.7911226116852113
# 0.7564859632710083
# Best regularization parameter : 14.162866162991973
# RMSE moyen: 0.5399559357654161
# 0.5213666113616616
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 0.5402247037401428
# 0.5217424378170666
# Best regularization parameter : 42.818517986524064
# RMSE moyen: 0.5518063896545434
# 0.5342317688277887

# %%
#plot des résultats
plt.plot([1]*len(mse_list), label='modèle naif')
plt.plot(mse_list, label="train")
plt.plot(mse_test_list, label='test')
plt.legend()
plt.ylabel("MSE")
plt.xlabel("Dimension du polynome")
# Out:
# Text(0.5, 0, 'Dimension du polynome')

# %% [markdown]
# ## Kernel Ridge Regression - Recherche sur grille ##

# %% [markdown]
# ### PIV ###

# %%
krrPIV = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-13, -10,4),
                                                                          "gamma": np.logspace(-7, -5, 4)})
krrPIV.fit(X_train_PIV_red, y_train)

y_pred_test_krr_PIV=krrPIV.predict(X_test_PIV_red)

mse_test_PIV=mean_squared_error(np.array(y_test), y_pred_test_krr_PIV)
b_params_PIV=krrPIV.best_params_
print("MSE : ", mse_test_PIV)
print("Meilleurs paramètres : ",b_params_PIV)
# Out:
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:251: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=8.84873e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.39844e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.06154e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=9.2265e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.38095e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=8.93483e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.79989e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.06628e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=9.30431e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.76602e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=3.15893e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.90176e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.94503e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=2.96933e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=2.98854e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.56393e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.47988e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.50105e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.49899e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=8.8057e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.57119e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.61143e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=9.69685e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.59167e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.41505e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.46261e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.07986e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=9.3529e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=7.43727e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=1.06591e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=8.3813e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:249: LinAlgWarning: Ill-conditioned matrix (rcond=9.73476e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# 0.5843809304285971
# {'alpha': 1e-10, 'gamma': 1e-05}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_PIV=krrPIV.predict(X_test_PIV_red)
plt.scatter(y_pred_test_krr_PIV,  y_test, marker='.', color='purple',alpha=0.3)
mse_test_PIV=mean_squared_error(np.array(y_test), y_pred_test_krr_PIV)
print(mse_test_PIV)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("PIV")
plt.show()
print(X_train_PIV_red.shape)
# Out:
# 0.5843815079695335
# (7500, 10)

# %% [markdown]
# ### Coulomb Matrix ###

# %%
krrcm = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-11, -10,4),
                                                                          "gamma": np.logspace(-5, -3,4)})
krrcm.fit(X_train_CM_red, y_train)

y_pred_test_krr_cm=krrcm.predict(X_test_CM_red)

mse_test_cm=mean_squared_error(np.array(y_test), y_pred_test_krr_cm)
b_params_cm=krrcm.best_params_
print("MSE : ", mse_test_cm)
print("Meilleurs paramètres : ",b_params_cm)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.08106e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.09593e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.09094e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.06055e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.88952e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.33993e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.73668e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.69697e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.65629e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.75428e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# 0.9167550999982191
# {'alpha': 4.641588833612773e-11, 'gamma': 0.001}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_cm=krrcm.predict(X_test_CM_red)
plt.scatter(y_pred_test_krr_cm,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.title("Coulomb Matrix (l2 sorted)")
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.show()
# Out:
# (7500, 49)

# %% [markdown]
# ### Coulomb Matrix Eigenvalues ###

# %%
krrcmeig = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-10, -9,4),
                                                                          "gamma": np.logspace(-5, -4,4)})
krrcmeig.fit(X_train_CMe_red, y_train)

y_pred_test_krr_cmeig=krrcmeig.predict(X_test_CMe_red)

mse_test_cmeig=mean_squared_error(np.array(y_test), y_pred_test_krr_cmeig)
b_params_cmeig=krrcmeig.best_params_
print("MSE : ", mse_test_cmeig)
print("Meilleurs paramètres : ",b_params_cmeig)
# Out:
# 0.5208119458707361
# {'alpha': 2.1544346900318867e-10, 'gamma': 1e-05}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_cmeig=krrcmeig.predict(X_test_CMe_red)
plt.scatter(y_pred_test_krr_cmeig,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Coulomb Matrix (Eigenvalues)")
plt.show()
# Out:
# (7500, 7)

# %% [markdown]
# ### Comparaison CM/PIV ###

# %%
#tirer des points au hasard dans le dataset et créer les descripteurs PIV et CMeig associés et retourner la valeur de la prediction
def random(dataset, energies, PIV, CMeig, N):
    idx=np.random.randint(len(dataset), size=N) #index tirés au hasard
    y_pred_PIV=krrPIV.predict(PIV[idx])
    y_pred_cmeig=krrcmeig.predict(CMeig[idx])
    
    return energies[idx], y_pred_PIV, y_pred_cmeig
    
ysample, PIVsample, CMeigsample = random(X_test, y_test, X_test_PIV_red, X_test_CMe_red, 15)

# %%
#Plot des points tirés au hasard

fig=plt.figure(figsize=(11, 5))
plt.subplot(1, 2, 1)
plt.xlabel('$y_{pred}$', fontsize=15)
plt.ylabel('$y_{test}$', fontsize=15)
colors = plt.cm.jet(np.linspace(0, 1, len(ysample)))
plt.scatter(y_pred_test_krr_PIV,  y_test, marker='.', color='purple',alpha=0.3)
plt.scatter(PIVsample, ysample, marker='.', color=colors,alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("PIV")

plt.subplot(1, 2, 2)
plt.scatter(y_pred_test_krr_cmeig,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$', fontsize=15)
plt.ylabel('$y_{test}$', fontsize=15)
plt.scatter(CMeigsample, ysample, marker='.', color=colors,alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Coulomb Matrix (Eigenvalues)")
plt.show()

# %%
# plot y_CM en fct de y_PIV + 10 points en cyan tirés au hasard

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test_krr_cmeig,  y_pred_test_krr_PIV, marker='.', color='purple',alpha=0.2)
plt.scatter(CMeigsample, PIVsample, marker='.', color='cyan',alpha=1)
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')

plt.xlabel('$y_{CM}$', fontsize=15)
plt.ylabel('$y_{PIV}$', fontsize=15)
#plt.scatter(CMeigsample, ysample, marker='.', color=colors,alpha=1)

plt.title("Prédictions PIV vs CM (eigenvalues)")
plt.show()

# %%
#histogramme des distances entre les deux modèles

sns.distplot(pd.DataFrame((PIVsample-CMeigsample)), color="blue")
plt.xlabel(r'Distance $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des distances")
plt.show()

print("Ecart type : ", np.std(pd.DataFrame((PIVsample-CMeigsample))))

# %% [markdown]
# ### SOAP ###

# %%
krrsoap = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-11.5, -10.5,4),
                                                                          "gamma": np.logspace(-7,-5,6)})
krrsoap.fit(X_train_soap_red, y_train)

y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)

mse_test_soap=mean_squared_error(np.array(y_test), y_pred_test_krr_soap)
b_params_soap=krrsoap.best_params_
print("MSE : ", mse_test_soap)
print(b_params_soap)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.24162e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.09026e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.10611e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.7371e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.13639e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.99501e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.39043e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.11706e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.27656e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.26587e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.11991e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.1449e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.22081e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.72126e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.1441e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.65234e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.69349e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.76044e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.17741e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.66791e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.23438e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.36554e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.34301e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.8129e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.27902e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.17686e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.35818e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.34833e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.32544e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=2.325e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.27335e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=8.95634e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.93111e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.93268e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=7.03641e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.84265e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.01962e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=9.80785e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.79667e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.9313e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.25587e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.24118e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.18548e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=5.18514e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# 0.23914669496495972
# {'alpha': 1.4677992676220676e-11, 'gamma': 1e-05}

# %%
fig=plt.figure(figsize=(5,5))
y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)
plt.scatter(y_pred_test_krr_soap,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("SOAP")
plt.show()
# Out:
# (2500, 12)

# %% [markdown]
# ## **Réseau de neurones** ##

# %%
#on renomme les variables
X_soap_red=X_train_soap_red
y_soap=y_train

#création du modèle
model=Sequential()
model.add(Dense(units=15, activation='tanh', input_shape=(15,)))
model.add(Dense(units=12, activation='tanh'))
model.add(Dense(units=1))
model.summary()

model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])

Hist=model.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist.history['loss'][1:])
plt.plot(Hist.history['val_loss'][1:])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 15)                195
#
#  dense_4 (Dense)             (None, 12)                192
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 400
# Trainable params: 400
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 1s 4ms/step - loss: 1.0755 - mean_squared_error: 1.0755 - val_loss: 0.8700 - val_mean_squared_error: 0.8700
# Epoch 2/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.9059 - mean_squared_error: 0.9059 - val_loss: 0.8367 - val_mean_squared_error: 0.8367
# Epoch 3/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8840 - mean_squared_error: 0.8840 - val_loss: 0.8205 - val_mean_squared_error: 0.8205
# Epoch 4/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3180 - mean_squared_error: 0.3180 - val_loss: 0.3624 - val_mean_squared_error: 0.3624
# Epoch 60/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3171 - mean_squared_error: 0.3171 - val_loss: 0.3643 - val_mean_squared_error: 0.3643
# Epoch 61/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3153 - mean_squared_error: 0.3153 - val_loss: 0.3613 - val_mean_squared_error: 0.3613
# Epoch 62/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3157 - mean_squared_error: 0.3157 - val_loss: 0.3690 - val_mean_squared_error: 0.3690
# Epoch 63/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3155 - mean_squared_error: 0.3155 - val_loss: 0.3622 - val_mean_squared_error: 0.3622
# Epoch 64/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3146 - mean_squared_error: 0.3146 - val_loss: 0.3625 - val_mean_squared_error: 0.3625
# Epoch 65/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3135 - mean_squared_error: 0.3135 - val_loss: 0.3621 - val_mean_squared_error: 0.3621
# Epoch 66/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3128 - mean_squared_error: 0.3128 - val_loss: 0.3616 - val_mean_squared_error: 0.3616
# Epoch 67/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3125 - mean_squared_error: 0.3125 - val_loss: 0.3686 - val_mean_squared_error: 0.3686
# Epoch 68/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3115 - mean_squared_error: 0.3115 - val_loss: 0.3625 - val_mean_squared_error: 0.3625
# Epoch 69/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3113 - mean_squared_error: 0.3113 - val_loss: 0.3532 - val_mean_squared_error: 0.3532
# Epoch 70/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3121 - mean_squared_error: 0.3121 - val_loss: 0.3587 - val_mean_squared_error: 0.3587
# Epoch 71/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3110 - mean_squared_error: 0.3110 - val_loss: 0.3601 - val_mean_squared_error: 0.3601
# Epoch 72/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3094 - mean_squared_error: 0.3094 - val_loss: 0.3600 - val_mean_squared_error: 0.3600
# Epoch 73/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3107 - mean_squared_error: 0.3107 - val_loss: 0.3565 - val_mean_squared_error: 0.3565
# Epoch 74/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3082 - mean_squared_error: 0.3082 - val_loss: 0.3579 - val_mean_squared_error: 0.3579
# Epoch 75/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3083 - mean_squared_error: 0.3083 - val_loss: 0.3585 - val_mean_squared_error: 0.3585
# Epoch 76/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3075 - mean_squared_error: 0.3075 - val_loss: 0.3523 - val_mean_squared_error: 0.3523
# Epoch 77/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3065 - mean_squared_error: 0.3065 - val_loss: 0.3545 - val_mean_squared_error: 0.3545
# Epoch 78/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3076 - mean_squared_error: 0.3076 - val_loss: 0.3623 - val_mean_squared_error: 0.3623
# Epoch 79/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3076 - mean_squared_error: 0.3076 - val_loss: 0.3565 - val_mean_squared_error: 0.3565
# Epoch 80/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3053 - mean_squared_error: 0.3053 - val_loss: 0.3501 - val_mean_squared_error: 0.3501
# Epoch 81/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3050 - mean_squared_error: 0.3050 - val_loss: 0.3503 - val_mean_squared_error: 0.3503
# Epoch 82/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3042 - mean_squared_error: 0.3042 - val_loss: 0.3480 - val_mean_squared_error: 0.3480
# Epoch 83/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3050 - mean_squared_error: 0.3050 - val_loss: 0.3545 - val_mean_squared_error: 0.3545
# Epoch 84/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3048 - mean_squared_error: 0.3048 - val_loss: 0.3509 - val_mean_squared_error: 0.3509
# Epoch 85/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3055 - mean_squared_error: 0.3055 - val_loss: 0.3546 - val_mean_squared_error: 0.3546
# Epoch 86/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3053 - mean_squared_error: 0.3053 - val_loss: 0.3488 - val_mean_squared_error: 0.3488
# Epoch 87/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2874 - mean_squared_error: 0.2874 - val_loss: 0.3457 - val_mean_squared_error: 0.3457
# Epoch 198/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2884 - mean_squared_error: 0.2884 - val_loss: 0.3416 - val_mean_squared_error: 0.3416
# Epoch 199/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2866 - mean_squared_error: 0.2866 - val_loss: 0.3314 - val_mean_squared_error: 0.3314
# Epoch 200/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2855 - mean_squared_error: 0.2855 - val_loss: 0.3320 - val_mean_squared_error: 0.3320
# Epoch 201/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2878 - mean_squared_error: 0.2878 - val_loss: 0.3377 - val_mean_squared_error: 0.3377
# Epoch 202/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2875 - mean_squared_error: 0.2875 - val_loss: 0.3376 - val_mean_squared_error: 0.3376
# Epoch 203/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2858 - mean_squared_error: 0.2858 - val_loss: 0.3326 - val_mean_squared_error: 0.3326
# Epoch 204/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2866 - mean_squared_error: 0.2866 - val_loss: 0.3361 - val_mean_squared_error: 0.3361
# Epoch 205/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.3281 - val_mean_squared_error: 0.3281
# Epoch 206/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2855 - mean_squared_error: 0.2855 - val_loss: 0.3318 - val_mean_squared_error: 0.3318
# Epoch 207/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2858 - mean_squared_error: 0.2858 - val_loss: 0.3391 - val_mean_squared_error: 0.3391
# Epoch 208/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.3303 - val_mean_squared_error: 0.3303
# Epoch 209/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2859 - mean_squared_error: 0.2859 - val_loss: 0.3353 - val_mean_squared_error: 0.3353
# Epoch 210/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2862 - mean_squared_error: 0.2862 - val_loss: 0.3331 - val_mean_squared_error: 0.3331
# Epoch 211/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2876 - mean_squared_error: 0.2876 - val_loss: 0.3340 - val_mean_squared_error: 0.3340
# Epoch 212/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2874 - mean_squared_error: 0.2874 - val_loss: 0.3310 - val_mean_squared_error: 0.3310
# Epoch 213/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2842 - mean_squared_error: 0.2842 - val_loss: 0.3355 - val_mean_squared_error: 0.3355
# Epoch 214/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2867 - mean_squared_error: 0.2867 - val_loss: 0.3321 - val_mean_squared_error: 0.3321
# Epoch 215/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2861 - mean_squared_error: 0.2861 - val_loss: 0.3345 - val_mean_squared_error: 0.3345
# Epoch 216/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2852 - mean_squared_error: 0.2852 - val_loss: 0.3339 - val_mean_squared_error: 0.3339
# Epoch 217/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.3379 - val_mean_squared_error: 0.3379
# Epoch 218/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2860 - mean_squared_error: 0.2860 - val_loss: 0.3350 - val_mean_squared_error: 0.3350
# Epoch 219/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2849 - mean_squared_error: 0.2849 - val_loss: 0.3298 - val_mean_squared_error: 0.3298
# Epoch 220/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3341 - val_mean_squared_error: 0.3341
# Epoch 221/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2844 - mean_squared_error: 0.2844 - val_loss: 0.3371 - val_mean_squared_error: 0.3371
# Epoch 222/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2854 - mean_squared_error: 0.2854 - val_loss: 0.3315 - val_mean_squared_error: 0.3315
# Epoch 223/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3493 - val_mean_squared_error: 0.3493
# Epoch 224/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2886 - mean_squared_error: 0.2886 - val_loss: 0.3289 - val_mean_squared_error: 0.3289
# Epoch 225/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2846 - mean_squared_error: 0.2846 - val_loss: 0.3361 - val_mean_squared_error: 0.3361
# Epoch 226/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2841 - mean_squared_error: 0.2841 - val_loss: 0.3339 - val_mean_squared_error: 0.3339
# Epoch 227/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2851 - mean_squared_error: 0.2851 - val_loss: 0.3296 - val_mean_squared_error: 0.3296
# Epoch 228/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2853 - mean_squared_error: 0.2853 - val_loss: 0.3460 - val_mean_squared_error: 0.3460
# Epoch 229/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2861 - mean_squared_error: 0.2861 - val_loss: 0.3300 - val_mean_squared_error: 0.3300
# Epoch 230/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2852 - mean_squared_error: 0.2852 - val_loss: 0.3350 - val_mean_squared_error: 0.3350
# Epoch 231/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2850 - mean_squared_error: 0.2850 - val_loss: 0.3293 - val_mean_squared_error: 0.3293
# Epoch 232/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3256 - val_mean_squared_error: 0.3256
# Epoch 233/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2839 - mean_squared_error: 0.2839 - val_loss: 0.3348 - val_mean_squared_error: 0.3348
# Epoch 234/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2843 - mean_squared_error: 0.2843 - val_loss: 0.3319 - val_mean_squared_error: 0.3319
# Epoch 235/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2860 - mean_squared_error: 0.2860 - val_loss: 0.3301 - val_mean_squared_error: 0.3301
# Epoch 236/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2849 - mean_squared_error: 0.2849 - val_loss: 0.3354 - val_mean_squared_error: 0.3354
# Epoch 237/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2866 - mean_squared_error: 0.2866 - val_loss: 0.3353 - val_mean_squared_error: 0.3353
# Epoch 238/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2851 - mean_squared_error: 0.2851 - val_loss: 0.3317 - val_mean_squared_error: 0.3317
# Epoch 239/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2838 - mean_squared_error: 0.2838 - val_loss: 0.3331 - val_mean_squared_error: 0.3331
# Epoch 240/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2844 - mean_squared_error: 0.2844 - val_loss: 0.3320 - val_mean_squared_error: 0.3320
# Epoch 241/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2833 - mean_squared_error: 0.2833 - val_loss: 0.3338 - val_mean_squared_error: 0.3338
# Epoch 242/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2823 - mean_squared_error: 0.2823 - val_loss: 0.3273 - val_mean_squared_error: 0.3273
# Epoch 243/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3354 - val_mean_squared_error: 0.3354
# Epoch 244/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.3282 - val_mean_squared_error: 0.3282
# Epoch 245/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2832 - mean_squared_error: 0.2832 - val_loss: 0.3338 - val_mean_squared_error: 0.3338
# Epoch 246/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2834 - mean_squared_error: 0.2834 - val_loss: 0.3402 - val_mean_squared_error: 0.3402
# Epoch 247/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2837 - mean_squared_error: 0.2837 - val_loss: 0.3340 - val_mean_squared_error: 0.3340
# Epoch 248/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2828 - mean_squared_error: 0.2828 - val_loss: 0.3379 - val_mean_squared_error: 0.3379
# Epoch 249/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2841 - mean_squared_error: 0.2841 - val_loss: 0.3326 - val_mean_squared_error: 0.3326
# Epoch 250/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.3313 - val_mean_squared_error: 0.3313
# Epoch 251/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2843 - mean_squared_error: 0.2843 - val_loss: 0.3402 - val_mean_squared_error: 0.3402
# Epoch 252/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2835 - mean_squared_error: 0.2835 - val_loss: 0.3356 - val_mean_squared_error: 0.3356
# Epoch 253/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2854 - mean_squared_error: 0.2854 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 254/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2821 - mean_squared_error: 0.2821 - val_loss: 0.3299 - val_mean_squared_error: 0.3299
# Epoch 282/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2831 - mean_squared_error: 0.2831 - val_loss: 0.3444 - val_mean_squared_error: 0.3444
# Epoch 283/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2833 - mean_squared_error: 0.2833 - val_loss: 0.3420 - val_mean_squared_error: 0.3420
# Epoch 284/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2879 - mean_squared_error: 0.2879 - val_loss: 0.3231 - val_mean_squared_error: 0.3231
# Epoch 285/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2814 - mean_squared_error: 0.2814 - val_loss: 0.3289 - val_mean_squared_error: 0.3289
# Epoch 286/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2806 - mean_squared_error: 0.2806 - val_loss: 0.3282 - val_mean_squared_error: 0.3282
# Epoch 287/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2807 - mean_squared_error: 0.2807 - val_loss: 0.3270 - val_mean_squared_error: 0.3270
# Epoch 288/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2836 - mean_squared_error: 0.2836 - val_loss: 0.3249 - val_mean_squared_error: 0.3249
# Epoch 289/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2810 - mean_squared_error: 0.2810 - val_loss: 0.3258 - val_mean_squared_error: 0.3258
# Epoch 290/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2824 - mean_squared_error: 0.2824 - val_loss: 0.3257 - val_mean_squared_error: 0.3257
# Epoch 291/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2816 - mean_squared_error: 0.2816 - val_loss: 0.3304 - val_mean_squared_error: 0.3304
# Epoch 292/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2815 - mean_squared_error: 0.2815 - val_loss: 0.3307 - val_mean_squared_error: 0.3307
# Epoch 293/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2823 - mean_squared_error: 0.2823 - val_loss: 0.3305 - val_mean_squared_error: 0.3305
# Epoch 294/300
# 94/94 [==============================] - 0s 3ms/step - loss: 0.2847 - mean_squared_error: 0.2847 - val_loss: 0.3264 - val_mean_squared_error: 0.3264
# Epoch 295/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2818 - mean_squared_error: 0.2818 - val_loss: 0.3300 - val_mean_squared_error: 0.3300
# Epoch 296/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2821 - mean_squared_error: 0.2821 - val_loss: 0.3317 - val_mean_squared_error: 0.3317
# Epoch 297/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2835 - mean_squared_error: 0.2835 - val_loss: 0.3301 - val_mean_squared_error: 0.3301
# Epoch 298/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2825 - mean_squared_error: 0.2825 - val_loss: 0.3247 - val_mean_squared_error: 0.3247
# Epoch 299/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2822 - mean_squared_error: 0.2822 - val_loss: 0.3249 - val_mean_squared_error: 0.3249
# Epoch 300/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2838 - mean_squared_error: 0.2838 - val_loss: 0.3297 - val_mean_squared_error: 0.3297

# %% [markdown]
# ### Modèle régularisé ###

# %%
model_reg=Sequential()
model_reg.add(Dense(units=15, activation='tanh', input_shape=(15,), kernel_regularizer=regularizers.l2(0.06)))

model_reg.add(Dense(units=12, activation='tanh'))
model_reg.add(Dense(units=1))
model_reg.summary()

model_reg.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])
Hist_reg=model_reg.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist_reg.history['loss'][1:])
plt.plot(Hist_reg.history['val_loss'][1:])
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_66 (Dense)            (None, 15)                195
#
#  dense_67 (Dense)            (None, 12)                192
#
#  dense_68 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 400
# Trainable params: 400
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
#
300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3603 - mean_squared_error: 0.3202 - val_loss: 0.3788 - val_mean_squared_error: 0.3386
# Epoch 276/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3569 - mean_squared_error: 0.3167 - val_loss: 0.3862 - val_mean_squared_error: 0.3461
# Epoch 277/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3600 - mean_squared_error: 0.3198 - val_loss: 0.3727 - val_mean_squared_error: 0.3326
# Epoch 278/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3608 - mean_squared_error: 0.3207 - val_loss: 0.3947 - val_mean_squared_error: 0.3548
# Epoch 279/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3606 - mean_squared_error: 0.3206 - val_loss: 0.3893 - val_mean_squared_error: 0.3491
# Epoch 280/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3583 - mean_squared_error: 0.3182 - val_loss: 0.3803 - val_mean_squared_error: 0.3402
# Epoch 281/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3606 - mean_squared_error: 0.3205 - val_loss: 0.3888 - val_mean_squared_error: 0.3487
# Epoch 282/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3614 - mean_squared_error: 0.3211 - val_loss: 0.4019 - val_mean_squared_error: 0.3618
# Epoch 283/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3574 - mean_squared_error: 0.3172 - val_loss: 0.3725 - val_mean_squared_error: 0.3324
# Epoch 284/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3566 - mean_squared_error: 0.3165 - val_loss: 0.3693 - val_mean_squared_error: 0.3292
# Epoch 285/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3554 - mean_squared_error: 0.3153 - val_loss: 0.3838 - val_mean_squared_error: 0.3437
# Epoch 286/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3542 - mean_squared_error: 0.3142 - val_loss: 0.3958 - val_mean_squared_error: 0.3557
# Epoch 287/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3588 - mean_squared_error: 0.3190 - val_loss: 0.3945 - val_mean_squared_error: 0.3545
# Epoch 288/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3578 - mean_squared_error: 0.3178 - val_loss: 0.3772 - val_mean_squared_error: 0.3371
# Epoch 289/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3572 - mean_squared_error: 0.3172 - val_loss: 0.3676 - val_mean_squared_error: 0.3277
# Epoch 290/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3609 - mean_squared_error: 0.3209 - val_loss: 0.4050 - val_mean_squared_error: 0.3651
# Epoch 291/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3587 - mean_squared_error: 0.3187 - val_loss: 0.3695 - val_mean_squared_error: 0.3297
# Epoch 292/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3608 - mean_squared_error: 0.3210 - val_loss: 0.4008 - val_mean_squared_error: 0.3612
# Epoch 293/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3572 - mean_squared_error: 0.3173 - val_loss: 0.3736 - val_mean_squared_error: 0.3337
# Epoch 294/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3575 - mean_squared_error: 0.3178 - val_loss: 0.3697 - val_mean_squared_error: 0.3299
# Epoch 295/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3596 - mean_squared_error: 0.3198 - val_loss: 0.3824 - val_mean_squared_error: 0.3425
# Epoch 296/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3550 - mean_squared_error: 0.3151 - val_loss: 0.3871 - val_mean_squared_error: 0.3471
# Epoch 297/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3555 - mean_squared_error: 0.3157 - val_loss: 0.3891 - val_mean_squared_error: 0.3492
# Epoch 298/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3593 - mean_squared_error: 0.3195 - val_loss: 0.3762 - val_mean_squared_error: 0.3366
# Epoch 299/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3540 - mean_squared_error: 0.3143 - val_loss: 0.3833 - val_mean_squared_error: 0.3434
# Epoch 300/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3560 - mean_squared_error: 0.3162 - val_loss: 0.3781 - val_mean_squared_error: 0.3385

# %% [markdown]
# ### Modèle dropout ###

# %%
model_drop=Sequential()
model_drop.add(Dense(units=15, activation='tanh', input_shape=(15,), kernel_regularizer=regularizers.l2(0.065)))
model.add(Dropout(0.2))
model_drop.add(Dense(units=12, activation='tanh'))
model_drop.add(Dense(units=1))
model_drop.summary()

model_drop.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_squared_error'])
Hist_drop=model_drop.fit(X_soap_red, y_soap, epochs=300, batch_size=64, validation_split=0.2)

plt.plot(Hist_drop.history['loss'][1:])
plt.plot(Hist_drop.history['val_loss'][1:])
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_69 (Dense)            (None, 15)                195
#
#  dense_70 (Dense)            (None, 12)                192
#
#  dense_71 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 400
# Trainable params: 400
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 1s 3ms/step - loss: 1.5935 - mean_squared_error: 1.0524 - val_loss: 1.3293 - val_mean_squared_error: 0.8791
# Epoch 2/300
# 94/94 [==============================] - 0s 1ms/step - loss: 1.2895 - mean_squared_error: 0.9148 - val_loss: 1.1438 - val_mean_squared_error: 0.8380
# Epoch 3/300
# 94/94 [==============================] - 0s 1ms/step - loss: 1.1416 - mean_squared_error: 0.8875 - val_loss: 1.0320 - val_mean_squared_error: 0.8247
# Epoch 4/300
# 94/94 [==============================] - 0s 2ms/step - loss: 1.0518 - mean_squared_error: 0.8775 - val_loss: 0.9648 - val_mean_squared_error: 0.8203
# Epoch 5/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.9931 - mean_squared_error: 0.8694 - val_loss: 0.9146 - val_mean_squared_error: 0.8091
# Epoch 6/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.9561 - mean_squared_error: 0.8636 - val_loss: 0.8877 - val_mean_squared_error: 0.8064
# Epoch 7/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.9312 - mean_squared_error: 0.8580 - val_loss: 0.8694 - val_mean_squared_error: 0.8027
# Epoch 8/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.9118 - mean_squared_error: 0.8500 - val_loss: 0.8546 - val_mean_squared_error: 0.7972
# Epoch 9/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.8952 - mean_squared_error: 0.8403 - val_loss: 0.8382 - val_mean_squared_error: 0.7860
# Epoch 10/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.8820 - mean_squared_error: 0.8308 - val_loss: 0.8235 - val_mean_squared_error: 0.7732
# Epoch 11/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.8675 - mean_squared_error: 0.8180 - val_loss: 0.8152 - val_mean_squared_error: 0.7662
# Epoch 12/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8531 - mean_squared_error: 0.8040 - val_loss: 0.8185 - val_mean_squared_error: 0.7690
# Epoch 13/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.8418 - mean_squared_error: 0.7923 - val_loss: 0.8013 - val_mean_squared_error: 0.7517
# Epoch 14/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8285 - mean_squared_error: 0.7779 - val_loss: 0.7915 - val_mean_squared_error: 0.7406
# Epoch 15/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8164 - mean_squared_error: 0.7652 - val_loss: 0.7746 - val_mean_squared_error: 0.7227
# Epoch 16/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.8045 - mean_squared_error: 0.7516 - val_loss: 0.7615 - val_mean_squared_error: 0.7082
# Epoch 17/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7906 - mean_squared_error: 0.7366 - val_loss: 0.7618 - val_mean_squared_error: 0.7067
# Epoch 18/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7749 - mean_squared_error: 0.7191 - val_loss: 0.7486 - val_mean_squared_error: 0.6920
# Epoch 19/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.7615 - mean_squared_error: 0.7044 - val_loss: 0.7328 - val_mean_squared_error: 0.6751
# Epoch 20/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.7481 - mean_squared_error: 0.6893 - val_loss: 0.7237 - val_mean_squared_error: 0.6646
# Epoch 21/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.7316 - mean_squared_error: 0.6719 - val_loss: 0.7049 - val_mean_squared_error: 0.6442
# Epoch 22/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.
300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3426 - mean_squared_error: 0.3033 - val_loss: 0.3631 - val_mean_squared_error: 0.3238
# Epoch 241/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3433 - mean_squared_error: 0.3040 - val_loss: 0.3629 - val_mean_squared_error: 0.3237
# Epoch 242/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3434 - mean_squared_error: 0.3042 - val_loss: 0.3708 - val_mean_squared_error: 0.3318
# Epoch 243/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3446 - mean_squared_error: 0.3056 - val_loss: 0.3749 - val_mean_squared_error: 0.3356
# Epoch 244/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3458 - mean_squared_error: 0.3068 - val_loss: 0.3885 - val_mean_squared_error: 0.3496
# Epoch 245/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3426 - mean_squared_error: 0.3034 - val_loss: 0.3800 - val_mean_squared_error: 0.3408
# Epoch 246/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3429 - mean_squared_error: 0.3038 - val_loss: 0.3634 - val_mean_squared_error: 0.3244
# Epoch 247/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3435 - mean_squared_error: 0.3046 - val_loss: 0.3666 - val_mean_squared_error: 0.3279
# Epoch 248/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3440 - mean_squared_error: 0.3051 - val_loss: 0.3768 - val_mean_squared_error: 0.3379
# Epoch 249/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3467 - mean_squared_error: 0.3080 - val_loss: 0.3751 - val_mean_squared_error: 0.3364
# Epoch 250/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3392 - mean_squared_error: 0.3005 - val_loss: 0.3809 - val_mean_squared_error: 0.3422
# Epoch 251/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3436 - mean_squared_error: 0.3048 - val_loss: 0.3630 - val_mean_squared_error: 0.3242
# Epoch 252/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3398 - mean_squared_error: 0.3011 - val_loss: 0.3657 - val_mean_squared_error: 0.3270
# Epoch 253/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3438 - mean_squared_error: 0.3051 - val_loss: 0.3745 - val_mean_squared_error: 0.3358
# Epoch 254/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3439 - mean_squared_error: 0.3053 - val_loss: 0.3558 - val_mean_squared_error: 0.3171
# Epoch 255/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3448 - mean_squared_error: 0.3062 - val_loss: 0.3735 - val_mean_squared_error: 0.3350
# Epoch 256/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3422 - mean_squared_error: 0.3037 - val_loss: 0.3594 - val_mean_squared_error: 0.3209
# Epoch 257/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3409 - mean_squared_error: 0.3025 - val_loss: 0.3725 - val_mean_squared_error: 0.3341
# Epoch 258/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3440 - mean_squared_error: 0.3056 - val_loss: 0.3630 - val_mean_squared_error: 0.3248
# Epoch 259/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3421 - mean_squared_error: 0.3039 - val_loss: 0.3580 - val_mean_squared_error: 0.3197
# Epoch 260/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3430 - mean_squared_error: 0.3048 - val_loss: 0.3623 - val_mean_squared_error: 0.3238
# Epoch 261/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3407 - mean_squared_error: 0.3024 - val_loss: 0.3678 - val_mean_squared_error: 0.3295
# Epoch 262/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3422 - mean_squared_error: 0.3040 - val_loss: 0.3637 - val_mean_squared_error: 0.3254
# Epoch 263/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3418 - mean_squared_error: 0.3035 - val_loss: 0.3650 - val_mean_squared_error: 0.3268
# Epoch 264/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3385 - mean_squared_error: 0.3004 - val_loss: 0.3623 - val_mean_squared_error: 0.3241
# Epoch 265/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3408 - mean_squared_error: 0.3026 - val_loss: 0.3633 - val_mean_squared_error: 0.3253
# Epoch 266/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3377 - mean_squared_error: 0.2997 - val_loss: 0.3697 - val_mean_squared_error: 0.3316
# Epoch 267/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3415 - mean_squared_error: 0.3035 - val_loss: 0.3562 - val_mean_squared_error: 0.3184
# Epoch 268/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3401 - mean_squared_error: 0.3022 - val_loss: 0.3686 - val_mean_squared_error: 0.3307
# Epoch 269/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3402 - mean_squared_error: 0.3024 - val_loss: 0.3737 - val_mean_squared_error: 0.3360
# Epoch 270/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3419 - mean_squared_error: 0.3042 - val_loss: 0.3709 - val_mean_squared_error: 0.3331
# Epoch 271/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3388 - mean_squared_error: 0.3012 - val_loss: 0.3686 - val_mean_squared_error: 0.3309
# Epoch 272/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3371 - mean_squared_error: 0.2994 - val_loss: 0.3649 - val_mean_squared_error: 0.3272
# Epoch 273/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3397 - mean_squared_error: 0.3021 - val_loss: 0.3628 - val_mean_squared_error: 0.3254
# Epoch 274/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3420 - mean_squared_error: 0.3045 - val_loss: 0.3755 - val_mean_squared_error: 0.3380
# Epoch 275/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3412 - mean_squared_error: 0.3038 - val_loss: 0.3551 - val_mean_squared_error: 0.3178
# Epoch 276/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3408 - mean_squared_error: 0.3034 - val_loss: 0.3562 - val_mean_squared_error: 0.3188
# Epoch 277/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3411 - mean_squared_error: 0.3037 - val_loss: 0.3697 - val_mean_squared_error: 0.3324
# Epoch 278/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3400 - mean_squared_error: 0.3026 - val_loss: 0.3620 - val_mean_squared_error: 0.3248
# Epoch 279/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3389 - mean_squared_error: 0.3017 - val_loss: 0.3652 - val_mean_squared_error: 0.3279
# Epoch 280/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3400 - mean_squared_error: 0.3027 - val_loss: 0.3617 - val_mean_squared_error: 0.3244
# Epoch 281/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3434 - mean_squared_error: 0.3062 - val_loss: 0.3637 - val_mean_squared_error: 0.3266
# Epoch 282/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3405 - mean_squared_error: 0.3033 - val_loss: 0.3655 - val_mean_squared_error: 0.3285
# Epoch 283/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3413 - mean_squared_error: 0.3041 - val_loss: 0.3588 - val_mean_squared_error: 0.3218
# Epoch 284/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3422 - mean_squared_error: 0.3050 - val_loss: 0.3673 - val_mean_squared_error: 0.3300
# Epoch 285/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3379 - mean_squared_error: 0.3009 - val_loss: 0.3663 - val_mean_squared_error: 0.3290
# Epoch 286/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3419 - mean_squared_error: 0.3046 - val_loss: 0.3634 - val_mean_squared_error: 0.3261
# Epoch 287/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3381 - mean_squared_error: 0.3010 - val_loss: 0.3650 - val_mean_squared_error: 0.3278
# Epoch 288/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3409 - mean_squared_error: 0.3037 - val_loss: 0.3633 - val_mean_squared_error: 0.3263
# Epoch 289/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3431 - mean_squared_error: 0.3062 - val_loss: 0.3763 - val_mean_squared_error: 0.3394
# Epoch 290/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3405 - mean_squared_error: 0.3035 - val_loss: 0.3673 - val_mean_squared_error: 0.3304
# Epoch 291/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3396 - mean_squared_error: 0.3026 - val_loss: 0.3596 - val_mean_squared_error: 0.3227
# Epoch 292/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3397 - mean_squared_error: 0.3027 - val_loss: 0.3797 - val_mean_squared_error: 0.3427
# Epoch 293/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3418 - mean_squared_error: 0.3050 - val_loss: 0.3551 - val_mean_squared_error: 0.3183
# Epoch 294/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3407 - mean_squared_error: 0.3038 - val_loss: 0.3625 - val_mean_squared_error: 0.3256
# Epoch 295/300
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3390 - mean_squared_error: 0.3021 - val_loss: 0.3687 - val_mean_squared_error: 0.3320
# Epoch 296/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3388 - mean_squared_error: 0.3020 - val_loss: 0.3646 - val_mean_squared_error: 0.3277
# Epoch 297/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3423 - mean_squared_error: 0.3053 - val_loss: 0.3637 - val_mean_squared_error: 0.3267
# Epoch 298/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3392 - mean_squared_error: 0.3024 - val_loss: 0.3634 - val_mean_squared_error: 0.3267
# Epoch 299/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3370 - mean_squared_error: 0.3002 - val_loss: 0.3611 - val_mean_squared_error: 0.3245
# Epoch 300/300
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3393 - mean_squared_error: 0.3026 - val_loss: 0.3625 - val_mean_squared_error: 0.3260

# %% [markdown]
# ### Plot des courbes d'apprentissage des modèles ###

# %%
plt.plot(Hist.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()
print(np.min(Hist.history['val_mean_squared_error'][3:]))

plt.plot(Hist_reg.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist_reg.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()

print(np.min(Hist_reg.history['val_mean_squared_error'][3:]))

plt.plot(Hist_drop.history['mean_squared_error'][3:],label="entrainement")
plt.plot(Hist_drop.history['val_mean_squared_error'][3:],label="validation")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("MSE [u.a]")
plt.show()
print(np.min(Hist_drop.history['val_mean_squared_error'][3:]))
# Out:
# 0.2998196482658386
# 0.3277217745780945
# 0.3171394467353821

# %% [markdown]
# ### Résultats des modèles (plot y_pred y_test) ###

# %%
y_pred_test=model.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))
      
fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau de neurones")
plt.show()

y_pred_test=model_reg.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau avec regularisation l2")
plt.show()

y_pred_test=model_drop.predict(X_test_soap_red)
print((np.mean(np.square(y_pred_test- y_test))))

fig=plt.figure(figsize=(5,5))
plt.scatter(y_pred_test,  y_test, marker='.', color='purple',alpha=0.3)
plt.xlabel('$y_{pred}$')
plt.ylabel('$y_{test}$')
plt.plot([np.min(y_test), np.max(y_test)],[np.min(y_test), np.max(y_test)], color='black', linestyle='--')
plt.title("Reseau avec dropout")
plt.show()
# Out:
# 79/79 [==============================] - 0s 1ms/step
# 0.30963207300280876
# 79/79 [==============================] - 0s 890us/step
# 0.4972052626515637
# 79/79 [==============================] - 0s 1ms/step
# 0.4912122133433323

# %% [markdown]
# # Monte-Carlo #
# ## Calcul de "signatures" en énergie ##

# %%
y_pred_test_krr_soap=krrsoap.predict(X_test_soap_red)

y_pred_test=model.predict(X_test_soap_red)
plt.plot(y_pred_test_krr_soap,label='KRR')
plt.plot(y_pred_test,alpha=0.5,label='reseaux de neurones')
plt.xlabel('pas de simulation')
plt.ylabel('energies [u.a]')
plt.legend()
# Out:
# 79/79 [==============================] - 0s 947us/step

# %%
import seaborn as sns
sns.set_style("white")


# Plot
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(y_pred_test_krr_soap), color="blue", **kwargs,label="Kernel Ridge")
print("E moyen :",y_pred_test_krr_soap.mean()," +- ",y_pred_test_krr_soap.std())
sns.distplot(pd.DataFrame(y_test), color="orange", **kwargs,label="Y test")
print("E moyen :",y_test.mean()," +- ",y_test.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
plt.figure(figsize=(5,2), dpi= 200)

# plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(y_pred_test), color="blue", **kwargs,label="Réseau de neurones")
print("E moyen :",y_pred_test.mean()," +- ",y_pred_test.std())
sns.distplot(pd.DataFrame(y_test), color="orange", **kwargs,label="Y test")
print("E moyen :",y_test.mean()," +- ",y_test.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E moyen : -0.013792578125  +-  0.9073304102060944
# E moyen : 1.1368683772161604e-17  +-  1.0
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Zacharie\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E moyen : 0.04339237  +-  0.90607244
# E moyen : 1.1368683772161604e-17  +-  1.0

# %% [markdown]
# ## Generation des positions Monte-Carlo

# %%
#genere un fichier xyz
def generate_xyz(positions, filename):
  # Open the file for writing
  with open(filename, 'w') as f:
    for position in positions :
        # Write the number of atoms to the file
        f.write(str(len(position)) + '\n')
        f.write('\n')

        # Loop over the atomic positions
        for pos in position:
          # Write the atomic symbol and coordinates to the file
            if(pos[0]==0.):
                f.write('O ' + ' '.join(str(x) for x in pos[1:4]) + '\n')
            if(pos[0]==1.):
                f.write('H ' + ' '.join(str(x) for x in pos[1:4]) + '\n')
            
class Monte_Carlo:
    def __init__(self, dataset,model,yscaler,soapscaler,temp,E_min):
        self.model=model
        self.dataset=dataset
        self.yscaler=yscaler
        self.E_min=E_min
        self.E_temp=temp*Boltzmann/eV
        soap_vect,pca=SOAP_Vectors("new_positions_sparse.xyz", output_filename=None, cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca_d=15)
        self.soapscaler=soapscaler.fit(soap_vect)
        self.pca=pca
        O1 =self.dataset[:,0,1:4]
        O2 =self.dataset[:,1,1:4]
        H  =self.dataset[:,2,1:4]
        H11=self.dataset[:,5,1:4]
        H12=self.dataset[:,6,1:4]
        H21=self.dataset[:,3,1:4]
        H22=self.dataset[:,4,1:4]
        H_O1       = O1-H
        H_O2       = O2-H
        O1_H11     = H11-O1
        O1_H12     = H12-O1
        O2_H21     = H21-O2
        O2_H22     = H22-O2
        #ecart typique permis dans une etape
        self.H_O1_std       = 0.01*(O1-H).std()
        self.H_O2_std       = 0.01*(O2-H).std()
        self.O1_H11_std     = 0.01*(H11-O1).std()
        self.O1_H12_std     = 0.01*(H12-O1).std()
        self.O2_H21_std     = 0.01*(H21-O2).std()
        self.O2_H22_std     = 0.01*(H22-O2).std()
        self.O1_H_O2_std    = 0.01*(vg.angle(H_O1,H_O2)).std()
        self.H22_O2_H21_std = 0.01*(vg.angle(O2_H21,O2_H22)).std()
        self.H12_O1_H11_std = 0.01*(vg.angle(O1_H11,O1_H12)).std()
        

    def create_config(self,config):
        O1 =config[0,1:4]
        O2 =config[1,1:4]
        H  =config[2,1:4]
        H21=config[3,1:4]
        H22=config[4,1:4]
        H11=config[5,1:4]
        H12=config[6,1:4]
        
        H_O1       = O1-H
        H_O2       = O2-H
        O1_H11     = H11-O1
        O1_H12     = H12-O1
        O2_H21     = H21-O2
        O2_H22     = H22-O2
        O1_H_O2    = vg.angle(H_O1,H_O2)
        H22_O2_H21 = vg.angle(O2_H21,O2_H22)
        H12_O1_H11 = vg.angle(O1_H11,O1_H12)
        
        d_H_O1       = np.random.normal(loc=0, scale=self.H_O1_std      )
        d_H_O2       = np.random.normal(loc=0, scale=self.H_O2_std      )
        d_O1_H11     = np.random.normal(loc=0, scale=self.O1_H11_std    )
        d_O1_H12     = np.random.normal(loc=0, scale=self.O1_H12_std    )
        d_O2_H21     = np.random.normal(loc=0, scale=self.O2_H21_std    )
        d_O2_H22     = np.random.normal(loc=0, scale=self.O2_H22_std    )
        d_O1_H_O2    = np.random.normal(loc=0, scale=self.O1_H_O2_std   )
        d_H22_O2_H21 = np.random.normal(loc=0, scale=self.H22_O2_H21_std)
        d_H12_O1_H11 = np.random.normal(loc=0, scale=self.H12_O1_H11_std)
        new_H  = H
        r,t,p  = cartesian_to_polar_3d(H_O1)
        new_O1 = new_H + polar_to_cartesian_3d(r+d_H_O1,t+d_O1_H_O2/4,p+d_O1_H_O2/4)
        r,t,p  = cartesian_to_polar_3d(H_O2)
        new_O2 = new_H + polar_to_cartesian_3d(r+d_H_O2,t+d_O1_H_O2/4,p+d_O1_H_O2/4)
        r,t,p  = cartesian_to_polar_3d(O1_H11)
        new_H11= new_O1 + polar_to_cartesian_3d(r+d_O1_H11,t+d_H12_O1_H11/4,p+d_H12_O1_H11/4)
        r,t,p  = cartesian_to_polar_3d(O1_H12)
        new_H12= new_O1 + polar_to_cartesian_3d(r+d_O1_H12,t+d_H12_O1_H11/4,p+d_H12_O1_H11/4)
        r,t,p  = cartesian_to_polar_3d(O2_H21)
        new_H21= new_O2 + polar_to_cartesian_3d(r+d_O2_H21,t+d_H22_O2_H21/4,p+d_H22_O2_H21/4)
        r,t,p  = cartesian_to_polar_3d(O2_H22)
        new_H22= new_O2 + polar_to_cartesian_3d(r+d_O2_H22,t+d_H22_O2_H21/4,p+d_H22_O2_H21/4)
        new_config=np.copy(config)
        new_config[0,1:4]=new_O1 
        new_config[1,1:4]=new_O2 
        new_config[2,1:4]=new_H  
        new_config[3,1:4]=new_H21
        new_config[4,1:4]=new_H22
        new_config[5,1:4]=new_H11
        new_config[6,1:4]=new_H12
        return new_config
    
    #calcul d'energie d'une configuration
    def GetEnergy(self,config):
        generate_xyz([config], "a.xyz")
        Soap_pca=SOAP_Vector("a.xyz",  cutoff=5., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pca=self.pca)
        Soap_pca_red=self.soapscaler.transform(Soap_pca)
        y_pred=self.model.predict(Soap_pca_red)
        E_pred=self.yscaler.inverse_transform(y_pred)
        return E_pred[0,0]
        
    #probabilité selon la distribution de Boltzmann
    def get_proba(self,E_last,E_new):
        return np.exp((E_last-E_new)/(self.E_temp))
    
    def run_mcmc(self,config_init,N_config):
        dataset_gen=[]
        energies_gen=[]
        E_last=self.GetEnergy(config_init)
        new_config=config_init
        dataset_gen.append(new_config)
        energies_gen.append(E_last)
        while(N_config> len(energies_gen)):
            test_config=self.create_config(new_config)
            E_pred=self.GetEnergy(test_config)
            if (E_pred <= E_last ):
                if (E_pred >= self.E_min):
                    new_config=test_config
                    dataset_gen.append(new_config)
                    energies_gen.append(E_pred)
            else :
                if(self.get_proba(E_last,E_pred)>np.random.uniform()):
                    new_config=test_config
                    dataset_gen.append(new_config)
                    energies_gen.append(E_pred)
        return np.array(dataset_gen),np.array(energies_gen)


def cartesian_to_polar_3d(vector):
  # Convert the input vector to a NumPy array
  v = np.array(vector)
  
  # Calculate the polar coordinates
  r = np.linalg.norm(v)
  theta = np.arccos(v[2] / r)
  phi = np.arctan2(v[1], v[0])
  
  # Return the polar coordinates
  return (r, theta, phi)

def polar_to_cartesian_3d(r, theta, phi):
  # Calculate the Cartesian coordinates
  x = r * np.sin(theta) * np.cos(phi)
  y = r * np.sin(theta) * np.sin(phi)
  z = r * np.cos(theta)
  
  # Return the Cartesian coordinates
  return (x, y, z)


krrsoap = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=1,param_grid={'alpha': [3.1622776601683794e-12], 'gamma': [3.162277660168379e-06]})
krrsoap.fit(X_train_soap_red, y_train)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.54603e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.5913e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.50017e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.57175e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=4.59364e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=3.48161e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# GridSearchCV(cv=5, estimator=KernelRidge(gamma=0.1, kernel='rbf'),
#              param_grid={'alpha': [3.1622776601683794e-12],
#                          'gamma': [3.162277660168379e-06]})

# %%
new_dataset,new_energies=MC.run_mcmc(dataset[0],1000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-286-30d103775674> in <module>
# ----> 1 new_dataset,new_energies=MC.run_mcmc(dataset[0],1000)
#
# <ipython-input-278-e73490efda70> in run_mcmc(self, config_init, N_config)
#     120         dataset_gen=[]
#     121         energies_gen=[]
# --> 122         E_last=self.GetEnergy(config_init)
#     123         new_config=config_init
#     124         dataset_gen.append(new_config)
#
# <ipython-input-278-e73490efda70> in GetEnergy(self, config)
#     105     #calcul de l'energie d'une configuration
#     106     def GetEnergy(self,config):
# --> 107         generate_xyz(config, "a.xyz")
#     108         Soap_pca=SOAP_Vector("a.xyz",  cutoff=3., n_max=6, l_max=6, zeta=2.0,
#     109          atom_sigma=0.5, pca=self.pca)
#
# <ipython-input-285-d46aa4360dcd> in generate_xyz(positions, filename)
#      11         for pos in position:
#      12           # Write the atomic symbol and coordinates to the file
# ---> 13             if(pos[0]==0.):
#      14                 f.write('O ' + ' '.join(str(x) for x in pos[1:4]) + '\n')
#      15             if(pos[0]==1.):
#
# IndexError: invalid index to scalar variable.

# %%
generate_xyz(new_dataset, "mcmc.xyz")
nv.show_mdtraj(mdt.load_xyz("mcmc.xyz", top='zundel.pdb'))
# Out:
# <ipython-input-223-dc7d3a271a01>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1=fig.add_subplot(2, 1, 2)
# <div id='ad20bd21-1164-4c7d-a7c1-555bc2d294cc'></div>

# %%
plt.plot(energies[:2000])
plt.plot(new_energies,alpha=0.6)

# %%
plt.figure(figsize=(5,2), dpi= 200)
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

# plt.figure(figsize=(5,2), dpi= 200)
sns.distplot(pd.DataFrame(energies), color="blue", **kwargs,label="ab initio")
print("E moyen :",energies.mean()," +- ",energies.std())
sns.distplot(pd.DataFrame(new_energies), color="orange", **kwargs,label="monte carlo")
print("E moyen :",new_energies.mean()," +- ",new_energies.std())

plt.legend()
plt.xlabel(r'Energie $[u.a]$')
plt.ylabel("Densité")

plt.title("Distribution des Energies")
plt.show()
# Out:
# array([[ 0.00000000e+00,  2.24643327e+00,  1.21709100e-02,
#          8.47437000e-03],
#        [ 0.00000000e+00, -2.25776180e+00,  1.15926000e-03,
#          2.68762000e-03],
#        [ 1.00000000e+00,  7.90166000e-03, -1.38440000e-03,
#          1.29170760e-01],
#        [ 1.00000000e+00, -3.01260594e+00,  1.47988102e+00,
#         -7.37079700e-01],
#        [ 1.00000000e+00, -3.20407528e+00, -4.70426980e-01,
#          1.48716647e+00],
#        [ 1.00000000e+00,  2.99892402e+00, -1.48736113e+00,
#         -7.45110910e-01],
#        [ 1.00000000e+00,  3.20703656e+00,  4.59307860e-01,
#          1.50818372e+00]])

# %%
Boltzmann
# plt.plot(output[5])
plt.plot(output[4])
plt.plot(output[7]*Boltzmann/eV)

# %%
eV
# Out:
# 1.602176634e-19

# %%
# Out:
# loaded xyz file: a.xyz, with 1 frames and elements: [1 8]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-db64f18927cf> in <module>
# ----> 1 Soap_pca,pca=SOAP_Vectors("a.xyz", output_filename=None, cutoff=3., n_max=6, l_max=6, zeta=2.0,
#       2          atom_sigma=0.5, pca_d=12)
#
# <ipython-input-150-bf601a99df3c> in SOAP_Vectors(xyz_filename, output_filename, cutoff, n_max, l_max, zeta, atom_sigma, pca_d, kernel_matrix)
#      42         data_2d = np.array([features_2d.flatten() for features_2d in soap_vectors])
#      43         pca = PCA(n_components=pca_d)
# ---> 44         pca.fit(data_2d)
#      45         Soap_pca = pca.transform(data_2d)
#      46 #         print("original shape:   ", soap_vectors.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     350             Returns the instance itself.
#     351         """
# --> 352         self._fit(X)
#     353         return self
#     354
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     421         # Call different fits for either full or truncated SVD
#     422         if self._fit_svd_solver == 'full':
# --> 423             return self._fit_full(X, n_components)
#     424         elif self._fit_svd_solver in ['arpack', 'randomized']:
#     425             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit_full(self, X, n_components)
#     437                                  "if n_samples >= n_features")
#     438         elif not 0 <= n_components <= min(n_samples, n_features):
# --> 439             raise ValueError("n_components=%r must be between 0 and "
#     440                              "min(n_samples, n_features)=%r with "
#     441                              "svd_solver='full'"
#
# ValueError: n_components=12 must be between 0 and min(n_samples, n_features)=7 with svd_solver='full'
