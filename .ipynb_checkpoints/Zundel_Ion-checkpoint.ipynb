# %% [markdown]
# ## **Load des données et animations** ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
import pandas as pd

# %matplotlib inline 

#Loader du fichier .xyz
def load_data(file):
    o1_index=[2]
    o2_index=[3]
    h1_index=[4]
    h2_index=[5]
    h3_index=[6]
    h4_index=[7]
    h5_index=[8]

    o1=[]
    o2=[]
    h1=[]
    h2=[]
    h3=[]
    h4=[]
    h5=[]

    with open(file, 'r') as infile:

        for index, line in enumerate(infile):
            items = line.split()

            if index%9 in o1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o1.append([0,x,y,z])

            if index%9 in o2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                o2.append([0,x,y,z])

            if index%9 in h1_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h1.append([1,x,y,z])   

            if index%9 in h2_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h2.append([1,x,y,z])

            if index%9 in h3_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h3.append([1,x,y,z])

            if index%9 in h4_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h4.append([1,x,y,z])

            if index%9 in h5_index:
                kind, x, y, z = items[0], float(items[1]), float(items[2]), float(items[3])
                h5.append([1,x,y,z])
                
    return np.concatenate((o1, o2, h1, h2, h3, h4, h5), axis=1).reshape(10000, 7, 4) #10000 fois 7 colomnes de 4 éléments  (particule, x, y, z)

#Loader de l'output de la simulation (fichier .out)
output=pd.read_csv('new_energies_sparse.out', sep=' ', header=None)

#output=pd.read_csv('zundel-1.ener', sep='       ')
#Extraction des énergies (5eme colonne)
energies=output[4]

#energies=output['     Pot.[a.u.]'][0::5]

#Load du fichier .xyz
#dataset=load_data("zundel-pos-1.xyz")
dataset=load_data("new_positions_sparse.xyz")

#################
# Plot des données (Animation 3D + Energie)
#################

#Nombre de data utilisées pour l'animation
N=100

#Init animation 2D
def init():
    return graph,

#Fonction update plot energies
def update_en(num):
    graph.set_data(x[:num],y[:num])
    return graph,

#Mise en forme des trajectoires
def transform_data(X, Y, Z):
    t = np.vstack((X, Y, Z))
    return t

#Fonction update pour le plot des trajectoires
def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        line.set_data(data[0:2, num-1:num])
        line.set_3d_properties(data[2,num-1:num])
    return lines

#Fonction update des deux plots
def update_both(num, data2, line2):
    update_en(num)
    update_lines(num, data2, line2)
    
#Création de la figure
fig= plt.figure(figsize=(5, 8))

#ax1 = plot des énergies
ax1=fig.add_subplot(2, 1, 2) 
ax1.set_xlim(0, N)
ax1.set_ylim(np.min(energies), np.max(energies))
ax1.set_xlabel("Simulation step")
ax1.set_ylabel("Energie potentielle du système (eV)")

graph, = plt.plot([], [], '-')

#ax = plot des trajectoires
ax=fig.add_subplot(2, 1, 1, projection='3d')

ax.set_xlim3d([np.min(dataset[:, :, 1][:N]), np.max(dataset[:, :, 1][:N])])
ax.set_xlabel('X')

ax.set_ylim3d([np.min(dataset[:, :, 2][:N]), np.max(dataset[:, :, 2][:N])])
ax.set_ylabel('Y')

ax.set_zlim3d([np.min(dataset[:, :, 3][:N]), np.max(dataset[:, :, 3][:N])])
ax.set_zlabel('Z')

ax.set_title('Résultats de la simulation ab-initio')

plt.tight_layout()

# Données de l'énergie
x = range(N)
y = energies[:N]

# Données 3D
data=[]
lines=[]
colors=['r', 'r', 'silver','silver', 'silver', 'silver', 'silver'] #couleur des atomes
for i in range(dataset.shape[1]):
    coord=dataset[:, i][:N]
    X=coord[:, 1]
    Y=coord[:, 2]
    Z=coord[:, 3]
    data.append(transform_data(X, Y, Z))
    
    lines.append(ax.plot(data[0][0,0:1], data[0][1,0:1], data[0][2,0:1], 'o', color=colors[i])[0])

# Objet d'animation
ani = animation.FuncAnimation(fig, update_both, len(X), fargs=(data, lines),
                              interval=100, blit=False)

ani.save('ab-initio.mp4')
plt.show()

# %%
dataset=dataset

# %%
output
# Out:
#         0         1         2         3         4         5         6  \
# 0     1.0       2.0  0.003692  0.003269  0.000096  0.003174  0.000302
# 1     1.0     102.0  0.004527  0.006531  0.002632  0.003899  0.000371
# 2     1.0     202.0  0.003945  0.007161  0.002978  0.004182  0.000398
# 3     1.0     302.0  0.003904  0.005873  0.002675  0.003198  0.000305
# 4     1.0     402.0  0.004485  0.007464  0.003446  0.004018  0.000383
# ...   ...       ...       ...       ...       ...       ...       ...
# 9995  1.0  999502.0  0.013434  0.006745  0.002987  0.003757  0.000358
# 9996  1.0  999602.0  0.012982  0.004565  0.001085  0.003480  0.000331
# 9997  1.0  999702.0  0.013049  0.006868  0.003645  0.003222  0.000307
# 9998  1.0  999802.0  0.013642  0.006621  0.002572  0.004050  0.000386
# 9999  1.0  999902.0  0.013920  0.004813  0.002191  0.002622  0.000250
#
#                7   8
# 0      95.439881 NaN
# 1     117.256850 NaN
# 2     125.779360 NaN
# 3      96.178014 NaN
# 4     120.833550 NaN
# ...          ...  ..
# 9995  112.999770 NaN
# 9996  104.660550 NaN
# 9997   96.906016 NaN
# 9998  121.790850 NaN
# 9999   78.868314 NaN
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## **Mise en place des descripteurs (matrice de Coulomb)** ##

# %%
from ase import Atoms
from dscribe.descriptors import CoulombMatrix

#Fonction pour la création de la matrice de Coulomb à partir d'un dataset
def create_CM(data):
    cm = CoulombMatrix(n_atoms_max=7)
    zundel_steps=[]
    for i in range(data.shape[0]):
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %% [markdown]
# ## **Séparation et exploration statistique des données**. ##

# %%
#Séparation des données
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split

print("data shape :", dataset.shape)
print("target shape :", energies.shape)
X_train, X_test, y_train, y_test=train_test_split(dataset, energies, random_state=22)

#création des matrices de Coulomb pour les données d'entrainement
X_train_CM=create_CM(X_train)
X_test_CM=create_CM(X_test)

#conversion dans un Dataset pour explorer les données statistiquement avec les outils pandas
X_train_DF=pd.DataFrame(X_train_CM)

stat=X_train_DF.describe()

statnp=stat.to_numpy().reshape(8, 7, 7)

for i, l in enumerate(stat.index):
    #plt.subplot(2, 4, i+1)
    plt.matshow(statnp[i], cmap="plasma")
    for (x, y), value in np.ndenumerate(statnp[i]):
        plt.text(x, y, f"{value:.2f}", va="center", ha="center", color="white")
    plt.title(l)
# Out:
# data shape : (10000, 7, 4)
# target shape : (10000,)

# %%
dataset[-1]
# Out:
# array([[ 0.        ,  2.58654844, 12.89679366, 21.45336724],
#        [ 0.        , -0.20412227, 13.11867535, 24.9613151 ],
#        [ 1.        ,  1.21485485, 12.90784129, 23.29377728],
#        [ 1.        , -0.7129864 , 14.85135666, 25.21131349],
#        [ 1.        , -1.63287982, 11.99057295, 25.01914398],
#        [ 1.        ,  3.9226899 , 11.70316952, 21.33694977],
#        [ 1.        ,  1.88295753, 13.20836486, 19.83790884]])

# %%
plt.matshow(create_CM(X_train)[0].reshape(7, 7), cmap="YlGnBu")

for (x, y), value in np.ndenumerate(create_CM(X_train)[0].reshape(7, 7)):
    plt.text(x, y, f"{value:.3f}", va="center", ha="center", color="red")
    
plt.title("Exemple de matrice de Coulomb")
# Out:
# Text(0.5, 1.0, 'Exemple de matrice de Coulomb')

# %% [markdown]
# Réduction des données

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train_CM_red=scaler.fit_transform(X_train_CM)
X_test_CM_red=scaler.fit_transform(X_test_CM)

#scaling des y
y_train=y_train/np.max(y_train)**2
y_test=y_test/np.max(y_test)**2

# %% [markdown]
# ### Eigenspectrum ###

# %%
def create_CM_eigen(data):
    cm = CoulombMatrix(n_atoms_max=7, permutation='eigenspectrum')
    zundel_steps=[]
    for i in range(data.shape[0]):
        zundel_steps.append(cm.create(Atoms("O2H5", [(data[i][j][1], data[i][j][2], data[i][j][3]) for j in range(data.shape[1])])))
    return np.array(zundel_steps)

# %%
pd.DataFrame(create_CM_eigen(X_train)).describe()
# Out:
#                  0            1            2            3            4  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     88.701505    59.682468     0.417565     0.242826     0.173534
# std       0.183102     0.177838     0.009194     0.006553     0.004729
# min      87.977655    58.979104     0.388062     0.219960     0.157364
# 25%      88.582326    59.559842     0.411327     0.238478     0.170198
# 50%      88.705274    59.678830     0.417490     0.242890     0.173346
# 75%      88.827863    59.797708     0.423616     0.247244     0.176679
# max      89.435804    60.383806     0.453386     0.267795     0.194823
#
#                  5            6
# count  7500.000000  7500.000000
# mean      0.162842     0.152649
# std       0.004301     0.005124
# min       0.143278     0.131788
# 25%       0.159958     0.149336
# 50%       0.162958     0.152911
# 75%       0.165817     0.156172
# max       0.178765     0.169214

# %%
X_train_CMe=create_CM_eigen(X_train)
X_test_CMe=create_CM_eigen(X_test)
X_train_CMe_red=scaler.fit_transform(X_train_CMe)
X_test_CMe_red=scaler.fit_transform(X_test_CMe)

# %% [markdown]
# ## PIV Vector ##

# %%
from scipy.spatial import distance

def PIV_descr(X):
    piv=[]
    for i in range(len(X)):
        dist=distance.cdist(dataset[i][:, 1:], dataset[i][:, 1:], 'euclidean')
        a=np.array([dist[0, 1]])
        b=np.concatenate((dist[0, 2:],dist[1, 2:]))
        c=[]
        for i in range(2, dist.shape[0]):
            c=np.concatenate((c, dist[i, i+1:]))

        bs=-np.sort(-b)
        cs=-np.sort(-c)
        piv.append(np.concatenate((a, bs, cs)))
        
    return piv

# %%
X_train_PIV=PIV_descr(X_train)
X_train_PIV_red=scaler.fit_transform(X_train_PIV)
X_test_PIV=PIV_descr(X_test)
X_test_PIV_red=scaler.fit_transform(X_test_PIV)

# %% [markdown]
# ## **SOAP** ##

# %%
from dscribe.descriptors import SOAP
from ase.io import write

def generate_SOAP(xyz_filename, output_filename=None, cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pbc=False, peratom=False, pca_d=4, njobs=1):
    """KenelPCA on atomic or per-config SOAP vectors.

    `peratom=True` performs projection on SOAP vectors from arrays
    `peratom=False` performs projection on SOAP vectors from info

    Note:
    The previous ASAP pca.py was projecting from info anyways and with peratom=True transformed the SOAP vectors from
    arrays into that space as well.

    Parameters
    ----------
    xyz_filename
    prefix
    output_filename
    cutoff
    n_max
    l_max
    zeta
    atom_sigma
    pbc
    peratom
    pca_d
    njobs

    Returns
    -------

    """

    if output_filename is None:
        output_filename =xyz_filename+ ".out".format(str(pca_d))
    peratom = bool(peratom)

    # read the xyz file
    frames = ase.io.read(xyz_filename, ':')
    n_frames = len(frames)

    # species and PBC
    global_species = []
    for frame in frames:
        global_species.extend(frame.get_atomic_numbers())
        frame.set_pbc(pbc)
    global_species = np.unique(global_species)
    print("loaded xyz file: {fn}, with {n_frames} frames and elements: {ele}".format(fn=xyz_filename, n_frames=n_frames,
                                                                                     ele=global_species))

    # soap
    desc = SOAP(rcut=cutoff, nmax=n_max, lmax=l_max, sigma=atom_sigma, species=global_species, periodic=False,
                average="off")

    # kernel
    soap_vectors = desc.create(frames)
    return soap_vectors
#     kNN = np.dot(soap_vectors, soap_vectors.T) ** zeta
#     print("kernel matrix (shape: {}) calculated from vector set of shape {}".format(kNN.shape, soap_vectors.shape))

#     # projection
#     projection = KernelPCA(pca_d).fit_transform(kNN)

#     # add coords to info/arrays
#     if peratom:
#         running_index = 0
#         for at in frames:
#             n_atoms = len(at)
#             at.arrays['pca_coord'] = projection[running_index:running_index + n_atoms, :].copy()
#             running_index += n_atoms
#     else:
#         for i, at in enumerate(frames):
#             at.info['pca_coord'] = projection[i]

#     # save
#     write(output_filename, frames, write_results=False)

# %%
vectors=generate_SOAP(xyz_filename="new_positions_sparse.xyz", output_filename=None, cutoff=3., n_max=6, l_max=6, zeta=2.0,
         atom_sigma=0.5, pbc=True, peratom=False, pca_d=4, njobs=4)
# Out:
# loaded xyz file: new_positions_sparse.xyz, with 10000 frames and elements: [1 8]

# %%
from sklearn.decomposition import PCA
data_2d = np.array([features_2d.flatten() for features_2d in vectors])
pca = PCA(n_components=10)
pca.fit(data_2d)
data_pca = pca.transform(data_2d)
print("original shape:   ", data_2d.shape)
print("transformed shape:", data_pca.shape)

print(pca.explained_variance_ratio_)

print(pca.singular_values_)


X_train, X_test, y_train, y_test=train_test_split(data_pca, energies, random_state=22)
# Out:
# (10000, 7, 546)
# original shape:    (10000, 3822)
# transformed shape: (10000, 10)
# [0.52890627 0.09964121 0.08459326 0.08082073 0.05515621 0.04941293
#  0.02679429 0.0144331  0.01396681 0.01340333]
# [54.08331438 23.47434221 21.62926834 21.14147738 17.46510356 16.53081456
#  12.17292947  8.93415955  8.78865641  8.60954626]

# %% [markdown]
# ## **Prédicteur naif** ##

# %%
from sklearn.metrics import mean_squared_error

def naive_predictor(xtrain, ytrain):
    return np.ones((xtrain.shape[0],))*ytrain.mean()

y_fit=naive_predictor(X_train_CMe_red, y_train)
y_pred_test=naive_predictor(X_test_CMe_red, y_train)


mse=mean_squared_error(np.array(y_train), y_fit)
mse_test=mean_squared_error(np.array(y_test), y_pred_test)
print(mse)
print(mse_test)
# Out:
# 359.92747668335727
# 324.9492863581159

# %%
y_fit=naive_predictor(X_train_PIV_red, y_train)
y_pred_test=naive_predictor(X_test_PIV_red, y_train)


mse=mean_squared_error(np.array(y_train), y_fit)
mse_test=mean_squared_error(np.array(y_test), y_pred_test)
print(mse)
print(mse_test)
# Out:
# 359.92747668335727
# 324.9492863581159

# %% [markdown]
# ## **Modèle linéaire** ##

# %%
from sklearn.linear_model import RidgeCV

a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_CMe_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("RMSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_CMe_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print(mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 284.7467653710055
# 249.75806520952406

# %%
plt.scatter(np.arange(0, len(y_train[:100])),model.predict(X_train_CMe_red[:100]), marker='.')
plt.plot(np.arange(0, len(y_train[:100])), y_train[:100], alpha=0.2)

# %%
#PIV
from sklearn.linear_model import RidgeCV

a=np.logspace(-10, 10, 1000)
model=RidgeCV(alphas=a)
model.fit(X_train_PIV_red, y_train)

print("Best regularization parameter :", model.alpha_)
print("RMSE moyen:", -model.best_score_)

y_pred_test_rcv=model.predict(X_test_PIV_red)
mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
print(mse_test_rcv)
# Out:
# Best regularization parameter : 4939.621743878326
# RMSE moyen: 8.267033110173408e-07
# 8.313969525925687e-07

# %%
import seaborn as sns

sns.pairplot(pd.DataFrame(X_train_CMe_red), corner=True)

# %%
from sklearn.preprocessing import PolynomialFeatures

mse_list=[]
mse_test_list=[]
for d in range(1,10):
    poly=PolynomialFeatures(degree=d)
    Zmodif=poly.fit_transform(X_train_CMe_red)
    Zmodif_test=poly.fit_transform(X_test_CMe_red)

    a=np.logspace(-10, 10, 1000)
    model=RidgeCV(alphas=a)
    model.fit(Zmodif, y_train)

    print("Best regularization parameter :", model.alpha_)
    print("RMSE moyen:", -model.best_score_)

    y_pred_test_rcv=model.predict(Zmodif_test)
    mse_test_rcv=mean_squared_error(np.array(y_test), y_pred_test_rcv)
    print(mse_test_rcv)
    mse_list.append(-model.best_score_)
    mse_test_list.append(mse_test_rcv)
# Out:
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 6.544416845910233e-07
# 6.277022605967206e-07
# Best regularization parameter : 14.162866162991973
# RMSE moyen: 4.466686541224127e-07
# 4.3266441931596907e-07
# Best regularization parameter : 17.030650292528428
# RMSE moyen: 4.4689098750480647e-07
# 4.329518199778006e-07
# Best regularization parameter : 42.818517986524064
# RMSE moyen: 4.5647172496354113e-07
# 4.4332864327097377e-07
# Best regularization parameter : 1560.2464143663713
# RMSE moyen: 4.878920310205851e-07
# 4.810495714600251e-07
# Best regularization parameter : 17148.81969870541
# RMSE moyen: 5.856778646335485e-07
# 5.131147666337386e-07
# Best regularization parameter : 312964.80106707505
# RMSE moyen: 6.862769009688551e-07
# 6.121174841429971e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3r/d3wp35hd6272_2dzc60w8lcm0000gn/T/ipykernel_1094/166360120.py in <module>
#      10     a=np.logspace(-10, 10, 1000)
#      11     model=RidgeCV(alphas=a)
# ---> 12     model.fit(Zmodif, y_train)
#      13
#      14     print("Best regularization parameter :", model.alpha_)
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
#    2167                 alpha_per_target=self.alpha_per_target,
#    2168             )
# -> 2169             estimator.fit(X, y, sample_weight=sample_weight)
#    2170             self.alpha_ = estimator.alpha_
#    2171             self.best_score_ = estimator.best_score_
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py in fit(self, X, y, sample_weight)
#    2008
#    2009         for i, alpha in enumerate(np.atleast_1d(self.alphas)):
# -> 2010             G_inverse_diag, c = solve(float(alpha), y, sqrt_sw, X_mean, *decomposition)
#    2011             if error:
#    2012                 squared_errors = (c / G_inverse_diag) ** 2
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py in _solve_svd_design_matrix(self, alpha, y, sqrt_sw, X_mean, singvals_sq, U, UT_y)
#    1917             w[intercept_dim] = -(alpha**-1)
#    1918         c = np.dot(U, self._diag_dot(w, UT_y)) + (alpha**-1) * y
# -> 1919         G_inverse_diag = self._decomp_diag(w, U) + (alpha**-1)
#    1920         if len(y.shape) != 1:
#    1921             # handle case where y is 2-d
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py in _decomp_diag(v_prime, Q)
#    1617     def _decomp_diag(v_prime, Q):
#    1618         # compute diagonal of the matrix: dot(Q, dot(diag(v_prime), Q^T))
# -> 1619         return (v_prime * Q**2).sum(axis=-1)
#    1620
#    1621     @staticmethod
#
# KeyboardInterrupt:

# %%
plt.plot([8.27e-7]*len(mse_list), label='modèle naif')
plt.plot(mse_list, label="train")
plt.plot(mse_test_list, label='test')
plt.legend()
plt.ylabel("MSE")
plt.xlabel("Dimension du polynome")
# Out:
# Text(0.5, 0, 'Dimension du polynome')

# %%
y_pred=model.predict(Zmodif_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/3r/d3wp35hd6272_2dzc60w8lcm0000gn/T/ipykernel_1094/2662304437.py in <module>
# ----> 1 y_pred=model.predict(Zmodif_test)
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     365
#     366     def _decision_function(self, X):
# --> 367         check_is_fitted(self)
#     368
#     369         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# /opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1343
#    1344     if not fitted:
# -> 1345         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1346
#    1347
#
# NotFittedError: This RidgeCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
plt.scatter(np.arange(0, len(y_test[:100])),y_pred[:100], marker='.')
plt.plot(np.arange(0, len(y_test[:100])), y_test[:100], alpha=0.2)
# Out:
# /var/folders/3r/d3wp35hd6272_2dzc60w8lcm0000gn/T/ipykernel_1631/3197482890.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.scatter(np.arange(0, len(y_test[:100])),y_pred[:100], marker='.')
# /var/folders/3r/d3wp35hd6272_2dzc60w8lcm0000gn/T/ipykernel_1631/3197482890.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(np.arange(0, len(y_test[:100])), y_test[:100], alpha=0.2)

# %%
from sklearn.linear_model import ElasticNetCV

a=np.logspace(-10, 10)
model=ElasticNetCV(alphas=a, max_iter=1000000)
model.fit(X_train_CMe_red, y_train)

print("Best regularization parameter :", model.alpha_)
#print("RMSE moyen:", -model.best_score_)

y_pred_train_en=model.predict(X_train_CMe_red)
mse_train_en=mean_squared_error(np.array(y_train), y_pred_train_en)
print(mse_train_en)


y_pred_test_en=model.predict(X_test_CMe_red)
mse_test_en=mean_squared_error(np.array(y_test), y_pred_test_en)
print(mse_test_en)
# Out:
# Best regularization parameter : 7.196856730011529e-08
# 6.529873802138329e-07
# 6.276422018040093e-07

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.kernel_ridge import KernelRidge
krr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,param_grid={"alpha": np.logspace(-5, -0,2),
                                                                          "gamma": np.logspace(-8.5, -7.5,2)})
krr.fit(X_train_CMe_red, y_train)

y_pred_test_krr=krr.predict(X_test_CMe_red)

mse_test=mean_squared_error(np.array(y_test), y_pred_test_krr)
print(mse_test)
# Out:
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\Zacharie\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# 5.248701520538279e-07

# %%
print(krr.best_params_)
y_pred_test_krr=krr.predict(X_test_CMe_red)

mse_test=mean_squared_error(np.array(y_test), y_pred_test_krr)
print(mse_test)

y_pred_train_krr=krr.predict(X_train_CMe_red)

mse_train=mean_squared_error(np.array(y_train), y_pred_train_krr)
print(mse_train)
# Out:
# {'alpha': 1e-10, 'gamma': 3.162277660168379e-08}
# 5.248701520538279e-07
# 5.400072114552637e-07

# %% [markdown]
# ## **Réseau de neurones** ##

# %%
import keras
import tensorflow as tf

from keras import Sequential
from keras.layers import Dense

model=Sequential()
model.add(Dense(units=15, activation='tanh', input_shape=(7,)))
model.add(Dense(units=15, activation='tanh'))
model.add(Dense(units=1))
model.summary()

model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=0.0008), metrics=['mean_squared_error'])

Hist=model.fit(X_train_CMe_red, y_train, epochs=300, batch_size=30, validation_split=0.2)

plt.plot(Hist.history['loss'][1:])
plt.plot(Hist.history['val_loss'][1:])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 15)                120
#
#  dense_28 (Dense)            (None, 15)                240
#
#  dense_29 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 376
# Trainable params: 376
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 200/200 [==============================] - 1s 4ms/step - loss: 3091.6069 - mean_squared_error: 3091.6069 - val_loss: 2799.1772 - val_mean_squared_error: 2799.1772
# Epoch 2/300
# 200/200 [==============================] - 0s 1ms/step - loss: 2515.4121 - mean_squared_error: 2515.4121 - val_loss: 2122.8059 - val_mean_squared_error: 2122.8059
# Epoch 3/300
# 200/200 [==============================] - 0s 1ms/step - loss: 2037.7152 - mean_squared_error: 2037.7152 - val_loss: 1815.2257 - val_mean_squared_error: 1815.2257
# Epoch 4/300
# 200/200 [==============================] - 0s 1ms/step - loss: 1780.5760 - mean_squared_error: 1780.5760 - val_loss: 1598.9303 - val_mean_squared_error: 1598.9303
# Epoch 5/300
# 200/200 [==============================] - 0s 1ms/step - loss: 1581.1354 - mean_squared_error: 1581.1354 - val_loss: 1420.8124 - val_mean_squared_error: 1420.8124
# Epoch 6/300
# 200/200 [==============================] - 0s 1ms/step - loss: 1412.1942 - mean_squared_error: 1412.1942 - val_loss: 1267.1676 - val_mean_squared_error: 1267.1676
# Epoch 7/300
300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.7032 - mean_squared_error: 197.7032 - val_loss: 194.2366 - val_mean_squared_error: 194.2366
# Epoch 284/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.4118 - mean_squared_error: 197.4118 - val_loss: 197.4278 - val_mean_squared_error: 197.4278
# Epoch 285/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.8059 - mean_squared_error: 197.8059 - val_loss: 195.4167 - val_mean_squared_error: 195.4167
# Epoch 286/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.7565 - mean_squared_error: 197.7565 - val_loss: 194.1085 - val_mean_squared_error: 194.1085
# Epoch 287/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.8000 - mean_squared_error: 197.8000 - val_loss: 195.3059 - val_mean_squared_error: 195.3059
# Epoch 288/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.8541 - mean_squared_error: 197.8541 - val_loss: 194.8120 - val_mean_squared_error: 194.8120
# Epoch 289/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.5259 - mean_squared_error: 197.5259 - val_loss: 193.9576 - val_mean_squared_error: 193.9576
# Epoch 290/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.6109 - mean_squared_error: 197.6109 - val_loss: 194.5606 - val_mean_squared_error: 194.5606
# Epoch 291/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.9077 - mean_squared_error: 197.9077 - val_loss: 193.5516 - val_mean_squared_error: 193.5516
# Epoch 292/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.6074 - mean_squared_error: 197.6074 - val_loss: 194.9211 - val_mean_squared_error: 194.9211
# Epoch 293/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.2067 - mean_squared_error: 197.2067 - val_loss: 193.9151 - val_mean_squared_error: 193.9151
# Epoch 294/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.4099 - mean_squared_error: 197.4099 - val_loss: 194.5028 - val_mean_squared_error: 194.5028
# Epoch 295/300
# 200/200 [==============================] - 0s 2ms/step - loss: 197.3014 - mean_squared_error: 197.3014 - val_loss: 193.8670 - val_mean_squared_error: 193.8670
# Epoch 296/300
# 200/200 [==============================] - 0s 1ms/step - loss: 196.9063 - mean_squared_error: 196.9063 - val_loss: 194.2767 - val_mean_squared_error: 194.2767
# Epoch 297/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.6012 - mean_squared_error: 197.6012 - val_loss: 196.9599 - val_mean_squared_error: 196.9599
# Epoch 298/300
# 200/200 [==============================] - 0s 2ms/step - loss: 197.3544 - mean_squared_error: 197.3544 - val_loss: 196.1432 - val_mean_squared_error: 196.1432
# Epoch 299/300
# 200/200 [==============================] - 0s 2ms/step - loss: 197.1247 - mean_squared_error: 197.1247 - val_loss: 194.8597 - val_mean_squared_error: 194.8597
# Epoch 300/300
# 200/200 [==============================] - 0s 1ms/step - loss: 197.6027 - mean_squared_error: 197.6027 - val_loss: 195.3852 - val_mean_squared_error: 195.3853

# %%
a=0
b=a+100
y_pred=model.predict(X_train_CMe_red)
plt.plot(np.arange(len(y_pred[a:b])),y_pred[a:b],alpha=0.5)
plt.scatter(np.arange(len(y_pred[a:b])),y_train[a:b],alpha=0.5,marker='o',c='red')

y_pred_test_krr=model.predict(X_test_CMe_red)

mse_test=mean_squared_error(np.array(y_test), y_pred_test_krr)
y_pred_train_krr=model.predict(X_train_CMe_red)

print("test ",mse_test)


mse_train=mean_squared_error(np.array(y_train), y_pred_train_krr)
print("train ",mse_train)
# Out:
# 235/235 [==============================] - 0s 812us/step
# 79/79 [==============================] - 0s 975us/step
# 235/235 [==============================] - 0s 925us/step
# test  186.14867309993897
# train  195.93589616558458
